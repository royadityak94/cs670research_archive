# %%
import boto3
import io
import re
import numpy as np
import os
import xml.etree.ElementTree as ET 
from google.cloud import vision
import requests
from nltk.corpus import stopwords as stpword
from nltk.stem import WordNetLemmatizer
import json
from nltk.corpus import stopwords as stpword
from nltk.stem import WordNetLemmatizer
from utilities.image_description_scoring import matching_label_score
from time import time
from utilities.pythonDB import writeToDB, recordsExists

# %%
stopwords = set(stpword.words('english'))
wordNetLemma = WordNetLemmatizer()

def extract_clean_list(original_list):
    cleaned = list(set([wordNetLemma.lemmatize(obj_item.lower().strip()) for item in original_list for obj_item in item.split() if obj_item not in stopwords]))
    return [item.strip() for item in [re.sub('[^a-zA-Z0-9]+', ' ', item, flags=re.UNICODE) for item in cleaned]]

def get_mapped(path):
    key_map, dict_idx = {}, 0
    for r, _, f in os.walk(path):
        for file in f:
            if '.JPG' in file or '.jpg' in file:
                key_map[dict_idx] = file
                dict_idx += 1
    idxs = list(key_map.keys())          
    shuffled_idxs = np.random.randint(0, len(idxs), len(idxs))
    return key_map, shuffled_idxs

def get_captions(base_path, annotation_file):
    with open(os.path.join(base_path, annotation_file)) as json_file:
        caption_file = json.load(json_file)
    captions, mapped_annotation = {}, {}

    for annotation in caption_file['annotations']:
        mapped_annotation[annotation['image_id']] = annotation['caption']

    for image in caption_file['images']:
        captions[image['file_name']] = mapped_annotation.get(image['id'])
    return captions

# %%
class DetectLabels():
    def __init__(self, base, file, max_labels=30):
        
        with io.open(os.path.join(base, file), 'rb') as image_file:
            content = (image_file.read())
        self.content = content
        self.base, self.file, self.actual_str, self.detected_str = base, file, '', ''
        self.label = ''
        self.start = time()
        self.max_labels = max_labels
        
    def return_function(self, name):
        dataset = self.base.split('/')[1]
        if recordsExists(self.file, dataset, name):
            return
        
        status, score =  getattr(self, 'if_' + name)()
        compute_time = time() - self.start
        self.label = name
        
        bag = (self.file, dataset, self.label, status, score, compute_time, self.actual_str, self.detected_str)
        writeToDB(bag)
        
    def compute_ground_truth(self):
        ''' Status = {-1:'API Error', -2: 'Ground Truth Empty', 0: 'All Correct'}, Return = Ground Truth, Status
        '''
        ground_truth_str = captions.get(self.file)
        
        if ground_truth_str is None or len(ground_truth_str) == 0:
            return '', -2
        else:
            ground_truth_str = extract_clean_list(ground_truth_str.lower().split(' '))
            self.actual_str = ground_truth_str
            return ground_truth_str, 0
    
    def if_gc(self):
        ground_truth, xml_status = self.compute_ground_truth()
        if xml_status != 0: return xml_status, 0
        
        try:
            vision_client = vision.ImageAnnotatorClient()
            image = vision.types.Image(content=self.content)
            text_detection_response = vision_client.label_detection(image=image)
            detected_label = extract_clean_list([str(label.description).lower() for label in text_detection_response.label_annotations])
            score1 = matching_label_score(detected_label, ground_truth, 1)
            score2 = matching_label_score(detected_label, ground_truth, 2)
            score3 = matching_label_score(detected_label, ground_truth, 3)
            score = str([score1, score2, score3])
            
            self.detected_str = detected_label
            return 0, score
        except:
            return -1, 0
            
    def if_aws(self):
        ground_truth, xml_status = self.compute_ground_truth()
        if xml_status != 0: return xml_status, 0
        
        try:
            imgobj = {'Bytes': self.content}
            client=boto3.client('rekognition', region_name='us-east-1')
            response=client.detect_labels(Image=imgobj, MaxLabels=self.max_labels)
            detected_label = [label['Name'] for label in response['Labels']]
            score1 = matching_label_score(detected_label, ground_truth, 1)
            score2 = matching_label_score(detected_label, ground_truth, 2)
            score3 = matching_label_score(detected_label, ground_truth, 3)
            score = str([score1, score2, score3])
            
            self.detected_str = detected_label
            return 0, score
        except:
            return -1, 0
        
    def if_azure(self):
        ground_truth, xml_status = self.compute_ground_truth()
        if xml_status != 0: return xml_status, 0
        
        try:
            subscription_key = os.environ['COMPUTER_VISION_SUBSCRIPTION_KEY']
            endpoint = os.environ['COMPUTER_VISION_ENDPOINT']
            ocr_url = endpoint + "vision/v2.1/describe"
            headers = {'Ocp-Apim-Subscription-Key': subscription_key, 'Content-Type': 'application/octet-stream'}
            params = {'maxCandidates': self.max_labels}
            response = requests.post(ocr_url, headers=headers, params=params, data=self.content).json()
            detected_label = response['description']['tags']
            score1 = matching_label_score(detected_label, ground_truth, 1)
            score2 = matching_label_score(detected_label, ground_truth, 2)
            score3 = matching_label_score(detected_label, ground_truth, 3)
            score = str([score1, score2, score3])
            
            self.detected_str = detected_label
            return 0, score
        except:
            return -1, 0

# %%
annotation_dir_path = 'datasets/image_labeling/annotations'
train_dir_path = 'datasets/image_labeling/train2017'
captions_validation = get_captions(annotation_dir_path, 'captions_val2017.json')
captions = get_captions(annotation_dir_path, 'captions_train2017.json')
captions.update(captions_validation)
del captions_validation

# %%
dict_files, files_idx = get_mapped(train_dir_path)
shuffled_idx = np.random.randint(0, len(files_idx), len(files_idx))[:10000]

# %%
for idx in shuffled_idx:
    file_name = dict_files.get(idx)
    print ("Iterating for File Name = {}".format(file_name))
    DetectLabels(train_dir_path, file_name).return_function('azure')
# Out:
# Iterating for File Name = 000000211919.jpg
# Iterating for File Name = 000000025541.jpg
# Iterating for File Name = 000000328628.jpg
# Iterating for File Name = 000000027353.jpg
# Iterating for File Name = 000000152871.jpg
# Iterating for File Name = 000000390238.jpg
# Iterating for File Name = 000000009050.jpg
# Iterating for File Name = 000000036281.jpg
# Iterating for File Name = 000000367578.jpg
# Iterating for File Name = 000000542640.jpg
# Iterating for File Name = 000000479712.jpg
# Iterating for File Name = 000000121000.jpg
# Iterating for File Name = 000000176089.jpg
# Iterating for File Name = 000000570418.jpg
# Iterating for File Name = 000000276801.jpg
# Iterating for File Name = 000000213790.jpg
# Iterating for File Name = 000000184157.jpg
# Iterating for File Name = 000000419401.jpg
# Iterating for File Name = 000000291476.jpg
# Iterating for File Name = 000000403693.jpg
# Iterating for File Name = 000000502140.jpg
# Iterating for File Name = 000000565429.jpg
# Iterating for File Name = 000000555805.jpg
# Iterating for File Name = 000000082745.jpg
# Iterating for File Name = 000000232302.jpg
# Iterating for File Name = 000000190556.jpg
# Iterating for File Name = 000000432727.jpg
# Iterating for File Name = 000000015268.jpg
# Iterating for File Name = 000000249791.jpg
# Iterating for File Name = 000000402829.jpg
# Iterating for File Name = 000000099751.jpg
# Iterating for File Name = 000000344236.jpg
# Iterating for File Name = 000000358396.jpg
# Iterating for File Name = 000000341603.jpg
# Iterating for File Name = 000000102978.jpg
# Iterating for File Name = 000000465877.jpg
# Iterating for File Name = 000000549830.jpg
# Iterating for File Name = 000000034662.jpg
# Iterating for File Name = 000000376246.jpg
# Iterating for File Name = 000000434125.jpg
# Iterating for File Name = 000000399983.jpg
# Iterating for File Name = 000000078701.jpg
# Iterating for File Name = 000000545538.jpg
# Iterating for File Name = 000000432138.jpg
# Iterating for File Name = 000000359303.jpg
# Iterating for File Name = 000000377572.jpg
# Iterating for File Name = 000000232627.jpg
# Iterating for File Name = 000000419098.jpg
# Iterating for File Name = 000000562708.jpg
# Iterating for File Name = 000000037646.jpg
# Iterating for File Name = 000000468577.jpg
# Iterating for File Name = 000000213340.jpg
# Iterating for File Name = 000000421064.jpg
# Iterating for File Name = 000000431472.jpg
# Iterating for File Name = 000000484158.jpg
# Iterating for File Name = 000000341110.jpg
# Iterating for File Name = 000000141053.jpg
# Iterating for File Name = 000000150244.jpg
# Iterating for File Name = 000000360610.jpg
# Iterating for File Name = 000000104422.jpg
# Iterating for File Name = 000000284818.jpg
# Iterating for File Name = 000000315423.jpg
# Iterating for File Name = 000000573085.jpg
# Iterating for File Name = 000000109450.jpg
# Iterating for File Name = 000000315111.jpg
# Iterating for File Name = 000000310407.jpg
# Iterating for File Name = 000000022806.jpg
# Iterating for File Name = 000000268388.jpg
# Iterating for File Name = 000000135424.jpg
# Iterating for File Name = 000000251360.jpg
# Iterating for File Name = 000000278469.jpg
# Iterating for File Name = 000000094871.jpg
# Iterating for File Name = 000000559247.jpg
# Iterating for File Name = 000000539087.jpg
# Iterating for File Name = 000000149686.jpg
# Iterating for File Name = 000000020779.jpg
# Iterating for File Name = 000000045644.jpg
# Iterating for File Name = 000000158420.jpg
# Iterating for File Name = 000000363940.jpg
# Iterating for File Name = 000000342146.jpg
# Iterating for File Name = 000000363191.jpg
# Iterating for File Name = 000000013662.jpg
# Iterating for File Name = 000000011051.jpg
# Iterating for File Name = 000000098098.jpg
# Iterating for File Name = 000000025142.jpg
# Iterating for File Name = 000000127854.jpg
# Iterating for File Name = 000000097899.jpg
# Iterating for File Name = 000000056302.jpg
# Iterating for File Name = 000000344703.jpg
# Iterating for File Name = 000000526735.jpg
# Iterating for File Name = 000000254169.jpg
# Iterating for File Name = 000000281302.jpg
# Iterating for File Name = 000000454509.jpg
# Iterating for File Name = 000000316578.jpg
# Iterating for File Name = 000000043425.jpg
# Iterating for File Name = 000000497537.jpg
# Iterating for File Name = 000000564267.jpg
# Iterating for File Name = 000000045468.jpg
# Iterating for File Name = 000000134518.jpg
# Iterating for File Name = 000000497443.jpg
# Iterating for File Name = 000000003398.jpg
# Iterating for File Name = 000000108639.jpg
# Iterating for File Name = 000000197330.jpg
# Iterating for File Name = 000000260973.jpg
# Iterating for File Name = 000000174231.jpg
# Iterating for File Name = 000000287095.jpg
# Iterating for File Name = 000000252133.jpg
# Iterating for File Name = 000000362941.jpg
# Iterating for File Name = 000000252696.jpg
# Iterating for File Name = 000000519136.jpg
# Iterating for File Name = 000000236690.jpg
# Iterating for File Name = 000000152994.jpg
# Iterating for File Name = 000000348111.jpg
# Iterating for File Name = 000000296330.jpg
# Iterating for File Name = 000000509949.jpg
# Iterating for File Name = 000000008816.jpg
# Iterating for File Name = 000000279430.jpg
# Iterating for File Name = 000000379771.jpg
# Iterating for File Name = 000000217449.jpg
# Iterating for File Name = 000000561168.jpg
# Iterating for File Name = 000000266302.jpg
# Iterating for File Name = 000000449517.jpg
# Iterating for File Name = 000000151978.jpg
# Iterating for File Name = 000000076584.jpg
# Iterating for File Name = 000000565360.jpg
# Iterating for File Name = 000000067771.jpg
# Iterating for File Name = 000000106079.jpg
# Iterating for File Name = 000000136932.jpg
# Iterating for File Name = 000000463222.jpg
# Iterating for File Name = 000000003225.jpg
# Iterating for File Name = 000000505402.jpg
# Iterating for File Name = 000000170007.jpg
# Iterating for File Name = 000000478298.jpg
# Iterating for File Name = 000000511700.jpg
# Iterating for File Name = 000000173252.jpg
# Iterating for File Name = 000000230893.jpg
# Iterating for File Name = 000000104095.jpg
# Iterating for File Name = 000000394682.jpg
# Iterating for File Name = 000000412899.jpg
# Iterating for File Name = 000000427123.jpg
# Iterating for File Name = 000000426528.jpg
# Iterating for File Name = 000000444783.jpg
# Iterating for File Name = 000000558817.jpg
# Iterating for File Name = 000000471915.jpg
# Iterating for File Name = 000000042342.jpg
# Iterating for File Name = 000000377701.jpg
# Iterating for File Name = 000000314412.jpg
# Iterating for File Name = 000000567340.jpg
# Iterating for File Name = 000000028523.jpg
# Iterating for File Name = 000000078548.jpg
# Iterating for File Name = 000000105885.jpg
# Iterating for File Name = 000000305695.jpg
# Iterating for File Name = 000000269550.jpg
# Iterating for File Name = 000000312199.jpg
# Iterating for File Name = 000000056652.jpg
# Iterating for File Name = 000000477440.jpg
# Iterating for File Name = 000000284028.jpg
# Iterating for File Name = 000000455340.jpg
# Iterating for File Name = 000000099184.jpg
# Iterating for File Name = 000000100665.jpg
# Iterating for File Name = 000000019725.jpg
# Iterating for File Name = 000000034381.jpg
# Iterating for File Name = 000000508582.jpg
# Iterating for File Name = 000000225567.jpg
# Iterating for File Name = 000000014484.jpg
# Iterating for File Name = 000000028952.jpg
# Iterating for File Name = 000000394245.jpg
# Iterating for File Name = 000000107638.jpg
# Iterating for File Name = 000000336492.jpg
# Iterating for File Name = 000000201246.jpg
# Iterating for File Name = 000000113139.jpg
# Iterating for File Name = 000000145520.jpg
# Iterating for File Name = 000000289919.jpg
# Iterating for File Name = 000000446094.jpg
# Iterating for File Name = 000000217306.jpg
# Iterating for File Name = 000000060202.jpg
# Iterating for File Name = 000000402004.jpg
# Iterating for File Name = 000000414819.jpg
# Iterating for File Name = 000000263112.jpg
# Iterating for File Name = 000000234022.jpg
# Iterating for File Name = 000000021968.jpg
# Iterating for File Name = 000000361858.jpg
# Iterating for File Name = 000000551518.jpg
# Iterating for File Name = 000000581839.jpg
# Iterating for File Name = 000000199158.jpg
# Iterating for File Name = 000000204241.jpg
# Iterating for File Name = 000000300868.jpg
# Iterating for File Name = 000000286717.jpg
# Iterating for File Name = 000000164001.jpg
# Iterating for File Name = 000000556813.jpg
# Iterating for File Name = 000000029602.jpg
# Iterating for File Name = 000000355064.jpg
# Iterating for File Name = 000000209701.jpg
# Iterating for File Name = 000000327146.jpg
# Iterating for File Name = 000000115459.jpg
# Iterating for File Name = 000000418009.jpg
# Iterating for File Name = 000000358429.jpg
# Iterating for File Name = 000000223526.jpg
# Iterating for File Name = 000000360504.jpg
# Iterating for File Name = 000000412613.jpg
# Iterating for File Name = 000000153822.jpg
# Iterating for File Name = 000000115502.jpg
# Iterating for File Name = 000000447439.jpg
# Iterating for File Name = 000000466775.jpg
# Iterating for File Name = 000000263679.jpg
# Iterating for File Name = 000000300930.jpg
# Iterating for File Name = 000000555495.jpg
# Iterating for File Name = 000000245384.jpg
# Iterating for File Name = 000000499266.jpg
# Iterating for File Name = 000000350631.jpg
# Iterating for File Name = 000000303342.jpg
# Iterating for File Name = 000000412873.jpg
# Iterating for File Name = 000000106636.jpg
# Iterating for File Name = 000000372464.jpg
# Iterating for File Name = 000000075786.jpg
# Iterating for File Name = 000000325015.jpg
# Iterating for File Name = 000000537424.jpg
# Iterating for File Name = 000000068295.jpg
# Iterating for File Name = 000000436203.jpg
# Iterating for File Name = 000000070566.jpg
# Iterating for File Name = 000000402199.jpg
# Iterating for File Name = 000000401196.jpg
# Iterating for File Name = 000000037548.jpg
# Iterating for File Name = 000000012326.jpg
# Iterating for File Name = 000000503595.jpg
# Iterating for File Name = 000000085187.jpg
# Iterating for File Name = 000000262191.jpg
# Iterating for File Name = 000000223872.jpg
# Iterating for File Name = 000000068290.jpg
# Iterating for File Name = 000000276244.jpg
# Iterating for File Name = 000000045356.jpg
# Iterating for File Name = 000000199339.jpg
# Iterating for File Name = 000000355767.jpg
# Iterating for File Name = 000000259186.jpg
# Iterating for File Name = 000000237344.jpg
# Iterating for File Name = 000000344909.jpg
# Iterating for File Name = 000000187902.jpg
# Iterating for File Name = 000000571920.jpg
# Iterating for File Name = 000000347648.jpg
# Iterating for File Name = 000000128058.jpg
# Iterating for File Name = 000000412835.jpg
# Iterating for File Name = 000000382361.jpg
# Iterating for File Name = 000000346614.jpg
# Iterating for File Name = 000000287044.jpg
# Iterating for File Name = 000000299712.jpg
# Iterating for File Name = 000000045173.jpg
# Iterating for File Name = 000000503943.jpg
# Iterating for File Name = 000000352802.jpg
# Iterating for File Name = 000000371871.jpg
# Iterating for File Name = 000000082118.jpg
# Iterating for File Name = 000000418270.jpg
# Iterating for File Name = 000000088603.jpg
# Iterating for File Name = 000000475957.jpg
# Iterating for File Name = 000000573087.jpg
# Iterating for File Name = 000000187902.jpg
# Iterating for File Name = 000000036765.jpg
# Iterating for File Name = 000000433774.jpg
# Iterating for File Name = 000000190794.jpg
# Iterating for File Name = 000000260223.jpg
# Iterating for File Name = 000000471785.jpg
# Iterating for File Name = 000000398616.jpg
# Iterating for File Name = 000000496693.jpg
# Iterating for File Name = 000000223573.jpg
# Iterating for File Name = 000000145956.jpg
# Iterating for File Name = 000000204432.jpg
# Iterating for File Name = 000000023004.jpg
# Iterating for File Name = 000000370210.jpg
# Iterating for File Name = 000000424464.jpg
# Iterating for File Name = 000000537513.jpg
# Iterating for File Name = 000000109588.jpg
# Iterating for File Name = 000000403432.jpg
# Iterating for File Name = 000000477658.jpg
# Iterating for File Name = 000000314265.jpg
# Iterating for File Name = 000000431167.jpg
# Iterating for File Name = 000000337585.jpg
# Iterating for File Name = 000000088605.jpg
# Iterating for File Name = 000000436636.jpg
# Iterating for File Name = 000000366688.jpg
# Iterating for File Name = 000000123862.jpg
# Iterating for File Name = 000000446815.jpg
# Iterating for File Name = 000000090432.jpg
# Iterating for File Name = 000000339634.jpg
# Iterating for File Name = 000000256742.jpg
# Iterating for File Name = 000000059230.jpg
# Iterating for File Name = 000000119093.jpg
# Iterating for File Name = 000000399957.jpg
# Iterating for File Name = 000000049143.jpg
# Iterating for File Name = 000000560992.jpg
# Iterating for File Name = 000000158015.jpg
# Iterating for File Name = 000000011576.jpg
# Iterating for File Name = 000000054733.jpg
# Iterating for File Name = 000000067162.jpg
# Iterating for File Name = 000000225675.jpg
# Iterating for File Name = 000000321874.jpg
# Iterating for File Name = 000000278306.jpg
# Iterating for File Name = 000000165431.jpg
# Iterating for File Name = 000000462880.jpg
# Iterating for File Name = 000000126798.jpg
# Iterating for File Name = 000000092064.jpg
# Iterating for File Name = 000000002498.jpg
# Iterating for File Name = 000000455716.jpg
# Iterating for File Name = 000000351818.jpg
# Iterating for File Name = 000000150669.jpg
# Iterating for File Name = 000000030187.jpg
# Iterating for File Name = 000000020629.jpg
# Iterating for File Name = 000000176720.jpg
# Iterating for File Name = 000000302375.jpg
# Iterating for File Name = 000000210024.jpg
# Iterating for File Name = 000000196842.jpg
# Iterating for File Name = 000000030775.jpg
# Iterating for File Name = 000000171729.jpg
# Iterating for File Name = 000000281227.jpg
# Iterating for File Name = 000000161356.jpg
# Iterating for File Name = 000000239771.jpg
# Iterating for File Name = 000000082805.jpg
# Iterating for File Name = 000000075027.jpg
# Iterating for File Name = 000000290693.jpg
# Iterating for File Name = 000000308630.jpg
# Iterating for File Name = 000000436972.jpg
# Iterating for File Name = 000000224647.jpg
# Iterating for File Name = 000000051571.jpg
# Iterating for File Name = 000000315165.jpg
# Iterating for File Name = 000000525971.jpg
# Iterating for File Name = 000000554582.jpg
# Iterating for File Name = 000000133869.jpg
# Iterating for File Name = 000000381014.jpg
# Iterating for File Name = 000000515642.jpg
# Iterating for File Name = 000000356817.jpg
# Iterating for File Name = 000000363541.jpg
# Iterating for File Name = 000000060690.jpg
# Iterating for File Name = 000000543588.jpg
# Iterating for File Name = 000000528621.jpg
# Iterating for File Name = 000000074407.jpg
# Iterating for File Name = 000000059024.jpg
# Iterating for File Name = 000000250054.jpg
# Iterating for File Name = 000000161451.jpg
# Iterating for File Name = 000000151235.jpg
# Iterating for File Name = 000000386277.jpg
# Iterating for File Name = 000000415232.jpg
# Iterating for File Name = 000000273537.jpg
# Iterating for File Name = 000000200638.jpg
# Iterating for File Name = 000000369567.jpg
# Iterating for File Name = 000000163599.jpg
# Iterating for File Name = 000000202843.jpg
# Iterating for File Name = 000000203214.jpg
# Iterating for File Name = 000000278463.jpg
# Iterating for File Name = 000000225539.jpg
# Iterating for File Name = 000000049473.jpg
# Iterating for File Name = 000000386210.jpg
# Iterating for File Name = 000000260618.jpg
# Iterating for File Name = 000000278963.jpg
# Iterating for File Name = 000000072428.jpg
# Iterating for File Name = 000000246246.jpg
# Iterating for File Name = 000000017018.jpg
# Iterating for File Name = 000000071090.jpg
# Iterating for File Name = 000000450359.jpg
# Iterating for File Name = 000000223755.jpg
# Iterating for File Name = 000000296634.jpg
# Iterating for File Name = 000000266914.jpg
# Iterating for File Name = 000000430193.jpg
# Iterating for File Name = 000000179544.jpg
# Iterating for File Name = 000000004546.jpg
# Iterating for File Name = 000000465045.jpg
# Iterating for File Name = 000000421134.jpg
# Iterating for File Name = 000000063857.jpg
# Iterating for File Name = 000000264828.jpg
# Iterating for File Name = 000000572467.jpg
# Iterating for File Name = 000000242422.jpg
# Iterating for File Name = 000000014892.jpg
# Iterating for File Name = 000000177339.jpg
# Iterating for File Name = 000000052790.jpg
# Iterating for File Name = 000000121690.jpg
# Iterating for File Name = 000000041839.jpg
# Iterating for File Name = 000000055966.jpg
# Iterating for File Name = 000000349410.jpg
# Iterating for File Name = 000000335709.jpg
# Iterating for File Name = 000000452803.jpg
# Iterating for File Name = 000000295398.jpg
# Iterating for File Name = 000000234357.jpg
# Iterating for File Name = 000000411646.jpg
# Iterating for File Name = 000000546568.jpg
# Iterating for File Name = 000000025191.jpg
# Iterating for File Name = 000000110819.jpg
# Iterating for File Name = 000000124617.jpg
# Iterating for File Name = 000000061834.jpg
# Iterating for File Name = 000000290566.jpg
# Iterating for File Name = 000000091839.jpg
# Iterating for File Name = 000000226496.jpg
# Iterating for File Name = 000000064516.jpg
# Iterating for File Name = 000000023311.jpg
# Iterating for File Name = 000000543192.jpg
# Iterating for File Name = 000000513811.jpg
# Iterating for File Name = 000000513795.jpg
# Iterating for File Name = 000000067307.jpg
# Iterating for File Name = 000000429283.jpg
# Iterating for File Name = 000000246549.jpg
# Iterating for File Name = 000000052575.jpg
# Iterating for File Name = 000000360698.jpg
# Iterating for File Name = 000000442181.jpg
# Iterating for File Name = 000000095854.jpg
# Iterating for File Name = 000000049625.jpg
# Iterating for File Name = 000000192594.jpg
# Iterating for File Name = 000000157370.jpg
# Iterating for File Name = 000000498555.jpg
# Iterating for File Name = 000000064139.jpg
# Iterating for File Name = 000000019375.jpg
# Iterating for File Name = 000000462105.jpg
# Iterating for File Name = 000000169023.jpg
# Iterating for File Name = 000000453354.jpg
# Iterating for File Name = 000000192796.jpg
# Iterating for File Name = 000000187111.jpg
# Iterating for File Name = 000000182658.jpg
# Iterating for File Name = 000000114246.jpg
# Iterating for File Name = 000000296283.jpg
# Iterating for File Name = 000000228953.jpg
# Iterating for File Name = 000000556374.jpg
# Iterating for File Name = 000000313218.jpg
# Iterating for File Name = 000000445216.jpg
# Iterating for File Name = 000000324032.jpg
# Iterating for File Name = 000000389184.jpg
# Iterating for File Name = 000000411327.jpg
# Iterating for File Name = 000000290412.jpg
# Iterating for File Name = 000000339336.jpg
# Iterating for File Name = 000000541029.jpg
# Iterating for File Name = 000000227048.jpg
# Iterating for File Name = 000000054011.jpg
# Iterating for File Name = 000000404990.jpg
# Iterating for File Name = 000000557200.jpg
# Iterating for File Name = 000000142999.jpg
# Iterating for File Name = 000000034234.jpg
# Iterating for File Name = 000000192322.jpg
# Iterating for File Name = 000000138086.jpg
# Iterating for File Name = 000000038017.jpg
# Iterating for File Name = 000000120541.jpg
# Iterating for File Name = 000000041570.jpg
# Iterating for File Name = 000000073669.jpg
# Iterating for File Name = 000000155571.jpg
# Iterating for File Name = 000000161019.jpg
# Iterating for File Name = 000000000143.jpg
# Iterating for File Name = 000000389103.jpg
# Iterating for File Name = 000000261670.jpg
# Iterating for File Name = 000000143559.jpg
# Iterating for File Name = 000000058253.jpg
# Iterating for File Name = 000000038572.jpg
# Iterating for File Name = 000000515296.jpg
# Iterating for File Name = 000000193121.jpg
# Iterating for File Name = 000000500565.jpg
# Iterating for File Name = 000000074446.jpg
# Iterating for File Name = 000000402143.jpg
# Iterating for File Name = 000000310175.jpg
# Iterating for File Name = 000000054961.jpg
# Iterating for File Name = 000000020398.jpg
# Iterating for File Name = 000000151211.jpg
# Iterating for File Name = 000000219313.jpg
# Iterating for File Name = 000000458762.jpg
# Iterating for File Name = 000000518638.jpg
# Iterating for File Name = 000000381837.jpg
# Iterating for File Name = 000000073139.jpg
# Iterating for File Name = 000000232165.jpg
# Iterating for File Name = 000000534702.jpg
# Iterating for File Name = 000000206858.jpg
# Iterating for File Name = 000000480575.jpg
# Iterating for File Name = 000000205461.jpg
# Iterating for File Name = 000000549932.jpg
# Iterating for File Name = 000000405368.jpg
# Iterating for File Name = 000000185759.jpg
# Iterating for File Name = 000000266334.jpg
# Iterating for File Name = 000000461130.jpg
# Iterating for File Name = 000000097479.jpg
# Iterating for File Name = 000000043795.jpg
# Iterating for File Name = 000000067779.jpg
# Iterating for File Name = 000000138911.jpg
# Iterating for File Name = 000000231379.jpg
# Iterating for File Name = 000000248980.jpg
# Iterating for File Name = 000000267126.jpg
# Iterating for File Name = 000000351598.jpg
# Iterating for File Name = 000000301443.jpg
# Iterating for File Name = 000000018089.jpg
# Iterating for File Name = 000000455716.jpg
# Iterating for File Name = 000000392111.jpg
# Iterating for File Name = 000000156375.jpg
# Iterating for File Name = 000000424542.jpg
# Iterating for File Name = 000000408805.jpg
# Iterating for File Name = 000000197888.jpg
# Iterating for File Name = 000000387903.jpg
# Iterating for File Name = 000000245337.jpg
# Iterating for File Name = 000000177899.jpg
# Iterating for File Name = 000000102096.jpg
# Iterating for File Name = 000000372759.jpg
# Iterating for File Name = 000000413615.jpg
# Iterating for File Name = 000000499202.jpg
# Iterating for File Name = 000000208618.jpg
# Iterating for File Name = 000000201886.jpg
# Iterating for File Name = 000000365034.jpg
# Iterating for File Name = 000000008686.jpg
# Iterating for File Name = 000000538465.jpg
# Iterating for File Name = 000000364159.jpg
# Iterating for File Name = 000000196521.jpg
# Iterating for File Name = 000000052151.jpg
# Iterating for File Name = 000000506052.jpg
# Iterating for File Name = 000000071984.jpg
# Iterating for File Name = 000000530772.jpg
# Iterating for File Name = 000000124122.jpg
# Iterating for File Name = 000000472954.jpg
# Iterating for File Name = 000000453926.jpg
# Iterating for File Name = 000000066717.jpg
# Iterating for File Name = 000000138234.jpg
# Iterating for File Name = 000000029716.jpg
# Iterating for File Name = 000000439859.jpg
# Iterating for File Name = 000000154924.jpg
# Iterating for File Name = 000000083670.jpg
# Iterating for File Name = 000000353915.jpg
# Iterating for File Name = 000000330050.jpg
# Iterating for File Name = 000000483311.jpg
# Iterating for File Name = 000000567416.jpg
# Iterating for File Name = 000000091808.jpg
# Iterating for File Name = 000000093764.jpg
# Iterating for File Name = 000000224916.jpg
# Iterating for File Name = 000000193504.jpg
# Iterating for File Name = 000000267774.jpg
# Iterating for File Name = 000000236262.jpg
# Iterating for File Name = 000000171665.jpg
# Iterating for File Name = 000000249128.jpg
# Iterating for File Name = 000000382890.jpg
# Iterating for File Name = 000000268548.jpg
# Iterating for File Name = 000000387672.jpg
# Iterating for File Name = 000000490361.jpg
# Iterating for File Name = 000000147404.jpg
# Iterating for File Name = 000000342849.jpg
# Iterating for File Name = 000000140776.jpg
# Iterating for File Name = 000000283912.jpg
# Iterating for File Name = 000000184822.jpg
# Iterating for File Name = 000000230598.jpg
# Iterating for File Name = 000000306549.jpg
# Iterating for File Name = 000000308139.jpg
# Iterating for File Name = 000000199632.jpg
# Iterating for File Name = 000000512764.jpg
# Iterating for File Name = 000000185437.jpg
# Iterating for File Name = 000000103008.jpg
# Iterating for File Name = 000000082157.jpg
# Iterating for File Name = 000000018250.jpg
# Iterating for File Name = 000000203976.jpg
# Iterating for File Name = 000000572991.jpg
# Iterating for File Name = 000000414482.jpg
# Iterating for File Name = 000000332724.jpg
# Iterating for File Name = 000000351876.jpg
# Iterating for File Name = 000000059821.jpg
# Iterating for File Name = 000000560489.jpg
# Iterating for File Name = 000000144273.jpg
# Iterating for File Name = 000000142378.jpg
# Iterating for File Name = 000000570013.jpg
# Iterating for File Name = 000000544481.jpg
# Iterating for File Name = 000000370986.jpg
# Iterating for File Name = 000000010222.jpg
# Iterating for File Name = 000000411142.jpg
# Iterating for File Name = 000000570263.jpg
# Iterating for File Name = 000000100157.jpg
# Iterating for File Name = 000000172158.jpg
# Iterating for File Name = 000000025508.jpg
# Iterating for File Name = 000000316448.jpg
# Iterating for File Name = 000000360447.jpg
# Iterating for File Name = 000000441203.jpg
# Iterating for File Name = 000000071724.jpg
# Iterating for File Name = 000000022178.jpg
# Iterating for File Name = 000000206318.jpg
# Iterating for File Name = 000000048209.jpg
# Iterating for File Name = 000000399122.jpg
# Iterating for File Name = 000000135626.jpg
# Iterating for File Name = 000000107907.jpg
# Iterating for File Name = 000000237611.jpg
# Iterating for File Name = 000000078663.jpg
# Iterating for File Name = 000000571906.jpg
# Iterating for File Name = 000000437138.jpg
# Iterating for File Name = 000000400822.jpg
# Iterating for File Name = 000000228388.jpg
# Iterating for File Name = 000000149298.jpg
# Iterating for File Name = 000000088116.jpg
# Iterating for File Name = 000000142000.jpg
# Iterating for File Name = 000000302030.jpg
# Iterating for File Name = 000000340242.jpg
# Iterating for File Name = 000000486936.jpg
# Iterating for File Name = 000000426994.jpg
# Iterating for File Name = 000000203775.jpg
# Iterating for File Name = 000000107481.jpg
# Iterating for File Name = 000000373748.jpg
# Iterating for File Name = 000000545260.jpg
# Iterating for File Name = 000000299468.jpg
# Iterating for File Name = 000000559837.jpg
# Iterating for File Name = 000000393928.jpg
# Iterating for File Name = 000000556524.jpg
# Iterating for File Name = 000000084049.jpg
# Iterating for File Name = 000000073864.jpg
# Iterating for File Name = 000000271338.jpg
# Iterating for File Name = 000000410236.jpg
# Iterating for File Name = 000000028115.jpg
# Iterating for File Name = 000000381228.jpg
# Iterating for File Name = 000000330187.jpg
# Iterating for File Name = 000000149253.jpg
# Iterating for File Name = 000000386062.jpg
# Iterating for File Name = 000000178410.jpg
# Iterating for File Name = 000000454731.jpg
# Iterating for File Name = 000000168451.jpg
# Iterating for File Name = 000000376490.jpg
# Iterating for File Name = 000000099230.jpg
# Iterating for File Name = 000000311099.jpg
# Iterating for File Name = 000000167375.jpg
# Iterating for File Name = 000000254082.jpg
# Iterating for File Name = 000000084391.jpg
# Iterating for File Name = 000000388057.jpg
# Iterating for File Name = 000000417430.jpg
# Iterating for File Name = 000000066798.jpg
# Iterating for File Name = 000000213538.jpg
# Iterating for File Name = 000000003692.jpg
# Iterating for File Name = 000000197585.jpg
# Iterating for File Name = 000000284885.jpg
# Iterating for File Name = 000000528355.jpg
# Iterating for File Name = 000000496166.jpg
# Iterating for File Name = 000000332333.jpg
# Iterating for File Name = 000000250920.jpg
# Iterating for File Name = 000000277390.jpg
# Iterating for File Name = 000000397792.jpg
# Iterating for File Name = 000000480741.jpg
# Iterating for File Name = 000000203798.jpg
# Iterating for File Name = 000000337994.jpg
# Iterating for File Name = 000000182202.jpg
# Iterating for File Name = 000000511472.jpg
# Iterating for File Name = 000000011076.jpg
# Iterating for File Name = 000000543872.jpg
# Iterating for File Name = 000000488086.jpg
# Iterating for File Name = 000000452931.jpg
# Iterating for File Name = 000000539694.jpg
# Iterating for File Name = 000000472228.jpg
# Iterating for File Name = 000000253873.jpg
# Iterating for File Name = 000000079610.jpg
# Iterating for File Name = 000000581415.jpg
# Iterating for File Name = 000000370030.jpg
# Iterating for File Name = 000000030815.jpg
# Iterating for File Name = 000000258399.jpg
# Iterating for File Name = 000000057545.jpg
# Iterating for File Name = 000000121562.jpg
# Iterating for File Name = 000000025115.jpg
# Iterating for File Name = 000000302077.jpg
# Iterating for File Name = 000000482454.jpg
# Iterating for File Name = 000000119290.jpg
# Iterating for File Name = 000000304047.jpg
# Iterating for File Name = 000000484165.jpg
# Iterating for File Name = 000000195748.jpg
# Iterating for File Name = 000000152963.jpg
# Iterating for File Name = 000000266520.jpg
# Iterating for File Name = 000000351422.jpg
# Iterating for File Name = 000000463970.jpg
# Iterating for File Name = 000000236599.jpg
# Iterating for File Name = 000000230936.jpg
# Iterating for File Name = 000000371484.jpg
# Iterating for File Name = 000000511716.jpg
# Iterating for File Name = 000000127316.jpg
# Iterating for File Name = 000000301261.jpg
# Iterating for File Name = 000000554541.jpg
# Iterating for File Name = 000000216322.jpg
# Iterating for File Name = 000000535464.jpg
# Iterating for File Name = 000000157215.jpg
# Iterating for File Name = 000000486825.jpg
# Iterating for File Name = 000000328113.jpg
# Iterating for File Name = 000000457631.jpg
# Iterating for File Name = 000000370709.jpg
# Iterating for File Name = 000000494759.jpg
# Iterating for File Name = 000000478132.jpg
# Iterating for File Name = 000000238685.jpg
# Iterating for File Name = 000000289248.jpg
# Iterating for File Name = 000000290189.jpg
# Iterating for File Name = 000000015517.jpg
# Iterating for File Name = 000000162770.jpg
# Iterating for File Name = 000000465806.jpg
# Iterating for File Name = 000000149199.jpg
# Iterating for File Name = 000000144272.jpg
# Iterating for File Name = 000000479292.jpg
# Iterating for File Name = 000000135846.jpg
# Iterating for File Name = 000000415776.jpg
# Iterating for File Name = 000000001667.jpg
# Iterating for File Name = 000000084391.jpg
# Iterating for File Name = 000000081680.jpg
# Iterating for File Name = 000000452947.jpg
# Iterating for File Name = 000000172475.jpg
# Iterating for File Name = 000000094118.jpg
# Iterating for File Name = 000000267205.jpg
# Iterating for File Name = 000000012377.jpg
# Iterating for File Name = 000000433911.jpg
# Iterating for File Name = 000000306620.jpg
# Iterating for File Name = 000000013574.jpg
# Iterating for File Name = 000000012678.jpg
# Iterating for File Name = 000000239427.jpg
# Iterating for File Name = 000000464522.jpg
# Iterating for File Name = 000000405695.jpg
# Iterating for File Name = 000000360919.jpg
# Iterating for File Name = 000000581557.jpg
# Iterating for File Name = 000000072717.jpg
# Iterating for File Name = 000000215410.jpg
# Iterating for File Name = 000000094334.jpg
# Iterating for File Name = 000000182402.jpg
# Iterating for File Name = 000000352877.jpg
# Iterating for File Name = 000000298641.jpg
# Iterating for File Name = 000000181267.jpg
# Iterating for File Name = 000000239670.jpg
# Iterating for File Name = 000000062772.jpg
# Iterating for File Name = 000000108021.jpg
# Iterating for File Name = 000000489374.jpg
# Iterating for File Name = 000000029030.jpg
# Iterating for File Name = 000000449990.jpg
# Iterating for File Name = 000000284623.jpg
# Iterating for File Name = 000000311706.jpg
# Iterating for File Name = 000000343820.jpg
# Iterating for File Name = 000000193690.jpg
# Iterating for File Name = 000000393268.jpg
# Iterating for File Name = 000000529166.jpg
# Iterating for File Name = 000000080590.jpg
# Iterating for File Name = 000000091839.jpg
# Iterating for File Name = 000000325991.jpg
# Iterating for File Name = 000000158965.jpg
# Iterating for File Name = 000000317193.jpg
# Iterating for File Name = 000000494345.jpg
# Iterating for File Name = 000000284351.jpg
# Iterating for File Name = 000000340282.jpg
# Iterating for File Name = 000000021310.jpg
# Iterating for File Name = 000000417355.jpg
# Iterating for File Name = 000000464526.jpg
# Iterating for File Name = 000000393282.jpg
# Iterating for File Name = 000000450776.jpg
# Iterating for File Name = 000000570521.jpg
# Iterating for File Name = 000000212525.jpg
# Iterating for File Name = 000000223622.jpg
# Iterating for File Name = 000000125755.jpg
# Iterating for File Name = 000000086065.jpg
# Iterating for File Name = 000000376740.jpg
# Iterating for File Name = 000000496855.jpg
# Iterating for File Name = 000000413600.jpg
# Iterating for File Name = 000000191270.jpg
# Iterating for File Name = 000000407822.jpg
# Iterating for File Name = 000000375788.jpg
# Iterating for File Name = 000000245523.jpg
# Iterating for File Name = 000000427655.jpg
# Iterating for File Name = 000000132646.jpg
# Iterating for File Name = 000000516733.jpg
# Iterating for File Name = 000000205055.jpg
# Iterating for File Name = 000000546361.jpg
# Iterating for File Name = 000000084064.jpg
# Iterating for File Name = 000000313525.jpg
# Iterating for File Name = 000000174363.jpg
# Iterating for File Name = 000000032093.jpg
# Iterating for File Name = 000000183585.jpg
# Iterating for File Name = 000000128428.jpg
# Iterating for File Name = 000000135171.jpg
# Iterating for File Name = 000000036023.jpg
# Iterating for File Name = 000000297314.jpg
# Iterating for File Name = 000000321071.jpg
# Iterating for File Name = 000000331223.jpg
# Iterating for File Name = 000000308524.jpg
# Iterating for File Name = 000000124732.jpg
# Iterating for File Name = 000000145645.jpg
# Iterating for File Name = 000000356330.jpg
# Iterating for File Name = 000000318564.jpg
# Iterating for File Name = 000000126755.jpg
# Iterating for File Name = 000000574665.jpg
# Iterating for File Name = 000000457184.jpg
# Iterating for File Name = 000000076627.jpg
# Iterating for File Name = 000000064799.jpg
# Iterating for File Name = 000000357728.jpg
# Iterating for File Name = 000000361073.jpg
# Iterating for File Name = 000000122962.jpg
# Iterating for File Name = 000000249608.jpg
# Iterating for File Name = 000000196876.jpg
# Iterating for File Name = 000000400453.jpg
# Iterating for File Name = 000000431077.jpg
# Iterating for File Name = 000000189015.jpg
# Iterating for File Name = 000000154584.jpg
# Iterating for File Name = 000000461787.jpg
# Iterating for File Name = 000000330727.jpg
# Iterating for File Name = 000000490626.jpg
# Iterating for File Name = 000000474439.jpg
# Iterating for File Name = 000000008176.jpg
# Iterating for File Name = 000000242007.jpg
# Iterating for File Name = 000000318491.jpg
# Iterating for File Name = 000000504606.jpg
# Iterating for File Name = 000000507854.jpg
# Iterating for File Name = 000000531033.jpg
# Iterating for File Name = 000000354718.jpg
# Iterating for File Name = 000000491992.jpg
# Iterating for File Name = 000000290361.jpg
# Iterating for File Name = 000000575005.jpg
# Iterating for File Name = 000000047116.jpg
# Iterating for File Name = 000000278541.jpg
# Iterating for File Name = 000000310213.jpg
# Iterating for File Name = 000000116272.jpg
# Iterating for File Name = 000000289591.jpg
# Iterating for File Name = 000000167901.jpg
# Iterating for File Name = 000000319126.jpg
# Iterating for File Name = 000000052161.jpg
# Iterating for File Name = 000000082945.jpg
# Iterating for File Name = 000000083369.jpg
# Iterating for File Name = 000000426591.jpg
# Iterating for File Name = 000000214853.jpg
# Iterating for File Name = 000000001164.jpg
# Iterating for File Name = 000000529877.jpg
# Iterating for File Name = 000000540384.jpg
# Iterating for File Name = 000000369568.jpg
# Iterating for File Name = 000000152751.jpg
# Iterating for File Name = 000000036277.jpg
# Iterating for File Name = 000000324338.jpg
# Iterating for File Name = 000000022041.jpg
# Iterating for File Name = 000000382527.jpg
# Iterating for File Name = 000000151787.jpg
# Iterating for File Name = 000000573968.jpg
# Iterating for File Name = 000000385205.jpg
# Iterating for File Name = 000000215481.jpg
# Iterating for File Name = 000000182658.jpg
# Iterating for File Name = 000000115928.jpg
# Iterating for File Name = 000000418523.jpg
# Iterating for File Name = 000000123366.jpg
# Iterating for File Name = 000000573277.jpg
# Iterating for File Name = 000000435102.jpg
# Iterating for File Name = 000000519374.jpg
# Iterating for File Name = 000000010265.jpg
# Iterating for File Name = 000000127406.jpg
# Iterating for File Name = 000000263388.jpg
# Iterating for File Name = 000000031482.jpg
# Iterating for File Name = 000000199940.jpg
# Iterating for File Name = 000000509914.jpg
# Iterating for File Name = 000000225183.jpg
# Iterating for File Name = 000000351473.jpg
# Iterating for File Name = 000000192594.jpg
# Iterating for File Name = 000000073574.jpg
# Iterating for File Name = 000000295862.jpg
# Iterating for File Name = 000000371824.jpg
# Iterating for File Name = 000000288580.jpg
# Iterating for File Name = 000000356953.jpg
# Iterating for File Name = 000000058329.jpg
# Iterating for File Name = 000000164863.jpg
# Iterating for File Name = 000000558808.jpg
# Iterating for File Name = 000000006057.jpg
# Iterating for File Name = 000000389404.jpg
# Iterating for File Name = 000000297764.jpg
# Iterating for File Name = 000000161970.jpg
# Iterating for File Name = 000000433156.jpg
# Iterating for File Name = 000000298219.jpg
# Iterating for File Name = 000000059968.jpg
# Iterating for File Name = 000000378764.jpg
# Iterating for File Name = 000000033216.jpg
# Iterating for File Name = 000000543869.jpg
# Iterating for File Name = 000000000581.jpg
# Iterating for File Name = 000000313914.jpg
# Iterating for File Name = 000000090520.jpg
# Iterating for File Name = 000000508053.jpg
# Iterating for File Name = 000000396159.jpg
# Iterating for File Name = 000000556954.jpg
# Iterating for File Name = 000000155751.jpg
# Iterating for File Name = 000000540922.jpg
# Iterating for File Name = 000000094000.jpg
# Iterating for File Name = 000000465566.jpg
# Iterating for File Name = 000000255786.jpg
# Iterating for File Name = 000000576518.jpg
# Iterating for File Name = 000000248118.jpg
# Iterating for File Name = 000000162813.jpg
# Iterating for File Name = 000000419680.jpg
# Iterating for File Name = 000000102655.jpg
# Iterating for File Name = 000000483897.jpg
# Iterating for File Name = 000000436315.jpg
# Iterating for File Name = 000000140908.jpg
# Iterating for File Name = 000000071440.jpg
# Iterating for File Name = 000000306412.jpg
# Iterating for File Name = 000000285660.jpg
# Iterating for File Name = 000000516212.jpg
# Iterating for File Name = 000000268569.jpg
# Iterating for File Name = 000000095062.jpg
# Iterating for File Name = 000000552824.jpg
# Iterating for File Name = 000000401528.jpg
# Iterating for File Name = 000000547383.jpg
# Iterating for File Name = 000000379067.jpg
# Iterating for File Name = 000000307773.jpg
# Iterating for File Name = 000000318385.jpg
# Iterating for File Name = 000000450313.jpg
# Iterating for File Name = 000000568405.jpg
# Iterating for File Name = 000000016827.jpg
# Iterating for File Name = 000000454129.jpg
# Iterating for File Name = 000000447484.jpg
# Iterating for File Name = 000000169885.jpg
# Iterating for File Name = 000000203406.jpg
# Iterating for File Name = 000000324901.jpg
# Iterating for File Name = 000000030526.jpg
# Iterating for File Name = 000000160614.jpg
# Iterating for File Name = 000000177948.jpg
# Iterating for File Name = 000000064622.jpg
# Iterating for File Name = 000000567836.jpg
# Iterating for File Name = 000000127839.jpg
# Iterating for File Name = 000000478090.jpg
# Iterating for File Name = 000000254290.jpg
# Iterating for File Name = 000000030356.jpg
# Iterating for File Name = 000000152474.jpg
# Iterating for File Name = 000000148099.jpg
# Iterating for File Name = 000000114657.jpg
# Iterating for File Name = 000000374561.jpg
# Iterating for File Name = 000000444703.jpg
# Iterating for File Name = 000000530630.jpg
# Iterating for File Name = 000000106875.jpg
# Iterating for File Name = 000000428477.jpg
# Iterating for File Name = 000000544983.jpg
# Iterating for File Name = 000000308605.jpg
# Iterating for File Name = 000000505768.jpg
# Iterating for File Name = 000000381529.jpg
# Iterating for File Name = 000000191717.jpg
# Iterating for File Name = 000000341989.jpg
# Iterating for File Name = 000000236228.jpg
# Iterating for File Name = 000000406709.jpg
# Iterating for File Name = 000000390817.jpg
# Iterating for File Name = 000000075682.jpg
# Iterating for File Name = 000000388468.jpg
# Iterating for File Name = 000000181949.jpg
# Iterating for File Name = 000000401838.jpg
# Iterating for File Name = 000000372353.jpg
# Iterating for File Name = 000000286042.jpg
# Iterating for File Name = 000000205668.jpg
# Iterating for File Name = 000000190007.jpg
# Iterating for File Name = 000000421360.jpg
# Iterating for File Name = 000000188388.jpg
# Iterating for File Name = 000000274959.jpg
# Iterating for File Name = 000000364343.jpg
# Iterating for File Name = 000000151956.jpg
# Iterating for File Name = 000000524068.jpg
# Iterating for File Name = 000000483311.jpg
# Iterating for File Name = 000000515982.jpg
# Iterating for File Name = 000000231052.jpg
# Iterating for File Name = 000000014453.jpg
# Iterating for File Name = 000000460364.jpg
# Iterating for File Name = 000000333182.jpg
# Iterating for File Name = 000000525039.jpg
# Iterating for File Name = 000000307174.jpg
# Iterating for File Name = 000000123330.jpg
# Iterating for File Name = 000000249643.jpg
# Iterating for File Name = 000000580986.jpg
# Iterating for File Name = 000000385188.jpg
# Iterating for File Name = 000000572850.jpg
# Iterating for File Name = 000000070307.jpg
# Iterating for File Name = 000000149755.jpg
# Iterating for File Name = 000000347885.jpg
# Iterating for File Name = 000000402378.jpg
# Iterating for File Name = 000000107571.jpg
# Iterating for File Name = 000000130432.jpg
# Iterating for File Name = 000000168978.jpg
# Iterating for File Name = 000000196777.jpg
# Iterating for File Name = 000000082372.jpg
# Iterating for File Name = 000000516948.jpg
# Iterating for File Name = 000000139248.jpg
# Iterating for File Name = 000000387264.jpg
# Iterating for File Name = 000000049891.jpg
# Iterating for File Name = 000000369789.jpg
# Iterating for File Name = 000000201939.jpg
# Iterating for File Name = 000000027810.jpg
# Iterating for File Name = 000000478731.jpg
# Iterating for File Name = 000000160844.jpg
# Iterating for File Name = 000000428843.jpg
# Iterating for File Name = 000000368821.jpg
# Iterating for File Name = 000000505637.jpg
# Iterating for File Name = 000000518075.jpg
# Iterating for File Name = 000000383967.jpg
# Iterating for File Name = 000000285683.jpg
# Iterating for File Name = 000000416125.jpg
# Iterating for File Name = 000000281634.jpg
# Iterating for File Name = 000000534593.jpg
# Iterating for File Name = 000000543422.jpg
# Iterating for File Name = 000000096712.jpg
# Iterating for File Name = 000000223241.jpg
# Iterating for File Name = 000000473420.jpg
# Iterating for File Name = 000000160402.jpg
# Iterating for File Name = 000000181574.jpg
# Iterating for File Name = 000000321097.jpg
# Iterating for File Name = 000000510047.jpg
# Iterating for File Name = 000000023570.jpg
# Iterating for File Name = 000000334616.jpg
# Iterating for File Name = 000000253480.jpg
# Iterating for File Name = 000000251062.jpg
# Iterating for File Name = 000000188757.jpg
# Iterating for File Name = 000000181133.jpg
# Iterating for File Name = 000000420765.jpg
# Iterating for File Name = 000000385190.jpg
# Iterating for File Name = 000000015994.jpg
# Iterating for File Name = 000000035030.jpg
# Iterating for File Name = 000000453328.jpg
# Iterating for File Name = 000000077432.jpg
# Iterating for File Name = 000000137984.jpg
# Iterating for File Name = 000000516345.jpg
# Iterating for File Name = 000000280211.jpg
# Iterating for File Name = 000000058765.jpg
# Iterating for File Name = 000000065986.jpg
# Iterating for File Name = 000000168134.jpg
# Iterating for File Name = 000000169800.jpg
# Iterating for File Name = 000000129753.jpg
# Iterating for File Name = 000000487528.jpg
# Iterating for File Name = 000000521199.jpg
# Iterating for File Name = 000000103710.jpg
# Iterating for File Name = 000000222654.jpg
# Iterating for File Name = 000000482223.jpg
# Iterating for File Name = 000000091858.jpg
# Iterating for File Name = 000000561033.jpg
# Iterating for File Name = 000000226761.jpg
# Iterating for File Name = 000000345543.jpg
# Iterating for File Name = 000000013995.jpg
# Iterating for File Name = 000000378089.jpg
# Iterating for File Name = 000000536879.jpg
# Iterating for File Name = 000000472103.jpg
# Iterating for File Name = 000000007952.jpg
# Iterating for File Name = 000000206791.jpg
# Iterating for File Name = 000000276610.jpg
# Iterating for File Name = 000000569384.jpg
# Iterating for File Name = 000000359253.jpg
# Iterating for File Name = 000000331134.jpg
# Iterating for File Name = 000000474506.jpg
# Iterating for File Name = 000000135627.jpg
# Iterating for File Name = 000000436698.jpg
# Iterating for File Name = 000000461815.jpg
# Iterating for File Name = 000000260765.jpg
# Iterating for File Name = 000000339793.jpg
# Iterating for File Name = 000000103865.jpg
# Iterating for File Name = 000000151778.jpg
# Iterating for File Name = 000000005324.jpg
# Iterating for File Name = 000000313465.jpg
# Iterating for File Name = 000000549410.jpg
# Iterating for File Name = 000000541528.jpg
# Iterating for File Name = 000000232076.jpg
# Iterating for File Name = 000000018688.jpg
# Iterating for File Name = 000000311448.jpg
# Iterating for File Name = 000000096046.jpg
# Iterating for File Name = 000000451623.jpg
# Iterating for File Name = 000000330699.jpg
# Iterating for File Name = 000000226899.jpg
# Iterating for File Name = 000000519491.jpg
# Iterating for File Name = 000000490022.jpg
# Iterating for File Name = 000000356809.jpg
# Iterating for File Name = 000000309881.jpg
# Iterating for File Name = 000000076462.jpg
# Iterating for File Name = 000000458918.jpg
# Iterating for File Name = 000000203478.jpg
# Iterating for File Name = 000000283772.jpg
# Iterating for File Name = 000000278962.jpg
# Iterating for File Name = 000000319996.jpg
# Iterating for File Name = 000000042622.jpg
# Iterating for File Name = 000000019929.jpg
# Iterating for File Name = 000000116927.jpg
# Iterating for File Name = 000000187157.jpg
# Iterating for File Name = 000000262329.jpg
# Iterating for File Name = 000000006608.jpg
# Iterating for File Name = 000000386236.jpg
# Iterating for File Name = 000000234416.jpg
# Iterating for File Name = 000000151915.jpg
# Iterating for File Name = 000000350214.jpg
# Iterating for File Name = 000000019881.jpg
# Iterating for File Name = 000000372165.jpg
# Iterating for File Name = 000000470062.jpg
# Iterating for File Name = 000000456827.jpg
# Iterating for File Name = 000000139124.jpg
# Iterating for File Name = 000000369831.jpg
# Iterating for File Name = 000000016950.jpg
# Iterating for File Name = 000000250506.jpg
# Iterating for File Name = 000000323979.jpg
# Iterating for File Name = 000000460289.jpg
# Iterating for File Name = 000000513577.jpg
# Iterating for File Name = 000000104543.jpg
# Iterating for File Name = 000000209200.jpg
# Iterating for File Name = 000000258761.jpg
# Iterating for File Name = 000000161796.jpg
# Iterating for File Name = 000000071603.jpg
# Iterating for File Name = 000000177935.jpg
# Iterating for File Name = 000000468818.jpg
# Iterating for File Name = 000000500814.jpg
# Iterating for File Name = 000000242193.jpg
# Iterating for File Name = 000000492114.jpg
# Iterating for File Name = 000000459248.jpg
# Iterating for File Name = 000000470632.jpg
# Iterating for File Name = 000000292493.jpg
# Iterating for File Name = 000000461802.jpg
# Iterating for File Name = 000000324261.jpg
# Iterating for File Name = 000000056585.jpg
# Iterating for File Name = 000000302960.jpg
# Iterating for File Name = 000000154279.jpg
# Iterating for File Name = 000000400726.jpg
# Iterating for File Name = 000000390000.jpg
# Iterating for File Name = 000000381251.jpg
# Iterating for File Name = 000000040181.jpg
# Iterating for File Name = 000000269311.jpg
# Iterating for File Name = 000000138547.jpg
# Iterating for File Name = 000000562253.jpg
# Iterating for File Name = 000000491084.jpg
# Iterating for File Name = 000000550481.jpg
# Iterating for File Name = 000000195724.jpg
# Iterating for File Name = 000000155883.jpg
# Iterating for File Name = 000000054850.jpg
# Iterating for File Name = 000000080065.jpg
# Iterating for File Name = 000000473153.jpg
# Iterating for File Name = 000000139211.jpg
# Iterating for File Name = 000000521472.jpg
# Iterating for File Name = 000000499408.jpg
# Iterating for File Name = 000000434699.jpg
# Iterating for File Name = 000000537293.jpg
# Iterating for File Name = 000000516088.jpg
# Iterating for File Name = 000000161686.jpg
# Iterating for File Name = 000000480591.jpg
# Iterating for File Name = 000000362090.jpg
# Iterating for File Name = 000000350073.jpg
# Iterating for File Name = 000000135872.jpg
# Iterating for File Name = 000000292690.jpg
# Iterating for File Name = 000000549622.jpg
# Iterating for File Name = 000000427655.jpg
# Iterating for File Name = 000000546499.jpg
# Iterating for File Name = 000000405061.jpg
# Iterating for File Name = 000000121172.jpg
# Iterating for File Name = 000000004275.jpg
# Iterating for File Name = 000000523957.jpg
# Iterating for File Name = 000000291262.jpg
# Iterating for File Name = 000000419224.jpg
# ...
# Iterating for File Name = 000000414701.jpg
# Iterating for File Name = 000000024762.jpg
# Iterating for File Name = 000000471351.jpg
# Iterating for File Name = 000000576399.jpg
# Iterating for File Name = 000000455170.jpg
# Iterating for File Name = 000000148761.jpg
# Iterating for File Name = 000000292001.jpg
# Iterating for File Name = 000000389004.jpg
# Iterating for File Name = 000000106896.jpg
# Iterating for File Name = 000000118113.jpg
# Iterating for File Name = 000000038622.jpg
# Iterating for File Name = 000000112608.jpg
# Iterating for File Name = 000000551063.jpg
# Iterating for File Name = 000000552488.jpg
# Iterating for File Name = 000000069510.jpg
# Iterating for File Name = 000000031606.jpg
# Iterating for File Name = 000000032391.jpg
# Iterating for File Name = 000000312951.jpg
# Iterating for File Name = 000000564127.jpg
# Iterating for File Name = 000000174417.jpg
# Iterating for File Name = 000000550193.jpg
# Iterating for File Name = 000000280069.jpg
# Iterating for File Name = 000000403482.jpg
# Iterating for File Name = 000000468801.jpg
# Iterating for File Name = 000000056684.jpg
# Iterating for File Name = 000000459214.jpg
# Iterating for File Name = 000000548550.jpg
# Iterating for File Name = 000000509565.jpg
# Iterating for File Name = 000000441103.jpg
# Iterating for File Name = 000000095659.jpg
# Iterating for File Name = 000000462968.jpg
# Iterating for File Name = 000000219647.jpg
# Iterating for File Name = 000000304812.jpg
# Iterating for File Name = 000000472357.jpg
# Iterating for File Name = 000000171284.jpg
# Iterating for File Name = 000000091360.jpg
# Iterating for File Name = 000000121841.jpg
# Iterating for File Name = 000000340665.jpg
# Iterating for File Name = 000000353989.jpg
# Iterating for File Name = 000000013770.jpg
# Iterating for File Name = 000000026007.jpg
# Iterating for File Name = 000000329827.jpg
# Iterating for File Name = 000000557266.jpg
# Iterating for File Name = 000000253247.jpg
# Iterating for File Name = 000000078416.jpg
# Iterating for File Name = 000000555020.jpg
# Iterating for File Name = 000000300745.jpg
# Iterating for File Name = 000000372247.jpg
# Iterating for File Name = 000000355453.jpg
# Iterating for File Name = 000000380191.jpg
# Iterating for File Name = 000000503779.jpg
# Iterating for File Name = 000000155319.jpg
# Iterating for File Name = 000000387299.jpg
# Iterating for File Name = 000000044138.jpg
# Iterating for File Name = 000000281660.jpg
# Iterating for File Name = 000000180281.jpg
# Iterating for File Name = 000000381704.jpg
# Iterating for File Name = 000000002732.jpg
# Iterating for File Name = 000000487840.jpg
# Iterating for File Name = 000000463555.jpg
# Iterating for File Name = 000000083407.jpg
# Iterating for File Name = 000000276894.jpg
# Iterating for File Name = 000000180830.jpg
# Iterating for File Name = 000000417474.jpg
# Iterating for File Name = 000000217951.jpg
# Iterating for File Name = 000000376079.jpg
# Iterating for File Name = 000000301827.jpg
# Iterating for File Name = 000000290081.jpg
# Iterating for File Name = 000000443259.jpg
# Iterating for File Name = 000000189684.jpg
# Iterating for File Name = 000000021215.jpg
# Iterating for File Name = 000000102930.jpg
# Iterating for File Name = 000000236246.jpg
# Iterating for File Name = 000000359408.jpg
# Iterating for File Name = 000000535585.jpg
# Iterating for File Name = 000000347456.jpg
# Iterating for File Name = 000000432160.jpg
# Iterating for File Name = 000000290269.jpg
# Iterating for File Name = 000000155167.jpg
# Iterating for File Name = 000000538454.jpg
# Iterating for File Name = 000000105679.jpg
# Iterating for File Name = 000000275835.jpg
# Iterating for File Name = 000000419076.jpg
# Iterating for File Name = 000000015660.jpg
# Iterating for File Name = 000000241554.jpg
# Iterating for File Name = 000000407926.jpg
# Iterating for File Name = 000000524453.jpg
# Iterating for File Name = 000000275304.jpg
# Iterating for File Name = 000000048910.jpg
# Iterating for File Name = 000000476220.jpg
# Iterating for File Name = 000000188948.jpg
# Iterating for File Name = 000000154659.jpg
# Iterating for File Name = 000000316907.jpg
# Iterating for File Name = 000000411384.jpg
# Iterating for File Name = 000000539971.jpg
# Iterating for File Name = 000000434587.jpg
# Iterating for File Name = 000000440449.jpg
# Iterating for File Name = 000000392212.jpg
# Iterating for File Name = 000000540465.jpg
# Iterating for File Name = 000000220226.jpg
# Iterating for File Name = 000000442463.jpg
# Iterating for File Name = 000000243091.jpg
# Iterating for File Name = 000000002544.jpg
# Iterating for File Name = 000000348669.jpg
# Iterating for File Name = 000000291788.jpg
# Iterating for File Name = 000000132316.jpg
# Iterating for File Name = 000000388853.jpg
# Iterating for File Name = 000000356261.jpg
# Iterating for File Name = 000000055903.jpg
# Iterating for File Name = 000000245409.jpg
# Iterating for File Name = 000000084615.jpg
# Iterating for File Name = 000000044504.jpg
# Iterating for File Name = 000000014135.jpg
# Iterating for File Name = 000000245915.jpg
# Iterating for File Name = 000000333402.jpg
# Iterating for File Name = 000000201758.jpg
# Iterating for File Name = 000000396150.jpg
# Iterating for File Name = 000000553364.jpg
# Iterating for File Name = 000000508944.jpg
# Iterating for File Name = 000000143436.jpg
# Iterating for File Name = 000000444483.jpg
# Iterating for File Name = 000000482314.jpg
# Iterating for File Name = 000000316605.jpg
# Iterating for File Name = 000000063950.jpg
# Iterating for File Name = 000000054962.jpg
# Iterating for File Name = 000000083690.jpg
# Iterating for File Name = 000000428440.jpg
# Iterating for File Name = 000000239444.jpg
# Iterating for File Name = 000000319452.jpg
# Iterating for File Name = 000000243075.jpg
# Iterating for File Name = 000000067502.jpg
# Iterating for File Name = 000000198545.jpg
# Iterating for File Name = 000000321223.jpg
# Iterating for File Name = 000000345372.jpg
# Iterating for File Name = 000000125541.jpg
# Iterating for File Name = 000000281323.jpg
# Iterating for File Name = 000000069866.jpg
# Iterating for File Name = 000000108019.jpg
# Iterating for File Name = 000000327088.jpg
# Iterating for File Name = 000000513295.jpg
# Iterating for File Name = 000000369567.jpg
# Iterating for File Name = 000000483199.jpg
# Iterating for File Name = 000000001025.jpg
# Iterating for File Name = 000000554255.jpg
# Iterating for File Name = 000000523700.jpg
# Iterating for File Name = 000000546395.jpg
# Iterating for File Name = 000000084386.jpg
# Iterating for File Name = 000000344762.jpg
# Iterating for File Name = 000000358302.jpg
# Iterating for File Name = 000000180129.jpg
# Iterating for File Name = 000000169975.jpg
# Iterating for File Name = 000000086524.jpg
# Iterating for File Name = 000000479008.jpg
# Iterating for File Name = 000000261721.jpg
# Iterating for File Name = 000000409725.jpg
# Iterating for File Name = 000000453389.jpg
# Iterating for File Name = 000000469235.jpg
# Iterating for File Name = 000000314647.jpg
# Iterating for File Name = 000000495487.jpg
# Iterating for File Name = 000000437119.jpg
# Iterating for File Name = 000000066192.jpg
# Iterating for File Name = 000000581258.jpg
# Iterating for File Name = 000000129860.jpg
# Iterating for File Name = 000000237542.jpg
# Iterating for File Name = 000000012998.jpg
# Iterating for File Name = 000000253600.jpg
# Iterating for File Name = 000000209835.jpg
# Iterating for File Name = 000000196742.jpg
# Iterating for File Name = 000000324094.jpg
# Iterating for File Name = 000000290952.jpg
# Iterating for File Name = 000000282032.jpg
# Iterating for File Name = 000000042421.jpg
# Iterating for File Name = 000000175757.jpg
# Iterating for File Name = 000000069293.jpg
# Iterating for File Name = 000000121381.jpg
# Iterating for File Name = 000000308027.jpg
# Iterating for File Name = 000000440811.jpg
# Iterating for File Name = 000000261785.jpg
# Iterating for File Name = 000000400175.jpg
# Iterating for File Name = 000000309492.jpg
# Iterating for File Name = 000000037024.jpg
# Iterating for File Name = 000000374023.jpg
# Iterating for File Name = 000000405055.jpg
# Iterating for File Name = 000000527060.jpg
# Iterating for File Name = 000000375980.jpg
# Iterating for File Name = 000000460022.jpg
# Iterating for File Name = 000000209763.jpg
# Iterating for File Name = 000000044029.jpg
# Iterating for File Name = 000000018292.jpg
# Iterating for File Name = 000000364592.jpg
# Iterating for File Name = 000000261481.jpg
# Iterating for File Name = 000000005991.jpg
# Iterating for File Name = 000000534065.jpg
# Iterating for File Name = 000000076213.jpg
# Iterating for File Name = 000000471708.jpg
# Iterating for File Name = 000000192236.jpg
# Iterating for File Name = 000000329993.jpg
# Iterating for File Name = 000000494208.jpg
# Iterating for File Name = 000000267731.jpg
# Iterating for File Name = 000000131075.jpg
# Iterating for File Name = 000000033835.jpg
# Iterating for File Name = 000000227958.jpg
# Iterating for File Name = 000000117512.jpg
# Iterating for File Name = 000000352482.jpg
# Iterating for File Name = 000000176195.jpg
# Iterating for File Name = 000000198518.jpg
# Iterating for File Name = 000000300568.jpg
# Iterating for File Name = 000000127298.jpg
# Iterating for File Name = 000000221654.jpg
# Iterating for File Name = 000000398753.jpg
# Iterating for File Name = 000000245447.jpg
# Iterating for File Name = 000000552276.jpg
# Iterating for File Name = 000000458654.jpg
# Iterating for File Name = 000000370405.jpg
# Iterating for File Name = 000000432598.jpg
# Iterating for File Name = 000000470960.jpg
# Iterating for File Name = 000000050242.jpg
# Iterating for File Name = 000000488270.jpg
# Iterating for File Name = 000000536390.jpg
# Iterating for File Name = 000000152341.jpg
# Iterating for File Name = 000000339498.jpg
# Iterating for File Name = 000000415823.jpg
# Iterating for File Name = 000000129908.jpg
# Iterating for File Name = 000000359625.jpg
# Iterating for File Name = 000000412167.jpg
# Iterating for File Name = 000000100558.jpg
# Iterating for File Name = 000000311811.jpg
# Iterating for File Name = 000000443860.jpg
# Iterating for File Name = 000000185512.jpg
# Iterating for File Name = 000000489971.jpg
# Iterating for File Name = 000000320979.jpg
# Iterating for File Name = 000000056049.jpg
# Iterating for File Name = 000000217323.jpg
# Iterating for File Name = 000000512403.jpg
# Iterating for File Name = 000000079357.jpg
# Iterating for File Name = 000000064889.jpg
# Iterating for File Name = 000000052644.jpg
# Iterating for File Name = 000000217034.jpg
# Iterating for File Name = 000000000326.jpg
# Iterating for File Name = 000000334713.jpg
# Iterating for File Name = 000000088005.jpg
# Iterating for File Name = 000000030421.jpg
# Iterating for File Name = 000000229001.jpg
# Iterating for File Name = 000000414111.jpg
# Iterating for File Name = 000000474369.jpg
# Iterating for File Name = 000000344174.jpg
# Iterating for File Name = 000000147712.jpg
# Iterating for File Name = 000000486994.jpg
# Iterating for File Name = 000000330728.jpg
# Iterating for File Name = 000000477807.jpg
# Iterating for File Name = 000000367776.jpg
# Iterating for File Name = 000000370783.jpg
# Iterating for File Name = 000000300636.jpg
# Iterating for File Name = 000000317939.jpg
# Iterating for File Name = 000000349827.jpg
# Iterating for File Name = 000000113880.jpg
# Iterating for File Name = 000000465017.jpg
# Iterating for File Name = 000000262103.jpg
# Iterating for File Name = 000000063626.jpg
# Iterating for File Name = 000000439709.jpg
# Iterating for File Name = 000000326527.jpg
# Iterating for File Name = 000000409338.jpg
# Iterating for File Name = 000000095559.jpg
# Iterating for File Name = 000000515820.jpg
# Iterating for File Name = 000000109774.jpg
# Iterating for File Name = 000000326367.jpg
# Iterating for File Name = 000000085081.jpg
# Iterating for File Name = 000000339042.jpg
# Iterating for File Name = 000000371396.jpg
# Iterating for File Name = 000000495695.jpg
# Iterating for File Name = 000000072124.jpg
# Iterating for File Name = 000000504517.jpg
# Iterating for File Name = 000000040620.jpg
# Iterating for File Name = 000000125180.jpg
# Iterating for File Name = 000000363592.jpg
# Iterating for File Name = 000000572998.jpg
# Iterating for File Name = 000000488277.jpg
# Iterating for File Name = 000000069167.jpg
# Iterating for File Name = 000000390644.jpg
# Iterating for File Name = 000000175263.jpg
# Iterating for File Name = 000000357194.jpg
# Iterating for File Name = 000000456556.jpg
# Iterating for File Name = 000000263574.jpg
# Iterating for File Name = 000000487869.jpg
# Iterating for File Name = 000000327961.jpg
# Iterating for File Name = 000000119525.jpg
# Iterating for File Name = 000000061395.jpg
# Iterating for File Name = 000000319704.jpg
# Iterating for File Name = 000000402410.jpg
# Iterating for File Name = 000000028671.jpg
# Iterating for File Name = 000000397004.jpg
# Iterating for File Name = 000000411047.jpg
# Iterating for File Name = 000000187989.jpg
# Iterating for File Name = 000000575343.jpg
# Iterating for File Name = 000000317424.jpg
# Iterating for File Name = 000000195998.jpg
# Iterating for File Name = 000000494403.jpg
# Iterating for File Name = 000000406451.jpg
# Iterating for File Name = 000000442467.jpg
# Iterating for File Name = 000000335037.jpg
# Iterating for File Name = 000000046149.jpg
# Iterating for File Name = 000000078750.jpg
# Iterating for File Name = 000000425035.jpg
# Iterating for File Name = 000000437862.jpg
# Iterating for File Name = 000000418418.jpg
# Iterating for File Name = 000000259983.jpg
# Iterating for File Name = 000000117644.jpg
# Iterating for File Name = 000000336990.jpg
# Iterating for File Name = 000000523988.jpg
# Iterating for File Name = 000000544611.jpg
# Iterating for File Name = 000000213527.jpg
# Iterating for File Name = 000000096894.jpg
# Iterating for File Name = 000000471962.jpg
# Iterating for File Name = 000000466052.jpg
# Iterating for File Name = 000000481026.jpg
# Iterating for File Name = 000000417144.jpg
# Iterating for File Name = 000000352235.jpg
# Iterating for File Name = 000000423037.jpg
# Iterating for File Name = 000000521914.jpg
# Iterating for File Name = 000000346337.jpg
# Iterating for File Name = 000000498903.jpg
# Iterating for File Name = 000000262509.jpg
# Iterating for File Name = 000000120509.jpg
# Iterating for File Name = 000000066821.jpg
# Iterating for File Name = 000000174573.jpg
# Iterating for File Name = 000000564820.jpg
# Iterating for File Name = 000000098350.jpg
# Iterating for File Name = 000000241591.jpg
# Iterating for File Name = 000000532635.jpg
# Iterating for File Name = 000000061588.jpg
# Iterating for File Name = 000000348794.jpg
# Iterating for File Name = 000000196804.jpg
# Iterating for File Name = 000000448859.jpg
# Iterating for File Name = 000000096573.jpg
# Iterating for File Name = 000000265625.jpg
# Iterating for File Name = 000000146091.jpg
# Iterating for File Name = 000000198163.jpg
# Iterating for File Name = 000000117718.jpg
# Iterating for File Name = 000000566041.jpg
# Iterating for File Name = 000000400593.jpg
# Iterating for File Name = 000000035459.jpg
# Iterating for File Name = 000000087889.jpg
# Iterating for File Name = 000000241421.jpg
# Iterating for File Name = 000000018224.jpg
# Iterating for File Name = 000000245145.jpg
# Iterating for File Name = 000000479095.jpg
# Iterating for File Name = 000000554992.jpg
# Iterating for File Name = 000000513424.jpg
# Iterating for File Name = 000000553224.jpg
# Iterating for File Name = 000000115087.jpg
# Iterating for File Name = 000000281164.jpg
# Iterating for File Name = 000000574203.jpg
# Iterating for File Name = 000000437302.jpg
# Iterating for File Name = 000000526319.jpg
# Iterating for File Name = 000000509864.jpg
# Iterating for File Name = 000000183127.jpg
# Iterating for File Name = 000000404621.jpg
# Iterating for File Name = 000000577455.jpg
# Iterating for File Name = 000000175830.jpg
# Iterating for File Name = 000000541055.jpg
# Iterating for File Name = 000000039267.jpg
# Iterating for File Name = 000000186927.jpg
# Iterating for File Name = 000000581929.jpg
# Iterating for File Name = 000000057969.jpg
# Iterating for File Name = 000000526874.jpg
# Iterating for File Name = 000000177628.jpg
# Iterating for File Name = 000000523560.jpg
# Iterating for File Name = 000000371245.jpg
# Iterating for File Name = 000000054655.jpg
# Iterating for File Name = 000000080819.jpg
# Iterating for File Name = 000000146886.jpg
# Iterating for File Name = 000000562174.jpg

# %%
for idx in shuffled_idx:
    file_name = dict_files.get(idx)
    print ("Iterating for File Name = {}".format(file_name))
    DetectLabels(train_dir_path, file_name).return_function('aws')

# %%
for idx in shuffled_idx:
    file_name = dict_files.get(idx)
    print ("Iterating for File Name = {}".format(file_name))
    DetectLabels(train_dir_path, file_name).return_function('gc')
