# %%
import boto3
import io
import re
import numpy as np
import os
import xml.etree.ElementTree as ET 
from google.cloud import vision
import requests
from time import time
from utilities.score_computors import jaccard_similarity
from utilities.pythonDB import writeToDB, recordsExists

# %%
class RegonizeText():
    def __init__(self, base, file): 
        with io.open(os.path.join(base, file), 'rb') as image_file:
            content = (image_file.read())
        self.content = content
        self.base, self.file, self.actual_str, self.detected_str = base, file, '', ''
        self.label = ''
        self.start = time()
        
    def return_function(self, name):
        dataset = dir_path.split('/')[1] 
        if recordsExists(self.file, dataset, name + '-OCR'):
            return
        
        self.label = name + '-OCR'
        status, score =  getattr(self, 'if_' + name)()
        compute_time = time() - self.start
        bag = (self.file, dataset, self.label, status, score, compute_time, self.actual_str, self.detected_str)
        writeToDB(bag)
    def compute_ground_truth(self):
        ''' 
            Status = {-1: 'XML File Missing', -2: 'Error in XML', -3: 'Ground Truth Empty', -4: 'API Error', 0: 'All Correct'} 
            Return = Ground Truth, Status
        
        '''
        xml_file = self.file[:len(self.file)-4] + '.xml' 
        
        if not os.path.exists(os.path.join(self.base, self.file)):
            return '', -1
        try:
            ground_truth_str = fetch_from_xml_natocr(dir_path, xml_file)
        except: 
            return '', -2
        
        if len(ground_truth_str) == 0:
            return '', -3
        else:
            self.actual_str = ground_truth_str
            return ground_truth_str, 0

    def if_aws(self):
        ground_truth, xml_status = self.compute_ground_truth()
        if xml_status != 0: return xml_status, 0
        
        try:
            imgobj = {'Bytes': self.content}
            client=boto3.client('rekognition', region_name='us-east-1')
            response=client.detect_text(Image=imgobj)
            detected_str = extract_clean_str(''.join([txt['DetectedText'] for txt in response['TextDetections'] \
                                                   if txt['Type']=='WORD']))
            self.detected_str = detected_str
            score = jaccard_similarity(detected_str, ground_truth)
            return 0, score
        except:
            return -4, 0

    def if_gc(self):
        ground_truth, xml_status = self.compute_ground_truth()
        if xml_status != 0: return xml_status, 0
        try:
            vision_client = vision.ImageAnnotatorClient()
            image = vision.types.Image(content=self.content)
            text_detection_response = vision_client.text_detection(image=image)
            detected_str = extract_clean_str(text_detection_response.full_text_annotation.text)
            self.detected_str = detected_str
            score = jaccard_similarity(detected_str, ground_truth)
            return 0, score
        except:
            return -4, 0
    
    def if_azure(self):
        ground_truth, xml_status = self.compute_ground_truth()
        if xml_status != 0: return xml_status, 0
        try:
            subscription_key, endpoint = os.environ['COMPUTER_VISION_SUBSCRIPTION_KEY'], os.environ['COMPUTER_VISION_ENDPOINT']
            ocr_url = endpoint + "vision/v2.1/ocr"
            headers = {'Ocp-Apim-Subscription-Key': subscription_key, 'Content-Type': 'application/octet-stream'}
            params = {'detectOrientation': 'true'}
            response = requests.post(ocr_url, headers=headers, params=params, data=self.content)
            response.raise_for_status()

            lines_info = [region["lines"] for region in response.json()["regions"]]
            detected_str = extract_clean_str(''.join([word_info['text'] for line in lines_info \
                                      for word_metadata in line for word_info in word_metadata["words"]]))
            self.detected_str = detected_str
            score = jaccard_similarity(detected_str, ground_truth)
            return 0, score
        except:
            return -4, 0

# %%
dir_path = 'datasets/neocr_dataset/OCR/'
dict_files, files_idx = get_mapped(dir_path)
shuffled_idx = np.random.randint(0, len(files_idx), len(files_idx))

# %%
for idx in shuffled_idx:
    file_name = dict_files.get(idx)
    print ("Iterating for File Name = {}".format(file_name))
    RegonizeText(dir_path, file_name).return_function('azure')
# Out:
# Iterating for File Name = img_431882674.jpg
# Iterating for File Name = img_368342066.jpg
# Iterating for File Name = img_836067259.jpg
# Iterating for File Name = img_238034465.jpg
# Iterating for File Name = img_383306977.jpg
# Iterating for File Name = img_535474250.jpg
# Iterating for File Name = img_720201586.jpg
# Iterating for File Name = img_830799757.jpg
# Iterating for File Name = img_575687816.jpg
# Iterating for File Name = img_730544651.jpg
# Iterating for File Name = img_124983963.jpg
# Iterating for File Name = img_442936783.jpg
# Iterating for File Name = img_448918739.jpg
# Iterating for File Name = img_198896356.jpg
# Iterating for File Name = img_697503541.jpg
# Iterating for File Name = img_238034465.jpg
# Iterating for File Name = img_442936783.jpg
# Iterating for File Name = img_567666779.jpg
# Iterating for File Name = img_388759127.jpg
# Iterating for File Name = img_906238596.jpg
# Iterating for File Name = img_66151835.jpg
# Iterating for File Name = img_639884818.jpg
# Iterating for File Name = img_741356374.jpg
# Iterating for File Name = img_416780208.jpg
# Iterating for File Name = img_563424682.jpg
# Iterating for File Name = img_216667337.jpg
# Iterating for File Name = img_148261129.jpg
# Iterating for File Name = img_977174748.jpg
# Iterating for File Name = img_548513187.jpg
# Iterating for File Name = img_75475741.jpg
# Iterating for File Name = img_368272591.jpg
# Iterating for File Name = img_387154384.jpg
# Iterating for File Name = img_173617791.jpg
# Iterating for File Name = img_156036368.jpg
# Iterating for File Name = img_241903791.jpg
# Iterating for File Name = img_240434857.jpg
# Iterating for File Name = img_321799060.jpg
# Iterating for File Name = img_110864247.jpg
# Iterating for File Name = img_939464754.jpg
# Iterating for File Name = img_407877135.jpg
# Iterating for File Name = img_532537349.jpg
# Iterating for File Name = img_858758239.jpg
# Iterating for File Name = img_368342066.jpg
# Iterating for File Name = img_456780905.jpg
# Iterating for File Name = img_529587527.jpg
# Iterating for File Name = img_95058077.jpg
# Iterating for File Name = img_392179229.jpg
# Iterating for File Name = img_388759127.jpg
# Iterating for File Name = img_853508676.jpg
# Iterating for File Name = img_176982230.jpg
# Iterating for File Name = img_40861793.jpg
# Iterating for File Name = img_190337203.jpg
# Iterating for File Name = img_887765578.jpg
# Iterating for File Name = img_642970880.jpg
# Iterating for File Name = img_513248114.jpg
# Iterating for File Name = img_135163420.jpg
# Iterating for File Name = img_179604732.jpg
# Iterating for File Name = img_400010536.jpg
# Iterating for File Name = img_612389039.jpg
# Iterating for File Name = img_785655467.jpg
# Iterating for File Name = img_892756832.jpg
# Iterating for File Name = img_710982865.jpg
# Iterating for File Name = img_662544171.jpg
# Iterating for File Name = img_50590835.jpg
# Iterating for File Name = img_310423170.jpg
# Iterating for File Name = img_124079970.jpg
# Iterating for File Name = img_66122196.jpg
# Iterating for File Name = img_251104389.jpg
# Iterating for File Name = img_936861464.jpg
# Iterating for File Name = img_875119778.jpg
# Iterating for File Name = img_773405553.jpg
# Iterating for File Name = img_548746862.jpg
# Iterating for File Name = img_66122196.jpg
# Iterating for File Name = img_344006007.jpg
# Iterating for File Name = img_698959378.jpg
# Iterating for File Name = img_669115561.jpg
# Iterating for File Name = img_93519188.jpg
# Iterating for File Name = img_441034296.jpg
# Iterating for File Name = img_494639149.jpg
# Iterating for File Name = img_232176481.jpg
# Iterating for File Name = img_276436350.jpg
# Iterating for File Name = img_368849951.jpg
# Iterating for File Name = img_297611753.jpg
# Iterating for File Name = img_890004914.jpg
# Iterating for File Name = img_240434857.jpg
# Iterating for File Name = img_301173412.jpg
# Iterating for File Name = img_902752521.jpg
# Iterating for File Name = img_521637008.jpg
# Iterating for File Name = img_992598443.jpg
# Iterating for File Name = img_687182256.jpg
# Iterating for File Name = img_12440053.jpg
# Iterating for File Name = img_603325961.jpg
# Iterating for File Name = img_816734020.jpg
# Iterating for File Name = img_865791358.jpg
# Iterating for File Name = img_506345857.jpg
# Iterating for File Name = img_12440053.jpg
# Iterating for File Name = img_32991545.jpg
# Iterating for File Name = img_954715588.jpg
# Iterating for File Name = img_284119117.jpg
# Iterating for File Name = img_596597607.jpg
# Iterating for File Name = img_469143174.jpg
# Iterating for File Name = img_977522472.jpg
# Iterating for File Name = img_777189975.jpg
# Iterating for File Name = img_554164824.jpg
# Iterating for File Name = img_599507746.jpg
# Iterating for File Name = img_583239523.jpg
# Iterating for File Name = img_489901269.jpg
# Iterating for File Name = img_205880919.jpg
# Iterating for File Name = img_958339325.jpg
# Iterating for File Name = img_111981198.jpg
# Iterating for File Name = img_646048987.jpg
# Iterating for File Name = img_276436350.jpg
# Iterating for File Name = img_588148702.jpg
# Iterating for File Name = img_77303996.jpg
# Iterating for File Name = img_475356249.jpg
# Iterating for File Name = img_377854318.jpg
# Iterating for File Name = img_161948616.jpg
# Iterating for File Name = img_489901269.jpg
# Iterating for File Name = img_767020227.jpg
# Iterating for File Name = img_670952987.jpg
# Iterating for File Name = img_198896356.jpg
# Iterating for File Name = img_475356249.jpg
# Iterating for File Name = img_152744903.jpg
# Iterating for File Name = img_566082409.jpg
# Iterating for File Name = img_516302195.jpg
# Iterating for File Name = img_433780658.jpg
# Iterating for File Name = img_213349078.jpg
# Iterating for File Name = img_632442895.jpg
# Iterating for File Name = img_404663257.jpg
# Iterating for File Name = img_202486105.jpg
# Iterating for File Name = img_279831162.jpg
# Iterating for File Name = img_276436350.jpg
# Iterating for File Name = img_354001143.jpg
# Iterating for File Name = img_673801310.jpg
# Iterating for File Name = img_532537349.jpg
# Iterating for File Name = img_169389607.jpg
# Iterating for File Name = img_475356249.jpg
# Iterating for File Name = img_54991.jpg
# Iterating for File Name = img_563424682.jpg
# Iterating for File Name = img_469143174.jpg
# Iterating for File Name = img_506345857.jpg
# Iterating for File Name = img_621371218.jpg
# Iterating for File Name = img_940648502.jpg
# Iterating for File Name = img_625968571.jpg
# Iterating for File Name = img_575860651.jpg
# Iterating for File Name = img_205880919.jpg
# Iterating for File Name = img_890618205.jpg
# Iterating for File Name = img_334770208.jpg
# Iterating for File Name = img_642970880.jpg
# Iterating for File Name = img_191441491.jpg
# Iterating for File Name = img_25908425.jpg
# Iterating for File Name = img_586185068.jpg
# Iterating for File Name = img_404658782.jpg
# Iterating for File Name = img_924784692.jpg
# Iterating for File Name = img_404658782.jpg
# Iterating for File Name = img_541742847.jpg
# Iterating for File Name = img_690054314.jpg
# Iterating for File Name = img_935190062.jpg
# Iterating for File Name = img_227822455.jpg
# Iterating for File Name = img_608522306.jpg
# Iterating for File Name = img_287051259.jpg
# Iterating for File Name = img_125116307.jpg
# Iterating for File Name = img_140286525.jpg
# Iterating for File Name = img_254077972.jpg
# Iterating for File Name = img_221554799.jpg
# Iterating for File Name = img_977174748.jpg
# Iterating for File Name = img_863047131.jpg
# Iterating for File Name = img_863047131.jpg
# Iterating for File Name = img_328131032.jpg
# Iterating for File Name = img_328242995.jpg
# Iterating for File Name = img_913111216.jpg
# Iterating for File Name = img_106049628.jpg
# Iterating for File Name = img_497906598.jpg
# Iterating for File Name = img_595928899.jpg
# Iterating for File Name = img_458112573.jpg
# Iterating for File Name = img_491397096.jpg
# Iterating for File Name = img_720862511.jpg
# Iterating for File Name = img_143371697.jpg
# Iterating for File Name = img_156679293.jpg
# Iterating for File Name = img_71445692.jpg
# Iterating for File Name = img_985762175.jpg
# Iterating for File Name = img_995082457.jpg
# Iterating for File Name = img_161948616.jpg
# Iterating for File Name = img_444578487.jpg
# Iterating for File Name = img_867881247.jpg
# Iterating for File Name = img_145782.jpg
# Iterating for File Name = img_859555763.jpg
# Iterating for File Name = img_219187814.jpg
# Iterating for File Name = img_286093498.jpg
# Iterating for File Name = img_466999428.jpg
# Iterating for File Name = img_861711709.jpg
# Iterating for File Name = img_140521666.jpg
# Iterating for File Name = img_603325961.jpg
# Iterating for File Name = img_125727917.jpg
# Iterating for File Name = img_669343765.jpg
# Iterating for File Name = img_939464754.jpg
# Iterating for File Name = img_368272591.jpg
# Iterating for File Name = img_465847322.jpg
# Iterating for File Name = img_535474250.jpg
# Iterating for File Name = img_592574387.jpg
# Iterating for File Name = img_596597607.jpg
# Iterating for File Name = img_896861793.jpg
# Iterating for File Name = img_271353050.jpg
# Iterating for File Name = img_438919089.jpg
# Iterating for File Name = img_227100705.jpg
# Iterating for File Name = img_254077972.jpg
# Iterating for File Name = img_62798522.jpg
# Iterating for File Name = img_265545352.jpg
# Iterating for File Name = img_54991.jpg
# Iterating for File Name = img_139130444.jpg
# Iterating for File Name = img_684559353.jpg
# Iterating for File Name = img_571698433.jpg
# Iterating for File Name = img_655524873.jpg
# Iterating for File Name = img_642970880.jpg
# Iterating for File Name = img_75475741.jpg
# Iterating for File Name = img_118087051.jpg
# Iterating for File Name = img_354001143.jpg
# Iterating for File Name = img_642970880.jpg
# Iterating for File Name = img_404658782.jpg
# Iterating for File Name = img_265545352.jpg
# Iterating for File Name = img_206866405.jpg
# Iterating for File Name = img_203100632.jpg
# Iterating for File Name = img_773315889.jpg
# Iterating for File Name = img_444578487.jpg
# Iterating for File Name = img_797343864.jpg
# Iterating for File Name = img_175166697.jpg
# Iterating for File Name = img_450137598.jpg
# Iterating for File Name = img_191876210.jpg
# Iterating for File Name = img_720862511.jpg
# Iterating for File Name = img_235036895.jpg
# Iterating for File Name = img_966193527.jpg
# Iterating for File Name = img_330365679.jpg
# Iterating for File Name = img_219187814.jpg
# Iterating for File Name = img_458112573.jpg
# Iterating for File Name = img_715310136.jpg
# Iterating for File Name = img_73672910.jpg
# Iterating for File Name = img_472926703.jpg
# Iterating for File Name = img_892756832.jpg
# Iterating for File Name = img_450686273.jpg
# Iterating for File Name = img_433056393.jpg
# Iterating for File Name = img_612389039.jpg
# Iterating for File Name = img_416036404.jpg
# Iterating for File Name = img_926719465.jpg
# Iterating for File Name = img_649219250.jpg
# Iterating for File Name = img_179604732.jpg
# Iterating for File Name = img_792014803.jpg
# Iterating for File Name = img_708094209.jpg
# Iterating for File Name = img_629485981.jpg
# Iterating for File Name = img_506715687.jpg
# Iterating for File Name = img_70249305.jpg
# Iterating for File Name = img_433780658.jpg
# Iterating for File Name = img_605892394.jpg
# Iterating for File Name = img_203100632.jpg
# Iterating for File Name = img_684326442.jpg
# Iterating for File Name = img_609791454.jpg
# Iterating for File Name = img_218972131.jpg
# Iterating for File Name = img_700377286.jpg
# Iterating for File Name = img_773405553.jpg
# Iterating for File Name = img_532537349.jpg
# Iterating for File Name = img_456959522.jpg
# Iterating for File Name = img_559060353.jpg
# Iterating for File Name = img_247632908.jpg
# Iterating for File Name = img_391349303.jpg
# Iterating for File Name = img_32991545.jpg
# Iterating for File Name = img_878925637.jpg
# Iterating for File Name = img_381694155.jpg
# Iterating for File Name = img_349495581.jpg
# Iterating for File Name = img_344006007.jpg
# Iterating for File Name = img_995082457.jpg
# Iterating for File Name = img_570362312.jpg
# Iterating for File Name = img_276436350.jpg
# Iterating for File Name = img_291308882.jpg
# Iterating for File Name = img_577812457.jpg
# Iterating for File Name = img_108294460.jpg
# Iterating for File Name = img_400010536.jpg
# Iterating for File Name = img_904022545.jpg
# Iterating for File Name = img_280728959.jpg
# Iterating for File Name = img_227822455.jpg
# Iterating for File Name = img_923028638.jpg
# Iterating for File Name = img_344006007.jpg
# Iterating for File Name = img_896592785.jpg
# Iterating for File Name = img_530707014.jpg
# Iterating for File Name = img_375873169.jpg
# Iterating for File Name = img_6742720.jpg
# Iterating for File Name = img_967803180.jpg
# Iterating for File Name = img_586185068.jpg
# Iterating for File Name = img_940072972.jpg
# Iterating for File Name = img_173617791.jpg
# Iterating for File Name = img_97722994.jpg
# Iterating for File Name = img_85205972.jpg
# Iterating for File Name = img_247632908.jpg
# Iterating for File Name = img_846916128.jpg
# Iterating for File Name = img_450686273.jpg
# Iterating for File Name = img_940382900.jpg
# Iterating for File Name = img_570362312.jpg
# Iterating for File Name = img_406391900.jpg
# Iterating for File Name = img_433056393.jpg
# Iterating for File Name = img_622878317.jpg
# Iterating for File Name = img_250421395.jpg
# Iterating for File Name = img_655515065.jpg
# Iterating for File Name = img_135163420.jpg
# Iterating for File Name = img_500717830.jpg
# Iterating for File Name = img_450137598.jpg
# Iterating for File Name = img_901429788.jpg
# Iterating for File Name = img_344282067.jpg
# Iterating for File Name = img_667695545.jpg
# Iterating for File Name = img_227822455.jpg
# Iterating for File Name = img_11267413.jpg
# Iterating for File Name = img_296499098.jpg
# Iterating for File Name = img_721270757.jpg
# Iterating for File Name = img_879348070.jpg
# Iterating for File Name = img_527600651.jpg
# Iterating for File Name = img_625947603.jpg
# Iterating for File Name = img_992598443.jpg
# Iterating for File Name = img_384031122.jpg
# Iterating for File Name = img_389227879.jpg
# Iterating for File Name = img_440827005.jpg
# Iterating for File Name = img_365589127.jpg
# Iterating for File Name = img_954715588.jpg
# Iterating for File Name = img_812852606.jpg
# Iterating for File Name = img_693786492.jpg
# Iterating for File Name = img_532537349.jpg
# Iterating for File Name = img_563148748.jpg
# Iterating for File Name = img_433177789.jpg
# Iterating for File Name = img_46505189.jpg
# Iterating for File Name = img_775143425.jpg
# Iterating for File Name = img_535474250.jpg
# Iterating for File Name = img_977174748.jpg
# Iterating for File Name = img_797153501.jpg
# Iterating for File Name = img_943519266.jpg
# Iterating for File Name = img_616541433.jpg
# Iterating for File Name = img_862900332.jpg
# Iterating for File Name = img_416036404.jpg
# Iterating for File Name = img_925328337.jpg
# Iterating for File Name = img_450635855.jpg
# Iterating for File Name = img_365483720.jpg
# Iterating for File Name = img_239500622.jpg
# Iterating for File Name = img_781405902.jpg
# Iterating for File Name = img_516673007.jpg
# Iterating for File Name = img_527600651.jpg
# Iterating for File Name = img_32991545.jpg
# Iterating for File Name = img_548746862.jpg
# Iterating for File Name = img_521637008.jpg
# Iterating for File Name = img_349495581.jpg
# Iterating for File Name = img_95058077.jpg
# Iterating for File Name = img_670647973.jpg
# Iterating for File Name = img_326666088.jpg
# Iterating for File Name = img_291904140.jpg
# Iterating for File Name = img_925328337.jpg
# Iterating for File Name = img_816734020.jpg
# Iterating for File Name = img_627622228.jpg
# Iterating for File Name = img_995082457.jpg
# Iterating for File Name = img_230664808.jpg
# Iterating for File Name = img_11267413.jpg
# Iterating for File Name = img_609775588.jpg
# Iterating for File Name = img_554164824.jpg
# Iterating for File Name = img_95741157.jpg
# Iterating for File Name = img_265545352.jpg
# Iterating for File Name = img_404658782.jpg
# Iterating for File Name = img_326666088.jpg
# Iterating for File Name = img_491350693.jpg
# Iterating for File Name = img_138315593.jpg
# Iterating for File Name = img_423115341.jpg
# Iterating for File Name = img_73672910.jpg
# Iterating for File Name = img_202932844.jpg
# Iterating for File Name = img_431882674.jpg
# Iterating for File Name = img_420957745.jpg
# Iterating for File Name = img_254376397.jpg
# Iterating for File Name = img_310423170.jpg
# Iterating for File Name = img_200721226.jpg
# Iterating for File Name = img_285836582.jpg
# Iterating for File Name = img_363848194.jpg
# Iterating for File Name = img_861128088.jpg
# Iterating for File Name = img_603097403.jpg
# Iterating for File Name = img_578831261.jpg
# Iterating for File Name = img_797153501.jpg
# Iterating for File Name = img_377854318.jpg
# Iterating for File Name = img_524532062.jpg
# Iterating for File Name = img_625968571.jpg
# Iterating for File Name = img_781379848.jpg
# Iterating for File Name = img_816734020.jpg
# Iterating for File Name = img_442936783.jpg
# Iterating for File Name = img_175166697.jpg
# Iterating for File Name = img_926016157.jpg
# Iterating for File Name = img_25740525.jpg
# Iterating for File Name = img_778299687.jpg
# Iterating for File Name = img_70249305.jpg
# Iterating for File Name = img_674039513.jpg
# Iterating for File Name = img_416780208.jpg
# Iterating for File Name = img_657467816.jpg
# Iterating for File Name = img_966193527.jpg
# Iterating for File Name = img_475356249.jpg
# Iterating for File Name = img_475356249.jpg
# Iterating for File Name = img_291308882.jpg
# Iterating for File Name = img_670952987.jpg
# Iterating for File Name = img_320207031.jpg
# Iterating for File Name = img_279831162.jpg
# Iterating for File Name = img_167044571.jpg
# Iterating for File Name = img_334770208.jpg
# Iterating for File Name = img_65692285.jpg
# Iterating for File Name = img_930545552.jpg
# Iterating for File Name = img_692711963.jpg
# Iterating for File Name = img_404658782.jpg
# Iterating for File Name = img_952156967.jpg
# Iterating for File Name = img_176182218.jpg
# Iterating for File Name = img_344282067.jpg
# Iterating for File Name = img_428161697.jpg
# Iterating for File Name = img_139588102.jpg
# Iterating for File Name = img_926016157.jpg
# Iterating for File Name = img_876275551.jpg
# Iterating for File Name = img_500717830.jpg
# Iterating for File Name = img_404283959.jpg
# Iterating for File Name = img_967803180.jpg
# Iterating for File Name = img_74775487.jpg
# Iterating for File Name = img_714814243.jpg
# Iterating for File Name = img_646511550.jpg
# Iterating for File Name = img_700377286.jpg
# Iterating for File Name = img_889528611.jpg
# Iterating for File Name = img_513248114.jpg
# Iterating for File Name = img_433177789.jpg
# Iterating for File Name = img_567706163.jpg
# Iterating for File Name = img_806015588.jpg
# Iterating for File Name = img_148261129.jpg
# Iterating for File Name = img_420957745.jpg
# Iterating for File Name = img_789499756.jpg
# Iterating for File Name = img_845406752.jpg
# Iterating for File Name = img_532537349.jpg
# Iterating for File Name = img_977904587.jpg
# Iterating for File Name = img_389942806.jpg
# Iterating for File Name = img_215344489.jpg
# Iterating for File Name = img_280728959.jpg
# Iterating for File Name = img_265545352.jpg
# Iterating for File Name = img_573842386.jpg
# Iterating for File Name = img_420977785.jpg
# Iterating for File Name = img_936860025.jpg
# Iterating for File Name = img_958339325.jpg
# Iterating for File Name = img_713164559.jpg
# Iterating for File Name = img_442793385.jpg
# Iterating for File Name = img_475356249.jpg
# Iterating for File Name = img_452251264.jpg
# Iterating for File Name = img_344500496.jpg
# Iterating for File Name = img_953687083.jpg
# Iterating for File Name = img_595928899.jpg
# Iterating for File Name = img_534894649.jpg
# Iterating for File Name = img_344006007.jpg
# Iterating for File Name = img_806015588.jpg
# Iterating for File Name = img_420957745.jpg
# Iterating for File Name = img_995082457.jpg
# Iterating for File Name = img_612389039.jpg
# Iterating for File Name = img_609018478.jpg
# Iterating for File Name = img_926719465.jpg
# Iterating for File Name = img_40861793.jpg
# Iterating for File Name = img_715310136.jpg
# Iterating for File Name = img_381948076.jpg
# Iterating for File Name = img_132467740.jpg
# Iterating for File Name = img_985369757.jpg
# Iterating for File Name = img_605568478.jpg
# Iterating for File Name = img_693786492.jpg
# Iterating for File Name = img_836067259.jpg
# Iterating for File Name = img_902752521.jpg
# Iterating for File Name = img_546667265.jpg
# Iterating for File Name = img_513083145.jpg
# Iterating for File Name = img_286093498.jpg
# Iterating for File Name = img_68834123.jpg
# Iterating for File Name = img_651552895.jpg
# Iterating for File Name = img_324371559.jpg
# Iterating for File Name = img_871644306.jpg
# Iterating for File Name = img_12440053.jpg
# Iterating for File Name = img_124079970.jpg
# Iterating for File Name = img_250388786.jpg
# Iterating for File Name = img_260751397.jpg
# Iterating for File Name = img_551755386.jpg
# Iterating for File Name = img_770101613.jpg
# Iterating for File Name = img_609775588.jpg
# Iterating for File Name = img_708430518.jpg
# Iterating for File Name = img_167795097.jpg
# Iterating for File Name = img_542727542.jpg
# Iterating for File Name = img_761211694.jpg
# Iterating for File Name = img_833382544.jpg
# Iterating for File Name = img_708430518.jpg
# Iterating for File Name = img_450635855.jpg
# Iterating for File Name = img_529587527.jpg
# Iterating for File Name = img_209669167.jpg
# Iterating for File Name = img_988365885.jpg
# Iterating for File Name = img_616925913.jpg
# Iterating for File Name = img_248027559.jpg
# Iterating for File Name = img_497906598.jpg
# Iterating for File Name = img_255514113.jpg
# Iterating for File Name = img_362672257.jpg
# Iterating for File Name = img_156036368.jpg
# Iterating for File Name = img_893207658.jpg
# Iterating for File Name = img_984064991.jpg
# Iterating for File Name = img_686460599.jpg
# Iterating for File Name = img_630994834.jpg
# Iterating for File Name = img_535474250.jpg
# Iterating for File Name = img_859292102.jpg
# Iterating for File Name = img_359591696.jpg
# Iterating for File Name = img_698959378.jpg
# Iterating for File Name = img_719789970.jpg
# Iterating for File Name = img_738364801.jpg
# Iterating for File Name = img_458112573.jpg
# Iterating for File Name = img_629476268.jpg
# Iterating for File Name = img_563188781.jpg
# Iterating for File Name = img_719789970.jpg
# Iterating for File Name = img_444578487.jpg
# Iterating for File Name = img_219187814.jpg
# Iterating for File Name = img_294548336.jpg
# Iterating for File Name = img_595928899.jpg
# Iterating for File Name = img_50590835.jpg
# Iterating for File Name = img_377854318.jpg
# Iterating for File Name = img_567706163.jpg
# Iterating for File Name = img_946772017.jpg
# Iterating for File Name = img_656096551.jpg
# Iterating for File Name = img_183641903.jpg
# Iterating for File Name = img_174876397.jpg
# Iterating for File Name = img_616925913.jpg
# Iterating for File Name = img_781195662.jpg
# Iterating for File Name = img_884609356.jpg
# Iterating for File Name = img_438919089.jpg
# Iterating for File Name = img_118087051.jpg
# Iterating for File Name = img_250388786.jpg
# Iterating for File Name = img_448918739.jpg
# Iterating for File Name = img_792014803.jpg
# Iterating for File Name = img_609018478.jpg
# Iterating for File Name = img_203100632.jpg
# Iterating for File Name = img_294548336.jpg
# Iterating for File Name = img_407877135.jpg
# Iterating for File Name = img_145782.jpg
# Iterating for File Name = img_853680252.jpg
# Iterating for File Name = img_673801310.jpg
# Iterating for File Name = img_108294460.jpg
# Iterating for File Name = img_853738424.jpg
# Iterating for File Name = img_892756832.jpg
# Iterating for File Name = img_260843726.jpg
# Iterating for File Name = img_545425599.jpg
# Iterating for File Name = img_605892394.jpg
# Iterating for File Name = img_131288292.jpg
# Iterating for File Name = img_507940877.jpg
# Iterating for File Name = img_383306977.jpg
# Iterating for File Name = img_985369757.jpg
# Iterating for File Name = img_105215353.jpg
# Iterating for File Name = img_924784692.jpg
# Iterating for File Name = img_655515065.jpg
# Iterating for File Name = img_697503541.jpg
# Iterating for File Name = img_830799757.jpg
# Iterating for File Name = img_940382900.jpg
# Iterating for File Name = img_433495885.jpg
# Iterating for File Name = img_265470126.jpg
# Iterating for File Name = img_179604732.jpg
# Iterating for File Name = img_452246776.jpg
# Iterating for File Name = img_71445692.jpg
# Iterating for File Name = img_759383398.jpg
# Iterating for File Name = img_823414610.jpg
# Iterating for File Name = img_169389607.jpg
# Iterating for File Name = img_715310136.jpg
# Iterating for File Name = img_105215353.jpg
# Iterating for File Name = img_362672257.jpg
# Iterating for File Name = img_71445692.jpg
# Iterating for File Name = img_202486105.jpg
# Iterating for File Name = img_892756832.jpg
# Iterating for File Name = img_198896356.jpg
# Iterating for File Name = img_391349303.jpg
# Iterating for File Name = img_994547931.jpg
# Iterating for File Name = img_42324802.jpg
# Iterating for File Name = img_109844195.jpg
# Iterating for File Name = img_577482077.jpg
# Iterating for File Name = img_541742847.jpg
# Iterating for File Name = img_828399006.jpg
# Iterating for File Name = img_281540538.jpg
# Iterating for File Name = img_365483720.jpg
# Iterating for File Name = img_787284418.jpg
# Iterating for File Name = img_148261129.jpg
# Iterating for File Name = img_792313480.jpg
# Iterating for File Name = img_547819252.jpg
# Iterating for File Name = img_810996216.jpg
# Iterating for File Name = img_953272397.jpg
# Iterating for File Name = img_896592785.jpg
# Iterating for File Name = img_686460599.jpg
# Iterating for File Name = img_662544171.jpg
# Iterating for File Name = img_295496652.jpg
# Iterating for File Name = img_778143575.jpg
# Iterating for File Name = img_325299426.jpg
# Iterating for File Name = img_31235891.jpg
# Iterating for File Name = img_572177224.jpg
# Iterating for File Name = img_890618205.jpg
# Iterating for File Name = img_388759127.jpg
# Iterating for File Name = img_97722994.jpg
# Iterating for File Name = img_596597607.jpg
# Iterating for File Name = img_903169389.jpg
# Iterating for File Name = img_328242995.jpg
# Iterating for File Name = img_248027559.jpg
# Iterating for File Name = img_494639149.jpg
# Iterating for File Name = img_151587462.jpg
# Iterating for File Name = img_314588345.jpg
# Iterating for File Name = img_935190062.jpg
# Iterating for File Name = img_219187814.jpg
# Iterating for File Name = img_792014803.jpg
# Iterating for File Name = img_507940877.jpg
# Iterating for File Name = img_542727542.jpg
# Iterating for File Name = img_818188992.jpg
# Iterating for File Name = img_6742720.jpg
# Iterating for File Name = img_118087051.jpg
# Iterating for File Name = img_899116515.jpg
# Iterating for File Name = img_823414610.jpg
# Iterating for File Name = img_532537349.jpg
# Iterating for File Name = img_203100632.jpg
# Iterating for File Name = img_625947603.jpg
# Iterating for File Name = img_407877135.jpg
# Iterating for File Name = img_296499098.jpg
# Iterating for File Name = img_500717830.jpg
# Iterating for File Name = img_539233740.jpg
# Iterating for File Name = img_899116515.jpg
# Iterating for File Name = img_720540842.jpg
# Iterating for File Name = img_151587462.jpg
# Iterating for File Name = img_513083145.jpg
# Iterating for File Name = img_285836582.jpg
# Iterating for File Name = img_227822455.jpg
# Iterating for File Name = img_377854318.jpg
# Iterating for File Name = img_812852606.jpg
# Iterating for File Name = img_861711709.jpg
# Iterating for File Name = img_381948076.jpg
# Iterating for File Name = img_392179229.jpg
# Iterating for File Name = img_513248114.jpg
# Iterating for File Name = img_773405553.jpg
# Iterating for File Name = img_570381637.jpg
# Iterating for File Name = img_541291505.jpg
# Iterating for File Name = img_441034296.jpg
# Iterating for File Name = img_433780658.jpg
# Iterating for File Name = img_598782963.jpg
# Iterating for File Name = img_781379848.jpg
# Iterating for File Name = img_988167485.jpg
# Iterating for File Name = img_131288292.jpg
# Iterating for File Name = img_209596332.jpg
# Iterating for File Name = img_344006007.jpg
# Iterating for File Name = img_715310136.jpg
# Iterating for File Name = img_541742847.jpg
# Iterating for File Name = img_846407440.jpg
# Iterating for File Name = img_301173412.jpg
# Iterating for File Name = img_232176481.jpg
# Iterating for File Name = img_660833938.jpg
# Iterating for File Name = img_953687083.jpg
# Iterating for File Name = img_143371697.jpg
# Iterating for File Name = img_635687714.jpg
# Iterating for File Name = img_551840052.jpg
# Iterating for File Name = img_194493908.jpg
# Iterating for File Name = img_232176481.jpg
# Iterating for File Name = img_254376397.jpg
# Iterating for File Name = img_686809156.jpg
# Iterating for File Name = img_250421395.jpg
# Iterating for File Name = img_655524873.jpg
# Iterating for File Name = img_286093498.jpg
# Iterating for File Name = img_238034465.jpg
# Iterating for File Name = img_21660913.jpg
# Iterating for File Name = img_985575452.jpg
# Iterating for File Name = img_748774975.jpg
# Iterating for File Name = img_400010536.jpg
# Iterating for File Name = img_939464754.jpg
# Iterating for File Name = img_139130444.jpg
# Iterating for File Name = img_954715588.jpg

# %%
for idx in shuffled_idx:
    file_name = dict_files.get(idx)
    print ("Iterating for File Name = {}".format(file_name))
    RegonizeText(dir_path, file_name).return_function('aws')
# Out:
# Iterating for File Name = img_431882674.jpg
# Iterating for File Name = img_368342066.jpg
# Iterating for File Name = img_836067259.jpg
# Iterating for File Name = img_238034465.jpg
# Iterating for File Name = img_383306977.jpg
# Iterating for File Name = img_535474250.jpg
# Iterating for File Name = img_720201586.jpg
# Iterating for File Name = img_830799757.jpg
# Iterating for File Name = img_575687816.jpg
# Iterating for File Name = img_730544651.jpg
# Iterating for File Name = img_124983963.jpg
# Iterating for File Name = img_442936783.jpg
# Iterating for File Name = img_448918739.jpg
# Iterating for File Name = img_198896356.jpg
# Iterating for File Name = img_697503541.jpg
# Iterating for File Name = img_238034465.jpg
# Iterating for File Name = img_442936783.jpg
# Iterating for File Name = img_567666779.jpg
# Iterating for File Name = img_388759127.jpg
# Iterating for File Name = img_906238596.jpg
# Iterating for File Name = img_66151835.jpg
# Iterating for File Name = img_639884818.jpg
# Iterating for File Name = img_741356374.jpg
# Iterating for File Name = img_416780208.jpg
# Iterating for File Name = img_563424682.jpg
# Iterating for File Name = img_216667337.jpg
# Iterating for File Name = img_148261129.jpg
# Iterating for File Name = img_977174748.jpg
# Iterating for File Name = img_548513187.jpg
# Iterating for File Name = img_75475741.jpg
# Iterating for File Name = img_368272591.jpg
# Iterating for File Name = img_387154384.jpg
# Iterating for File Name = img_173617791.jpg
# Iterating for File Name = img_156036368.jpg
# Iterating for File Name = img_241903791.jpg
# Iterating for File Name = img_240434857.jpg
# Iterating for File Name = img_321799060.jpg
# Iterating for File Name = img_110864247.jpg
# Iterating for File Name = img_939464754.jpg
# Iterating for File Name = img_407877135.jpg
# Iterating for File Name = img_532537349.jpg
# Iterating for File Name = img_858758239.jpg
# Iterating for File Name = img_368342066.jpg
# Iterating for File Name = img_456780905.jpg
# Iterating for File Name = img_529587527.jpg
# Iterating for File Name = img_95058077.jpg
# Iterating for File Name = img_392179229.jpg
# Iterating for File Name = img_388759127.jpg
# Iterating for File Name = img_853508676.jpg
# Iterating for File Name = img_176982230.jpg
# Iterating for File Name = img_40861793.jpg
# Iterating for File Name = img_190337203.jpg
# Iterating for File Name = img_887765578.jpg
# Iterating for File Name = img_642970880.jpg
# Iterating for File Name = img_513248114.jpg
# Iterating for File Name = img_135163420.jpg
# Iterating for File Name = img_179604732.jpg
# Iterating for File Name = img_400010536.jpg
# Iterating for File Name = img_612389039.jpg
# Iterating for File Name = img_785655467.jpg
# Iterating for File Name = img_892756832.jpg
# Iterating for File Name = img_710982865.jpg
# Iterating for File Name = img_662544171.jpg
# Iterating for File Name = img_50590835.jpg
# Iterating for File Name = img_310423170.jpg
# Iterating for File Name = img_124079970.jpg
# Iterating for File Name = img_66122196.jpg
# Iterating for File Name = img_251104389.jpg
# Iterating for File Name = img_936861464.jpg
# Iterating for File Name = img_875119778.jpg
# Iterating for File Name = img_773405553.jpg
# Iterating for File Name = img_548746862.jpg
# Iterating for File Name = img_66122196.jpg
# Iterating for File Name = img_344006007.jpg
# Iterating for File Name = img_698959378.jpg
# Iterating for File Name = img_669115561.jpg
# Iterating for File Name = img_93519188.jpg
# Iterating for File Name = img_441034296.jpg
# Iterating for File Name = img_494639149.jpg
# Iterating for File Name = img_232176481.jpg
# Iterating for File Name = img_276436350.jpg
# Iterating for File Name = img_368849951.jpg
# Iterating for File Name = img_297611753.jpg
# Iterating for File Name = img_890004914.jpg
# Iterating for File Name = img_240434857.jpg
# Iterating for File Name = img_301173412.jpg
# Iterating for File Name = img_902752521.jpg
# Iterating for File Name = img_521637008.jpg
# Iterating for File Name = img_992598443.jpg
# Iterating for File Name = img_687182256.jpg
# Iterating for File Name = img_12440053.jpg
# Iterating for File Name = img_603325961.jpg
# Iterating for File Name = img_816734020.jpg
# Iterating for File Name = img_865791358.jpg
# Iterating for File Name = img_506345857.jpg
# Iterating for File Name = img_12440053.jpg
# Iterating for File Name = img_32991545.jpg
# Iterating for File Name = img_954715588.jpg
# Iterating for File Name = img_284119117.jpg
# Iterating for File Name = img_596597607.jpg
# Iterating for File Name = img_469143174.jpg
# Iterating for File Name = img_977522472.jpg
# Iterating for File Name = img_777189975.jpg
# Iterating for File Name = img_554164824.jpg
# Iterating for File Name = img_599507746.jpg
# Iterating for File Name = img_583239523.jpg
# Iterating for File Name = img_489901269.jpg
# Iterating for File Name = img_205880919.jpg
# Iterating for File Name = img_958339325.jpg
# Iterating for File Name = img_111981198.jpg
# Iterating for File Name = img_646048987.jpg
# Iterating for File Name = img_276436350.jpg
# Iterating for File Name = img_588148702.jpg
# Iterating for File Name = img_77303996.jpg
# Iterating for File Name = img_475356249.jpg
# Iterating for File Name = img_377854318.jpg
# Iterating for File Name = img_161948616.jpg
# Iterating for File Name = img_489901269.jpg
# Iterating for File Name = img_767020227.jpg
# Iterating for File Name = img_670952987.jpg
# Iterating for File Name = img_198896356.jpg
# Iterating for File Name = img_475356249.jpg
# Iterating for File Name = img_152744903.jpg
# Iterating for File Name = img_566082409.jpg
# Iterating for File Name = img_516302195.jpg
# Iterating for File Name = img_433780658.jpg
# Iterating for File Name = img_213349078.jpg
# Iterating for File Name = img_632442895.jpg
# Iterating for File Name = img_404663257.jpg
# Iterating for File Name = img_202486105.jpg
# Iterating for File Name = img_279831162.jpg
# Iterating for File Name = img_276436350.jpg
# Iterating for File Name = img_354001143.jpg
# Iterating for File Name = img_673801310.jpg
# Iterating for File Name = img_532537349.jpg
# Iterating for File Name = img_169389607.jpg
# Iterating for File Name = img_475356249.jpg
# Iterating for File Name = img_54991.jpg
# Iterating for File Name = img_563424682.jpg
# Iterating for File Name = img_469143174.jpg
# Iterating for File Name = img_506345857.jpg
# Iterating for File Name = img_621371218.jpg
# Iterating for File Name = img_940648502.jpg
# Iterating for File Name = img_625968571.jpg
# Iterating for File Name = img_575860651.jpg
# Iterating for File Name = img_205880919.jpg
# Iterating for File Name = img_890618205.jpg
# Iterating for File Name = img_334770208.jpg
# Iterating for File Name = img_642970880.jpg
# Iterating for File Name = img_191441491.jpg
# Iterating for File Name = img_25908425.jpg
# Iterating for File Name = img_586185068.jpg
# Iterating for File Name = img_404658782.jpg
# Iterating for File Name = img_924784692.jpg
# Iterating for File Name = img_404658782.jpg
# Iterating for File Name = img_541742847.jpg
# Iterating for File Name = img_690054314.jpg
# Iterating for File Name = img_935190062.jpg
# Iterating for File Name = img_227822455.jpg
# Iterating for File Name = img_608522306.jpg
# Iterating for File Name = img_287051259.jpg
# Iterating for File Name = img_125116307.jpg
# Iterating for File Name = img_140286525.jpg
# Iterating for File Name = img_254077972.jpg
# Iterating for File Name = img_221554799.jpg
# Iterating for File Name = img_977174748.jpg
# Iterating for File Name = img_863047131.jpg
# Iterating for File Name = img_863047131.jpg
# Iterating for File Name = img_328131032.jpg
# Iterating for File Name = img_328242995.jpg
# Iterating for File Name = img_913111216.jpg
# Iterating for File Name = img_106049628.jpg
# Iterating for File Name = img_497906598.jpg
# Iterating for File Name = img_595928899.jpg
# Iterating for File Name = img_458112573.jpg
# Iterating for File Name = img_491397096.jpg
# Iterating for File Name = img_720862511.jpg
# Iterating for File Name = img_143371697.jpg
# Iterating for File Name = img_156679293.jpg
# Iterating for File Name = img_71445692.jpg
# Iterating for File Name = img_985762175.jpg
# Iterating for File Name = img_995082457.jpg
# Iterating for File Name = img_161948616.jpg
# Iterating for File Name = img_444578487.jpg
# Iterating for File Name = img_867881247.jpg
# Iterating for File Name = img_145782.jpg
# Iterating for File Name = img_859555763.jpg
# Iterating for File Name = img_219187814.jpg
# Iterating for File Name = img_286093498.jpg
# Iterating for File Name = img_466999428.jpg
# Iterating for File Name = img_861711709.jpg
# Iterating for File Name = img_140521666.jpg
# Iterating for File Name = img_603325961.jpg
# Iterating for File Name = img_125727917.jpg
# Iterating for File Name = img_669343765.jpg
# Iterating for File Name = img_939464754.jpg
# Iterating for File Name = img_368272591.jpg
# Iterating for File Name = img_465847322.jpg
# Iterating for File Name = img_535474250.jpg
# Iterating for File Name = img_592574387.jpg
# Iterating for File Name = img_596597607.jpg
# Iterating for File Name = img_896861793.jpg
# Iterating for File Name = img_271353050.jpg
# Iterating for File Name = img_438919089.jpg
# Iterating for File Name = img_227100705.jpg
# Iterating for File Name = img_254077972.jpg
# Iterating for File Name = img_62798522.jpg
# Iterating for File Name = img_265545352.jpg
# Iterating for File Name = img_54991.jpg
# Iterating for File Name = img_139130444.jpg
# Iterating for File Name = img_684559353.jpg
# Iterating for File Name = img_571698433.jpg
# Iterating for File Name = img_655524873.jpg
# Iterating for File Name = img_642970880.jpg
# Iterating for File Name = img_75475741.jpg
# Iterating for File Name = img_118087051.jpg
# Iterating for File Name = img_354001143.jpg
# Iterating for File Name = img_642970880.jpg
# Iterating for File Name = img_404658782.jpg
# Iterating for File Name = img_265545352.jpg
# Iterating for File Name = img_206866405.jpg
# Iterating for File Name = img_203100632.jpg
# Iterating for File Name = img_773315889.jpg
# Iterating for File Name = img_444578487.jpg
# Iterating for File Name = img_797343864.jpg
# Iterating for File Name = img_175166697.jpg
# Iterating for File Name = img_450137598.jpg
# Iterating for File Name = img_191876210.jpg
# Iterating for File Name = img_720862511.jpg
# Iterating for File Name = img_235036895.jpg
# Iterating for File Name = img_966193527.jpg
# Iterating for File Name = img_330365679.jpg
# Iterating for File Name = img_219187814.jpg
# Iterating for File Name = img_458112573.jpg
# Iterating for File Name = img_715310136.jpg
# Iterating for File Name = img_73672910.jpg
# Iterating for File Name = img_472926703.jpg
# Iterating for File Name = img_892756832.jpg
# Iterating for File Name = img_450686273.jpg
# Iterating for File Name = img_433056393.jpg
# Iterating for File Name = img_612389039.jpg
# Iterating for File Name = img_416036404.jpg
# Iterating for File Name = img_926719465.jpg
# Iterating for File Name = img_649219250.jpg
# Iterating for File Name = img_179604732.jpg
# Iterating for File Name = img_792014803.jpg
# Iterating for File Name = img_708094209.jpg
# Iterating for File Name = img_629485981.jpg
# Iterating for File Name = img_506715687.jpg
# Iterating for File Name = img_70249305.jpg
# Iterating for File Name = img_433780658.jpg
# Iterating for File Name = img_605892394.jpg
# Iterating for File Name = img_203100632.jpg
# Iterating for File Name = img_684326442.jpg
# Iterating for File Name = img_609791454.jpg
# Iterating for File Name = img_218972131.jpg
# Iterating for File Name = img_700377286.jpg
# Iterating for File Name = img_773405553.jpg
# Iterating for File Name = img_532537349.jpg
# Iterating for File Name = img_456959522.jpg
# Iterating for File Name = img_559060353.jpg
# Iterating for File Name = img_247632908.jpg
# Iterating for File Name = img_391349303.jpg
# Iterating for File Name = img_32991545.jpg
# Iterating for File Name = img_878925637.jpg
# Iterating for File Name = img_381694155.jpg
# Iterating for File Name = img_349495581.jpg
# Iterating for File Name = img_344006007.jpg
# Iterating for File Name = img_995082457.jpg
# Iterating for File Name = img_570362312.jpg
# Iterating for File Name = img_276436350.jpg
# Iterating for File Name = img_291308882.jpg
# Iterating for File Name = img_577812457.jpg
# Iterating for File Name = img_108294460.jpg
# Iterating for File Name = img_400010536.jpg
# Iterating for File Name = img_904022545.jpg
# Iterating for File Name = img_280728959.jpg
# Iterating for File Name = img_227822455.jpg
# Iterating for File Name = img_923028638.jpg
# Iterating for File Name = img_344006007.jpg
# Iterating for File Name = img_896592785.jpg
# Iterating for File Name = img_530707014.jpg
# Iterating for File Name = img_375873169.jpg
# Iterating for File Name = img_6742720.jpg
# Iterating for File Name = img_967803180.jpg
# Iterating for File Name = img_586185068.jpg
# Iterating for File Name = img_940072972.jpg
# Iterating for File Name = img_173617791.jpg
# Iterating for File Name = img_97722994.jpg
# Iterating for File Name = img_85205972.jpg
# Iterating for File Name = img_247632908.jpg
# Iterating for File Name = img_846916128.jpg
# Iterating for File Name = img_450686273.jpg
# Iterating for File Name = img_940382900.jpg
# Iterating for File Name = img_570362312.jpg
# Iterating for File Name = img_406391900.jpg
# Iterating for File Name = img_433056393.jpg
# Iterating for File Name = img_622878317.jpg
# Iterating for File Name = img_250421395.jpg
# Iterating for File Name = img_655515065.jpg
# Iterating for File Name = img_135163420.jpg
# Iterating for File Name = img_500717830.jpg
# Iterating for File Name = img_450137598.jpg
# Iterating for File Name = img_901429788.jpg
# Iterating for File Name = img_344282067.jpg
# Iterating for File Name = img_667695545.jpg
# Iterating for File Name = img_227822455.jpg
# Iterating for File Name = img_11267413.jpg
# Iterating for File Name = img_296499098.jpg
# Iterating for File Name = img_721270757.jpg
# Iterating for File Name = img_879348070.jpg
# Iterating for File Name = img_527600651.jpg
# Iterating for File Name = img_625947603.jpg
# Iterating for File Name = img_992598443.jpg
# Iterating for File Name = img_384031122.jpg
# Iterating for File Name = img_389227879.jpg
# Iterating for File Name = img_440827005.jpg
# Iterating for File Name = img_365589127.jpg
# Iterating for File Name = img_954715588.jpg
# Iterating for File Name = img_812852606.jpg
# Iterating for File Name = img_693786492.jpg
# Iterating for File Name = img_532537349.jpg
# Iterating for File Name = img_563148748.jpg
# Iterating for File Name = img_433177789.jpg
# Iterating for File Name = img_46505189.jpg
# Iterating for File Name = img_775143425.jpg
# Iterating for File Name = img_535474250.jpg
# Iterating for File Name = img_977174748.jpg
# Iterating for File Name = img_797153501.jpg
# Iterating for File Name = img_943519266.jpg
# Iterating for File Name = img_616541433.jpg
# Iterating for File Name = img_862900332.jpg
# Iterating for File Name = img_416036404.jpg
# Iterating for File Name = img_925328337.jpg
# Iterating for File Name = img_450635855.jpg
# Iterating for File Name = img_365483720.jpg
# Iterating for File Name = img_239500622.jpg
# Iterating for File Name = img_781405902.jpg
# Iterating for File Name = img_516673007.jpg
# Iterating for File Name = img_527600651.jpg
# Iterating for File Name = img_32991545.jpg
# Iterating for File Name = img_548746862.jpg
# Iterating for File Name = img_521637008.jpg
# Iterating for File Name = img_349495581.jpg
# Iterating for File Name = img_95058077.jpg
# Iterating for File Name = img_670647973.jpg
# Iterating for File Name = img_326666088.jpg
# Iterating for File Name = img_291904140.jpg
# Iterating for File Name = img_925328337.jpg
# Iterating for File Name = img_816734020.jpg
# Iterating for File Name = img_627622228.jpg
# Iterating for File Name = img_995082457.jpg
# Iterating for File Name = img_230664808.jpg
# Iterating for File Name = img_11267413.jpg
# Iterating for File Name = img_609775588.jpg
# Iterating for File Name = img_554164824.jpg
# Iterating for File Name = img_95741157.jpg
# Iterating for File Name = img_265545352.jpg
# Iterating for File Name = img_404658782.jpg
# Iterating for File Name = img_326666088.jpg
# Iterating for File Name = img_491350693.jpg
# Iterating for File Name = img_138315593.jpg
# Iterating for File Name = img_423115341.jpg
# Iterating for File Name = img_73672910.jpg
# Iterating for File Name = img_202932844.jpg
# Iterating for File Name = img_431882674.jpg
# Iterating for File Name = img_420957745.jpg
# Iterating for File Name = img_254376397.jpg
# Iterating for File Name = img_310423170.jpg
# Iterating for File Name = img_200721226.jpg
# Iterating for File Name = img_285836582.jpg
# Iterating for File Name = img_363848194.jpg
# Iterating for File Name = img_861128088.jpg
# Iterating for File Name = img_603097403.jpg
# Iterating for File Name = img_578831261.jpg
# Iterating for File Name = img_797153501.jpg
# Iterating for File Name = img_377854318.jpg
# Iterating for File Name = img_524532062.jpg
# Iterating for File Name = img_625968571.jpg
# Iterating for File Name = img_781379848.jpg
# Iterating for File Name = img_816734020.jpg
# Iterating for File Name = img_442936783.jpg
# Iterating for File Name = img_175166697.jpg
# Iterating for File Name = img_926016157.jpg
# Iterating for File Name = img_25740525.jpg
# Iterating for File Name = img_778299687.jpg
# Iterating for File Name = img_70249305.jpg
# Iterating for File Name = img_674039513.jpg
# Iterating for File Name = img_416780208.jpg
# Iterating for File Name = img_657467816.jpg
# Iterating for File Name = img_966193527.jpg
# Iterating for File Name = img_475356249.jpg
# Iterating for File Name = img_475356249.jpg
# Iterating for File Name = img_291308882.jpg
# Iterating for File Name = img_670952987.jpg
# Iterating for File Name = img_320207031.jpg
# Iterating for File Name = img_279831162.jpg
# Iterating for File Name = img_167044571.jpg
# Iterating for File Name = img_334770208.jpg
# Iterating for File Name = img_65692285.jpg
# Iterating for File Name = img_930545552.jpg
# Iterating for File Name = img_692711963.jpg
# Iterating for File Name = img_404658782.jpg
# Iterating for File Name = img_952156967.jpg
# Iterating for File Name = img_176182218.jpg
# Iterating for File Name = img_344282067.jpg
# Iterating for File Name = img_428161697.jpg
# Iterating for File Name = img_139588102.jpg
# Iterating for File Name = img_926016157.jpg
# Iterating for File Name = img_876275551.jpg
# Iterating for File Name = img_500717830.jpg
# Iterating for File Name = img_404283959.jpg
# Iterating for File Name = img_967803180.jpg
# Iterating for File Name = img_74775487.jpg
# Iterating for File Name = img_714814243.jpg
# Iterating for File Name = img_646511550.jpg
# Iterating for File Name = img_700377286.jpg
# Iterating for File Name = img_889528611.jpg
# Iterating for File Name = img_513248114.jpg
# Iterating for File Name = img_433177789.jpg
# Iterating for File Name = img_567706163.jpg
# Iterating for File Name = img_806015588.jpg
# Iterating for File Name = img_148261129.jpg
# Iterating for File Name = img_420957745.jpg
# Iterating for File Name = img_789499756.jpg
# Iterating for File Name = img_845406752.jpg
# Iterating for File Name = img_532537349.jpg
# Iterating for File Name = img_977904587.jpg
# Iterating for File Name = img_389942806.jpg
# Iterating for File Name = img_215344489.jpg
# Iterating for File Name = img_280728959.jpg
# Iterating for File Name = img_265545352.jpg
# Iterating for File Name = img_573842386.jpg
# Iterating for File Name = img_420977785.jpg
# Iterating for File Name = img_936860025.jpg
# Iterating for File Name = img_958339325.jpg
# Iterating for File Name = img_713164559.jpg
# Iterating for File Name = img_442793385.jpg
# Iterating for File Name = img_475356249.jpg
# Iterating for File Name = img_452251264.jpg
# Iterating for File Name = img_344500496.jpg
# Iterating for File Name = img_953687083.jpg
# Iterating for File Name = img_595928899.jpg
# Iterating for File Name = img_534894649.jpg
# Iterating for File Name = img_344006007.jpg
# Iterating for File Name = img_806015588.jpg
# Iterating for File Name = img_420957745.jpg
# Iterating for File Name = img_995082457.jpg
# Iterating for File Name = img_612389039.jpg
# Iterating for File Name = img_609018478.jpg
# Iterating for File Name = img_926719465.jpg
# Iterating for File Name = img_40861793.jpg
# Iterating for File Name = img_715310136.jpg
# Iterating for File Name = img_381948076.jpg
# Iterating for File Name = img_132467740.jpg
# Iterating for File Name = img_985369757.jpg
# Iterating for File Name = img_605568478.jpg
# Iterating for File Name = img_693786492.jpg
# Iterating for File Name = img_836067259.jpg
# Iterating for File Name = img_902752521.jpg
# Iterating for File Name = img_546667265.jpg
# Iterating for File Name = img_513083145.jpg
# Iterating for File Name = img_286093498.jpg
# Iterating for File Name = img_68834123.jpg
# Iterating for File Name = img_651552895.jpg
# Iterating for File Name = img_324371559.jpg
# Iterating for File Name = img_871644306.jpg
# Iterating for File Name = img_12440053.jpg
# Iterating for File Name = img_124079970.jpg
# Iterating for File Name = img_250388786.jpg
# Iterating for File Name = img_260751397.jpg
# Iterating for File Name = img_551755386.jpg
# Iterating for File Name = img_770101613.jpg
# Iterating for File Name = img_609775588.jpg
# Iterating for File Name = img_708430518.jpg
# Iterating for File Name = img_167795097.jpg
# Iterating for File Name = img_542727542.jpg
# Iterating for File Name = img_761211694.jpg
# Iterating for File Name = img_833382544.jpg
# Iterating for File Name = img_708430518.jpg
# Iterating for File Name = img_450635855.jpg
# Iterating for File Name = img_529587527.jpg
# Iterating for File Name = img_209669167.jpg
# Iterating for File Name = img_988365885.jpg
# Iterating for File Name = img_616925913.jpg
# Iterating for File Name = img_248027559.jpg
# Iterating for File Name = img_497906598.jpg
# Iterating for File Name = img_255514113.jpg
# Iterating for File Name = img_362672257.jpg
# Iterating for File Name = img_156036368.jpg
# Iterating for File Name = img_893207658.jpg
# Iterating for File Name = img_984064991.jpg
# Iterating for File Name = img_686460599.jpg
# Iterating for File Name = img_630994834.jpg
# Iterating for File Name = img_535474250.jpg
# Iterating for File Name = img_859292102.jpg
# Iterating for File Name = img_359591696.jpg
# Iterating for File Name = img_698959378.jpg
# Iterating for File Name = img_719789970.jpg
# Iterating for File Name = img_738364801.jpg
# Iterating for File Name = img_458112573.jpg
# Iterating for File Name = img_629476268.jpg
# Iterating for File Name = img_563188781.jpg
# Iterating for File Name = img_719789970.jpg
# Iterating for File Name = img_444578487.jpg
# Iterating for File Name = img_219187814.jpg
# Iterating for File Name = img_294548336.jpg
# Iterating for File Name = img_595928899.jpg
# Iterating for File Name = img_50590835.jpg
# Iterating for File Name = img_377854318.jpg
# Iterating for File Name = img_567706163.jpg
# Iterating for File Name = img_946772017.jpg
# Iterating for File Name = img_656096551.jpg
# Iterating for File Name = img_183641903.jpg
# Iterating for File Name = img_174876397.jpg
# Iterating for File Name = img_616925913.jpg
# Iterating for File Name = img_781195662.jpg
# Iterating for File Name = img_884609356.jpg
# Iterating for File Name = img_438919089.jpg
# Iterating for File Name = img_118087051.jpg
# Iterating for File Name = img_250388786.jpg
# Iterating for File Name = img_448918739.jpg
# Iterating for File Name = img_792014803.jpg
# Iterating for File Name = img_609018478.jpg
# Iterating for File Name = img_203100632.jpg
# Iterating for File Name = img_294548336.jpg
# Iterating for File Name = img_407877135.jpg
# Iterating for File Name = img_145782.jpg
# Iterating for File Name = img_853680252.jpg
# Iterating for File Name = img_673801310.jpg
# Iterating for File Name = img_108294460.jpg
# Iterating for File Name = img_853738424.jpg
# Iterating for File Name = img_892756832.jpg
# Iterating for File Name = img_260843726.jpg
# Iterating for File Name = img_545425599.jpg
# Iterating for File Name = img_605892394.jpg
# Iterating for File Name = img_131288292.jpg
# Iterating for File Name = img_507940877.jpg
# Iterating for File Name = img_383306977.jpg
# Iterating for File Name = img_985369757.jpg
# Iterating for File Name = img_105215353.jpg
# Iterating for File Name = img_924784692.jpg
# Iterating for File Name = img_655515065.jpg
# Iterating for File Name = img_697503541.jpg
# Iterating for File Name = img_830799757.jpg
# Iterating for File Name = img_940382900.jpg
# Iterating for File Name = img_433495885.jpg
# Iterating for File Name = img_265470126.jpg
# Iterating for File Name = img_179604732.jpg
# Iterating for File Name = img_452246776.jpg
# Iterating for File Name = img_71445692.jpg
# Iterating for File Name = img_759383398.jpg
# Iterating for File Name = img_823414610.jpg
# Iterating for File Name = img_169389607.jpg
# Iterating for File Name = img_715310136.jpg
# Iterating for File Name = img_105215353.jpg
# Iterating for File Name = img_362672257.jpg
# Iterating for File Name = img_71445692.jpg
# Iterating for File Name = img_202486105.jpg
# Iterating for File Name = img_892756832.jpg
# Iterating for File Name = img_198896356.jpg
# Iterating for File Name = img_391349303.jpg
# Iterating for File Name = img_994547931.jpg
# Iterating for File Name = img_42324802.jpg
# Iterating for File Name = img_109844195.jpg
# Iterating for File Name = img_577482077.jpg
# Iterating for File Name = img_541742847.jpg
# Iterating for File Name = img_828399006.jpg
# Iterating for File Name = img_281540538.jpg
# Iterating for File Name = img_365483720.jpg
# Iterating for File Name = img_787284418.jpg
# Iterating for File Name = img_148261129.jpg
# Iterating for File Name = img_792313480.jpg
# Iterating for File Name = img_547819252.jpg
# Iterating for File Name = img_810996216.jpg
# Iterating for File Name = img_953272397.jpg
# Iterating for File Name = img_896592785.jpg
# Iterating for File Name = img_686460599.jpg
# Iterating for File Name = img_662544171.jpg
# Iterating for File Name = img_295496652.jpg
# Iterating for File Name = img_778143575.jpg
# Iterating for File Name = img_325299426.jpg
# Iterating for File Name = img_31235891.jpg
# Iterating for File Name = img_572177224.jpg
# Iterating for File Name = img_890618205.jpg
# Iterating for File Name = img_388759127.jpg
# Iterating for File Name = img_97722994.jpg
# Iterating for File Name = img_596597607.jpg
# Iterating for File Name = img_903169389.jpg
# Iterating for File Name = img_328242995.jpg
# Iterating for File Name = img_248027559.jpg
# Iterating for File Name = img_494639149.jpg
# Iterating for File Name = img_151587462.jpg
# Iterating for File Name = img_314588345.jpg
# Iterating for File Name = img_935190062.jpg
# Iterating for File Name = img_219187814.jpg
# Iterating for File Name = img_792014803.jpg
# Iterating for File Name = img_507940877.jpg
# Iterating for File Name = img_542727542.jpg
# Iterating for File Name = img_818188992.jpg
# Iterating for File Name = img_6742720.jpg
# Iterating for File Name = img_118087051.jpg
# Iterating for File Name = img_899116515.jpg
# Iterating for File Name = img_823414610.jpg
# Iterating for File Name = img_532537349.jpg
# Iterating for File Name = img_203100632.jpg
# Iterating for File Name = img_625947603.jpg
# Iterating for File Name = img_407877135.jpg
# Iterating for File Name = img_296499098.jpg
# Iterating for File Name = img_500717830.jpg
# Iterating for File Name = img_539233740.jpg
# Iterating for File Name = img_899116515.jpg
# Iterating for File Name = img_720540842.jpg
# Iterating for File Name = img_151587462.jpg
# Iterating for File Name = img_513083145.jpg
# Iterating for File Name = img_285836582.jpg
# Iterating for File Name = img_227822455.jpg
# Iterating for File Name = img_377854318.jpg
# Iterating for File Name = img_812852606.jpg
# Iterating for File Name = img_861711709.jpg
# Iterating for File Name = img_381948076.jpg
# Iterating for File Name = img_392179229.jpg
# Iterating for File Name = img_513248114.jpg
# Iterating for File Name = img_773405553.jpg
# Iterating for File Name = img_570381637.jpg
# Iterating for File Name = img_541291505.jpg
# Iterating for File Name = img_441034296.jpg
# Iterating for File Name = img_433780658.jpg
# Iterating for File Name = img_598782963.jpg
# Iterating for File Name = img_781379848.jpg
# Iterating for File Name = img_988167485.jpg
# Iterating for File Name = img_131288292.jpg
# Iterating for File Name = img_209596332.jpg
# Iterating for File Name = img_344006007.jpg
# Iterating for File Name = img_715310136.jpg
# Iterating for File Name = img_541742847.jpg
# Iterating for File Name = img_846407440.jpg
# Iterating for File Name = img_301173412.jpg
# Iterating for File Name = img_232176481.jpg
# Iterating for File Name = img_660833938.jpg
# Iterating for File Name = img_953687083.jpg
# Iterating for File Name = img_143371697.jpg
# Iterating for File Name = img_635687714.jpg
# Iterating for File Name = img_551840052.jpg
# Iterating for File Name = img_194493908.jpg
# Iterating for File Name = img_232176481.jpg
# Iterating for File Name = img_254376397.jpg
# Iterating for File Name = img_686809156.jpg
# Iterating for File Name = img_250421395.jpg
# Iterating for File Name = img_655524873.jpg
# Iterating for File Name = img_286093498.jpg
# Iterating for File Name = img_238034465.jpg
# Iterating for File Name = img_21660913.jpg
# Iterating for File Name = img_985575452.jpg
# Iterating for File Name = img_748774975.jpg
# Iterating for File Name = img_400010536.jpg
# Iterating for File Name = img_939464754.jpg
# Iterating for File Name = img_139130444.jpg
# Iterating for File Name = img_954715588.jpg

# %%
for idx in shuffled_idx:
    file_name = dict_files.get(idx)
    print ("Iterating for File Name = {}".format(file_name))
    RegonizeText(dir_path, file_name).return_function('gc')
# Out:
# Iterating for File Name = img_431882674.jpg
# Iterating for File Name = img_368342066.jpg
# Iterating for File Name = img_836067259.jpg
# Iterating for File Name = img_238034465.jpg
# Iterating for File Name = img_383306977.jpg
# Iterating for File Name = img_535474250.jpg
# Iterating for File Name = img_720201586.jpg
# Iterating for File Name = img_830799757.jpg
# Iterating for File Name = img_575687816.jpg
# Iterating for File Name = img_730544651.jpg
# Iterating for File Name = img_124983963.jpg
# Iterating for File Name = img_442936783.jpg
# Iterating for File Name = img_448918739.jpg
# Iterating for File Name = img_198896356.jpg
# Iterating for File Name = img_697503541.jpg
# Iterating for File Name = img_238034465.jpg
# Iterating for File Name = img_442936783.jpg
# Iterating for File Name = img_567666779.jpg
# Iterating for File Name = img_388759127.jpg
# Iterating for File Name = img_906238596.jpg
# Iterating for File Name = img_66151835.jpg
# Iterating for File Name = img_639884818.jpg
# Iterating for File Name = img_741356374.jpg
# Iterating for File Name = img_416780208.jpg
# Iterating for File Name = img_563424682.jpg
# Iterating for File Name = img_216667337.jpg
# Iterating for File Name = img_148261129.jpg
# Iterating for File Name = img_977174748.jpg
# Iterating for File Name = img_548513187.jpg
# Iterating for File Name = img_75475741.jpg
# Iterating for File Name = img_368272591.jpg
# Iterating for File Name = img_387154384.jpg
# Iterating for File Name = img_173617791.jpg
# Iterating for File Name = img_156036368.jpg
# Iterating for File Name = img_241903791.jpg
# Iterating for File Name = img_240434857.jpg
# Iterating for File Name = img_321799060.jpg
# Iterating for File Name = img_110864247.jpg
# Iterating for File Name = img_939464754.jpg
# Iterating for File Name = img_407877135.jpg
# Iterating for File Name = img_532537349.jpg
# Iterating for File Name = img_858758239.jpg
# Iterating for File Name = img_368342066.jpg
# Iterating for File Name = img_456780905.jpg
# Iterating for File Name = img_529587527.jpg
# Iterating for File Name = img_95058077.jpg
# Iterating for File Name = img_392179229.jpg
# Iterating for File Name = img_388759127.jpg
# Iterating for File Name = img_853508676.jpg
# Iterating for File Name = img_176982230.jpg
# Iterating for File Name = img_40861793.jpg
# Iterating for File Name = img_190337203.jpg
# Iterating for File Name = img_887765578.jpg
# Iterating for File Name = img_642970880.jpg
# Iterating for File Name = img_513248114.jpg
# Iterating for File Name = img_135163420.jpg
# Iterating for File Name = img_179604732.jpg
# Iterating for File Name = img_400010536.jpg
# Iterating for File Name = img_612389039.jpg
# Iterating for File Name = img_785655467.jpg
# Iterating for File Name = img_892756832.jpg
# Iterating for File Name = img_710982865.jpg
# Iterating for File Name = img_662544171.jpg
# Iterating for File Name = img_50590835.jpg
# Iterating for File Name = img_310423170.jpg
# Iterating for File Name = img_124079970.jpg
# Iterating for File Name = img_66122196.jpg
# Iterating for File Name = img_251104389.jpg
# Iterating for File Name = img_936861464.jpg
# Iterating for File Name = img_875119778.jpg
# Iterating for File Name = img_773405553.jpg
# Iterating for File Name = img_548746862.jpg
# Iterating for File Name = img_66122196.jpg
# Iterating for File Name = img_344006007.jpg
# Iterating for File Name = img_698959378.jpg
# Iterating for File Name = img_669115561.jpg
# Iterating for File Name = img_93519188.jpg
# Iterating for File Name = img_441034296.jpg
# Iterating for File Name = img_494639149.jpg
# Iterating for File Name = img_232176481.jpg
# Iterating for File Name = img_276436350.jpg
# Iterating for File Name = img_368849951.jpg
# Iterating for File Name = img_297611753.jpg
# Iterating for File Name = img_890004914.jpg
# Iterating for File Name = img_240434857.jpg
# Iterating for File Name = img_301173412.jpg
# Iterating for File Name = img_902752521.jpg
# Iterating for File Name = img_521637008.jpg
# Iterating for File Name = img_992598443.jpg
# Iterating for File Name = img_687182256.jpg
# Iterating for File Name = img_12440053.jpg
# Iterating for File Name = img_603325961.jpg
# Iterating for File Name = img_816734020.jpg
# Iterating for File Name = img_865791358.jpg
# Iterating for File Name = img_506345857.jpg
# Iterating for File Name = img_12440053.jpg
# Iterating for File Name = img_32991545.jpg
# Iterating for File Name = img_954715588.jpg
# Iterating for File Name = img_284119117.jpg
# Iterating for File Name = img_596597607.jpg
# Iterating for File Name = img_469143174.jpg
# Iterating for File Name = img_977522472.jpg
# Iterating for File Name = img_777189975.jpg
# Iterating for File Name = img_554164824.jpg
# Iterating for File Name = img_599507746.jpg
# Iterating for File Name = img_583239523.jpg
# Iterating for File Name = img_489901269.jpg
# Iterating for File Name = img_205880919.jpg
# Iterating for File Name = img_958339325.jpg
# Iterating for File Name = img_111981198.jpg
# Iterating for File Name = img_646048987.jpg
# Iterating for File Name = img_276436350.jpg
# Iterating for File Name = img_588148702.jpg
# Iterating for File Name = img_77303996.jpg
# Iterating for File Name = img_475356249.jpg
# Iterating for File Name = img_377854318.jpg
# Iterating for File Name = img_161948616.jpg
# Iterating for File Name = img_489901269.jpg
# Iterating for File Name = img_767020227.jpg
# Iterating for File Name = img_670952987.jpg
# Iterating for File Name = img_198896356.jpg
# Iterating for File Name = img_475356249.jpg
# Iterating for File Name = img_152744903.jpg
# Iterating for File Name = img_566082409.jpg
# Iterating for File Name = img_516302195.jpg
# Iterating for File Name = img_433780658.jpg
# Iterating for File Name = img_213349078.jpg
# Iterating for File Name = img_632442895.jpg
# Iterating for File Name = img_404663257.jpg
# Iterating for File Name = img_202486105.jpg
# Iterating for File Name = img_279831162.jpg
# Iterating for File Name = img_276436350.jpg
# Iterating for File Name = img_354001143.jpg
# Iterating for File Name = img_673801310.jpg
# Iterating for File Name = img_532537349.jpg
# Iterating for File Name = img_169389607.jpg
# Iterating for File Name = img_475356249.jpg
# Iterating for File Name = img_54991.jpg
# Iterating for File Name = img_563424682.jpg
# Iterating for File Name = img_469143174.jpg
# Iterating for File Name = img_506345857.jpg
# Iterating for File Name = img_621371218.jpg
# Iterating for File Name = img_940648502.jpg
# Iterating for File Name = img_625968571.jpg
# Iterating for File Name = img_575860651.jpg
# Iterating for File Name = img_205880919.jpg
# Iterating for File Name = img_890618205.jpg
# Iterating for File Name = img_334770208.jpg
# Iterating for File Name = img_642970880.jpg
# Iterating for File Name = img_191441491.jpg
# Iterating for File Name = img_25908425.jpg
# Iterating for File Name = img_586185068.jpg
# Iterating for File Name = img_404658782.jpg
# Iterating for File Name = img_924784692.jpg
# Iterating for File Name = img_404658782.jpg
# Iterating for File Name = img_541742847.jpg
# Iterating for File Name = img_690054314.jpg
# Iterating for File Name = img_935190062.jpg
# Iterating for File Name = img_227822455.jpg
# Iterating for File Name = img_608522306.jpg
# Iterating for File Name = img_287051259.jpg
# Iterating for File Name = img_125116307.jpg
# Iterating for File Name = img_140286525.jpg
# Iterating for File Name = img_254077972.jpg
# Iterating for File Name = img_221554799.jpg
# Iterating for File Name = img_977174748.jpg
# Iterating for File Name = img_863047131.jpg
# Iterating for File Name = img_863047131.jpg
# Iterating for File Name = img_328131032.jpg
# Iterating for File Name = img_328242995.jpg
# Iterating for File Name = img_913111216.jpg
# Iterating for File Name = img_106049628.jpg
# Iterating for File Name = img_497906598.jpg
# Iterating for File Name = img_595928899.jpg
# Iterating for File Name = img_458112573.jpg
# Iterating for File Name = img_491397096.jpg
# Iterating for File Name = img_720862511.jpg
# Iterating for File Name = img_143371697.jpg
# Iterating for File Name = img_156679293.jpg
# Iterating for File Name = img_71445692.jpg
# Iterating for File Name = img_985762175.jpg
# Iterating for File Name = img_995082457.jpg
# Iterating for File Name = img_161948616.jpg
# Iterating for File Name = img_444578487.jpg
# Iterating for File Name = img_867881247.jpg
# Iterating for File Name = img_145782.jpg
# Iterating for File Name = img_859555763.jpg
# Iterating for File Name = img_219187814.jpg
# Iterating for File Name = img_286093498.jpg
# Iterating for File Name = img_466999428.jpg
# Iterating for File Name = img_861711709.jpg
# Iterating for File Name = img_140521666.jpg
# Iterating for File Name = img_603325961.jpg
# Iterating for File Name = img_125727917.jpg
# Iterating for File Name = img_669343765.jpg
# Iterating for File Name = img_939464754.jpg
# Iterating for File Name = img_368272591.jpg
# Iterating for File Name = img_465847322.jpg
# Iterating for File Name = img_535474250.jpg
# Iterating for File Name = img_592574387.jpg
# Iterating for File Name = img_596597607.jpg
# Iterating for File Name = img_896861793.jpg
# Iterating for File Name = img_271353050.jpg
# Iterating for File Name = img_438919089.jpg
# Iterating for File Name = img_227100705.jpg
# Iterating for File Name = img_254077972.jpg
# Iterating for File Name = img_62798522.jpg
# Iterating for File Name = img_265545352.jpg
# Iterating for File Name = img_54991.jpg
# Iterating for File Name = img_139130444.jpg
# Iterating for File Name = img_684559353.jpg
# Iterating for File Name = img_571698433.jpg
# Iterating for File Name = img_655524873.jpg
# Iterating for File Name = img_642970880.jpg
# Iterating for File Name = img_75475741.jpg
# Iterating for File Name = img_118087051.jpg
# Iterating for File Name = img_354001143.jpg
# Iterating for File Name = img_642970880.jpg
# Iterating for File Name = img_404658782.jpg
# Iterating for File Name = img_265545352.jpg
# Iterating for File Name = img_206866405.jpg
# Iterating for File Name = img_203100632.jpg
# Iterating for File Name = img_773315889.jpg
# Iterating for File Name = img_444578487.jpg
# Iterating for File Name = img_797343864.jpg
# Iterating for File Name = img_175166697.jpg
# Iterating for File Name = img_450137598.jpg
# Iterating for File Name = img_191876210.jpg
# Iterating for File Name = img_720862511.jpg
# Iterating for File Name = img_235036895.jpg
# Iterating for File Name = img_966193527.jpg
# Iterating for File Name = img_330365679.jpg
# Iterating for File Name = img_219187814.jpg
# Iterating for File Name = img_458112573.jpg
# Iterating for File Name = img_715310136.jpg
# Iterating for File Name = img_73672910.jpg
# Iterating for File Name = img_472926703.jpg
# Iterating for File Name = img_892756832.jpg
# Iterating for File Name = img_450686273.jpg
# Iterating for File Name = img_433056393.jpg
# Iterating for File Name = img_612389039.jpg
# Iterating for File Name = img_416036404.jpg
# Iterating for File Name = img_926719465.jpg
# Iterating for File Name = img_649219250.jpg
# Iterating for File Name = img_179604732.jpg
# Iterating for File Name = img_792014803.jpg
# Iterating for File Name = img_708094209.jpg
# Iterating for File Name = img_629485981.jpg
# Iterating for File Name = img_506715687.jpg
# Iterating for File Name = img_70249305.jpg
# Iterating for File Name = img_433780658.jpg
# Iterating for File Name = img_605892394.jpg
# Iterating for File Name = img_203100632.jpg
# Iterating for File Name = img_684326442.jpg
# Iterating for File Name = img_609791454.jpg
# Iterating for File Name = img_218972131.jpg
# Iterating for File Name = img_700377286.jpg
# Iterating for File Name = img_773405553.jpg
# Iterating for File Name = img_532537349.jpg
# Iterating for File Name = img_456959522.jpg
# Iterating for File Name = img_559060353.jpg
# Iterating for File Name = img_247632908.jpg
# Iterating for File Name = img_391349303.jpg
# Iterating for File Name = img_32991545.jpg
# Iterating for File Name = img_878925637.jpg
# Iterating for File Name = img_381694155.jpg
# Iterating for File Name = img_349495581.jpg
# Iterating for File Name = img_344006007.jpg
# Iterating for File Name = img_995082457.jpg
# Iterating for File Name = img_570362312.jpg
# Iterating for File Name = img_276436350.jpg
# Iterating for File Name = img_291308882.jpg
# Iterating for File Name = img_577812457.jpg
# Iterating for File Name = img_108294460.jpg
# Iterating for File Name = img_400010536.jpg
# Iterating for File Name = img_904022545.jpg
# Iterating for File Name = img_280728959.jpg
# Iterating for File Name = img_227822455.jpg
# Iterating for File Name = img_923028638.jpg
# Iterating for File Name = img_344006007.jpg
# Iterating for File Name = img_896592785.jpg
# Iterating for File Name = img_530707014.jpg
# Iterating for File Name = img_375873169.jpg
# Iterating for File Name = img_6742720.jpg
# Iterating for File Name = img_967803180.jpg
# Iterating for File Name = img_586185068.jpg
# Iterating for File Name = img_940072972.jpg
# Iterating for File Name = img_173617791.jpg
# Iterating for File Name = img_97722994.jpg
# Iterating for File Name = img_85205972.jpg
# Iterating for File Name = img_247632908.jpg
# Iterating for File Name = img_846916128.jpg
# Iterating for File Name = img_450686273.jpg
# Iterating for File Name = img_940382900.jpg
# Iterating for File Name = img_570362312.jpg
# Iterating for File Name = img_406391900.jpg
# Iterating for File Name = img_433056393.jpg
# Iterating for File Name = img_622878317.jpg
# Iterating for File Name = img_250421395.jpg
# Iterating for File Name = img_655515065.jpg
# Iterating for File Name = img_135163420.jpg
# Iterating for File Name = img_500717830.jpg
# Iterating for File Name = img_450137598.jpg
# Iterating for File Name = img_901429788.jpg
# Iterating for File Name = img_344282067.jpg
# Iterating for File Name = img_667695545.jpg
# Iterating for File Name = img_227822455.jpg
# Iterating for File Name = img_11267413.jpg
# Iterating for File Name = img_296499098.jpg
# Iterating for File Name = img_721270757.jpg
# Iterating for File Name = img_879348070.jpg
# Iterating for File Name = img_527600651.jpg
# Iterating for File Name = img_625947603.jpg
# Iterating for File Name = img_992598443.jpg
# Iterating for File Name = img_384031122.jpg
# Iterating for File Name = img_389227879.jpg
# Iterating for File Name = img_440827005.jpg
# Iterating for File Name = img_365589127.jpg
# Iterating for File Name = img_954715588.jpg
# Iterating for File Name = img_812852606.jpg
# Iterating for File Name = img_693786492.jpg
# Iterating for File Name = img_532537349.jpg
# Iterating for File Name = img_563148748.jpg
# Iterating for File Name = img_433177789.jpg
# Iterating for File Name = img_46505189.jpg
# Iterating for File Name = img_775143425.jpg
# Iterating for File Name = img_535474250.jpg
# Iterating for File Name = img_977174748.jpg
# Iterating for File Name = img_797153501.jpg
# Iterating for File Name = img_943519266.jpg
# Iterating for File Name = img_616541433.jpg
# Iterating for File Name = img_862900332.jpg
# Iterating for File Name = img_416036404.jpg
# Iterating for File Name = img_925328337.jpg
# Iterating for File Name = img_450635855.jpg
# Iterating for File Name = img_365483720.jpg
# Iterating for File Name = img_239500622.jpg
# Iterating for File Name = img_781405902.jpg
# Iterating for File Name = img_516673007.jpg
# Iterating for File Name = img_527600651.jpg
# Iterating for File Name = img_32991545.jpg
# Iterating for File Name = img_548746862.jpg
# Iterating for File Name = img_521637008.jpg
# Iterating for File Name = img_349495581.jpg
# Iterating for File Name = img_95058077.jpg
# Iterating for File Name = img_670647973.jpg
# Iterating for File Name = img_326666088.jpg
# Iterating for File Name = img_291904140.jpg
# Iterating for File Name = img_925328337.jpg
# Iterating for File Name = img_816734020.jpg
# Iterating for File Name = img_627622228.jpg
# Iterating for File Name = img_995082457.jpg
# Iterating for File Name = img_230664808.jpg
# Iterating for File Name = img_11267413.jpg
# Iterating for File Name = img_609775588.jpg
# Iterating for File Name = img_554164824.jpg
# Iterating for File Name = img_95741157.jpg
# Iterating for File Name = img_265545352.jpg
# Iterating for File Name = img_404658782.jpg
# Iterating for File Name = img_326666088.jpg
# Iterating for File Name = img_491350693.jpg
# Iterating for File Name = img_138315593.jpg
# Iterating for File Name = img_423115341.jpg
# Iterating for File Name = img_73672910.jpg
# Iterating for File Name = img_202932844.jpg
# Iterating for File Name = img_431882674.jpg
# Iterating for File Name = img_420957745.jpg
# Iterating for File Name = img_254376397.jpg
# Iterating for File Name = img_310423170.jpg
# Iterating for File Name = img_200721226.jpg
# Iterating for File Name = img_285836582.jpg
# Iterating for File Name = img_363848194.jpg
# Iterating for File Name = img_861128088.jpg
# Iterating for File Name = img_603097403.jpg
# Iterating for File Name = img_578831261.jpg
# Iterating for File Name = img_797153501.jpg
# Iterating for File Name = img_377854318.jpg
# Iterating for File Name = img_524532062.jpg
# Iterating for File Name = img_625968571.jpg
# Iterating for File Name = img_781379848.jpg
# Iterating for File Name = img_816734020.jpg
# Iterating for File Name = img_442936783.jpg
# Iterating for File Name = img_175166697.jpg
# Iterating for File Name = img_926016157.jpg
# Iterating for File Name = img_25740525.jpg
# Iterating for File Name = img_778299687.jpg
# Iterating for File Name = img_70249305.jpg
# Iterating for File Name = img_674039513.jpg
# Iterating for File Name = img_416780208.jpg
# Iterating for File Name = img_657467816.jpg
# Iterating for File Name = img_966193527.jpg
# Iterating for File Name = img_475356249.jpg
# Iterating for File Name = img_475356249.jpg
# Iterating for File Name = img_291308882.jpg
# Iterating for File Name = img_670952987.jpg
# Iterating for File Name = img_320207031.jpg
# Iterating for File Name = img_279831162.jpg
# Iterating for File Name = img_167044571.jpg
# Iterating for File Name = img_334770208.jpg
# Iterating for File Name = img_65692285.jpg
# Iterating for File Name = img_930545552.jpg
# Iterating for File Name = img_692711963.jpg
# Iterating for File Name = img_404658782.jpg
# Iterating for File Name = img_952156967.jpg
# Iterating for File Name = img_176182218.jpg
# Iterating for File Name = img_344282067.jpg
# Iterating for File Name = img_428161697.jpg
# Iterating for File Name = img_139588102.jpg
# Iterating for File Name = img_926016157.jpg
# Iterating for File Name = img_876275551.jpg
# Iterating for File Name = img_500717830.jpg
# Iterating for File Name = img_404283959.jpg
# Iterating for File Name = img_967803180.jpg
# Iterating for File Name = img_74775487.jpg
# Iterating for File Name = img_714814243.jpg
# Iterating for File Name = img_646511550.jpg
# Iterating for File Name = img_700377286.jpg
# Iterating for File Name = img_889528611.jpg
# Iterating for File Name = img_513248114.jpg
# Iterating for File Name = img_433177789.jpg
# Iterating for File Name = img_567706163.jpg
# Iterating for File Name = img_806015588.jpg
# Iterating for File Name = img_148261129.jpg
# Iterating for File Name = img_420957745.jpg
# Iterating for File Name = img_789499756.jpg
# Iterating for File Name = img_845406752.jpg
# Iterating for File Name = img_532537349.jpg
# Iterating for File Name = img_977904587.jpg
# Iterating for File Name = img_389942806.jpg
# Iterating for File Name = img_215344489.jpg
# Iterating for File Name = img_280728959.jpg
# Iterating for File Name = img_265545352.jpg
# Iterating for File Name = img_573842386.jpg
# Iterating for File Name = img_420977785.jpg
# Iterating for File Name = img_936860025.jpg
# Iterating for File Name = img_958339325.jpg
# Iterating for File Name = img_713164559.jpg
# Iterating for File Name = img_442793385.jpg
# Iterating for File Name = img_475356249.jpg
# Iterating for File Name = img_452251264.jpg
# Iterating for File Name = img_344500496.jpg
# Iterating for File Name = img_953687083.jpg
# Iterating for File Name = img_595928899.jpg
# Iterating for File Name = img_534894649.jpg
# Iterating for File Name = img_344006007.jpg
# Iterating for File Name = img_806015588.jpg
# Iterating for File Name = img_420957745.jpg
# Iterating for File Name = img_995082457.jpg
# Iterating for File Name = img_612389039.jpg
# Iterating for File Name = img_609018478.jpg
# Iterating for File Name = img_926719465.jpg
# Iterating for File Name = img_40861793.jpg
# Iterating for File Name = img_715310136.jpg
# Iterating for File Name = img_381948076.jpg
# Iterating for File Name = img_132467740.jpg
# Iterating for File Name = img_985369757.jpg
# Iterating for File Name = img_605568478.jpg
# Iterating for File Name = img_693786492.jpg
# Iterating for File Name = img_836067259.jpg
# Iterating for File Name = img_902752521.jpg
# Iterating for File Name = img_546667265.jpg
# Iterating for File Name = img_513083145.jpg
# Iterating for File Name = img_286093498.jpg
# Iterating for File Name = img_68834123.jpg
# Iterating for File Name = img_651552895.jpg
# Iterating for File Name = img_324371559.jpg
# Iterating for File Name = img_871644306.jpg
# Iterating for File Name = img_12440053.jpg
# Iterating for File Name = img_124079970.jpg
# Iterating for File Name = img_250388786.jpg
# Iterating for File Name = img_260751397.jpg
# Iterating for File Name = img_551755386.jpg
# Iterating for File Name = img_770101613.jpg
# Iterating for File Name = img_609775588.jpg
# Iterating for File Name = img_708430518.jpg
# Iterating for File Name = img_167795097.jpg
# Iterating for File Name = img_542727542.jpg
# Iterating for File Name = img_761211694.jpg
# Iterating for File Name = img_833382544.jpg
# Iterating for File Name = img_708430518.jpg
# Iterating for File Name = img_450635855.jpg
# Iterating for File Name = img_529587527.jpg
# Iterating for File Name = img_209669167.jpg
# Iterating for File Name = img_988365885.jpg
# Iterating for File Name = img_616925913.jpg
# Iterating for File Name = img_248027559.jpg
# Iterating for File Name = img_497906598.jpg
# Iterating for File Name = img_255514113.jpg
# Iterating for File Name = img_362672257.jpg
# Iterating for File Name = img_156036368.jpg
# Iterating for File Name = img_893207658.jpg
# Iterating for File Name = img_984064991.jpg
# Iterating for File Name = img_686460599.jpg
# Iterating for File Name = img_630994834.jpg
# Iterating for File Name = img_535474250.jpg
# Iterating for File Name = img_859292102.jpg
# Iterating for File Name = img_359591696.jpg
# Iterating for File Name = img_698959378.jpg
# Iterating for File Name = img_719789970.jpg
# Iterating for File Name = img_738364801.jpg
# Iterating for File Name = img_458112573.jpg
# Iterating for File Name = img_629476268.jpg
# Iterating for File Name = img_563188781.jpg
# Iterating for File Name = img_719789970.jpg
# Iterating for File Name = img_444578487.jpg
# Iterating for File Name = img_219187814.jpg
# Iterating for File Name = img_294548336.jpg
# Iterating for File Name = img_595928899.jpg
# Iterating for File Name = img_50590835.jpg
# Iterating for File Name = img_377854318.jpg
# Iterating for File Name = img_567706163.jpg
# Iterating for File Name = img_946772017.jpg
# Iterating for File Name = img_656096551.jpg
# Iterating for File Name = img_183641903.jpg
# Iterating for File Name = img_174876397.jpg
# Iterating for File Name = img_616925913.jpg
# Iterating for File Name = img_781195662.jpg
# Iterating for File Name = img_884609356.jpg
# Iterating for File Name = img_438919089.jpg
# Iterating for File Name = img_118087051.jpg
# Iterating for File Name = img_250388786.jpg
# Iterating for File Name = img_448918739.jpg
# Iterating for File Name = img_792014803.jpg
# Iterating for File Name = img_609018478.jpg
# Iterating for File Name = img_203100632.jpg
# Iterating for File Name = img_294548336.jpg
# Iterating for File Name = img_407877135.jpg
# Iterating for File Name = img_145782.jpg
# Iterating for File Name = img_853680252.jpg
# Iterating for File Name = img_673801310.jpg
# Iterating for File Name = img_108294460.jpg
# Iterating for File Name = img_853738424.jpg
# Iterating for File Name = img_892756832.jpg
# Iterating for File Name = img_260843726.jpg
# Iterating for File Name = img_545425599.jpg
# Iterating for File Name = img_605892394.jpg
# Iterating for File Name = img_131288292.jpg
# Iterating for File Name = img_507940877.jpg
# Iterating for File Name = img_383306977.jpg
# Iterating for File Name = img_985369757.jpg
# Iterating for File Name = img_105215353.jpg
# Iterating for File Name = img_924784692.jpg
# Iterating for File Name = img_655515065.jpg
# Iterating for File Name = img_697503541.jpg
# Iterating for File Name = img_830799757.jpg
# Iterating for File Name = img_940382900.jpg
# Iterating for File Name = img_433495885.jpg
# Iterating for File Name = img_265470126.jpg
# Iterating for File Name = img_179604732.jpg
# Iterating for File Name = img_452246776.jpg
# Iterating for File Name = img_71445692.jpg
# Iterating for File Name = img_759383398.jpg
# Iterating for File Name = img_823414610.jpg
# Iterating for File Name = img_169389607.jpg
# Iterating for File Name = img_715310136.jpg
# Iterating for File Name = img_105215353.jpg
# Iterating for File Name = img_362672257.jpg
# Iterating for File Name = img_71445692.jpg
# Iterating for File Name = img_202486105.jpg
# Iterating for File Name = img_892756832.jpg
# Iterating for File Name = img_198896356.jpg
# Iterating for File Name = img_391349303.jpg
# Iterating for File Name = img_994547931.jpg
# Iterating for File Name = img_42324802.jpg
# Iterating for File Name = img_109844195.jpg
# Iterating for File Name = img_577482077.jpg
# Iterating for File Name = img_541742847.jpg
# Iterating for File Name = img_828399006.jpg
# Iterating for File Name = img_281540538.jpg
# Iterating for File Name = img_365483720.jpg
# Iterating for File Name = img_787284418.jpg
# Iterating for File Name = img_148261129.jpg
# Iterating for File Name = img_792313480.jpg
# Iterating for File Name = img_547819252.jpg
# Iterating for File Name = img_810996216.jpg
# Iterating for File Name = img_953272397.jpg
# Iterating for File Name = img_896592785.jpg
# Iterating for File Name = img_686460599.jpg
# Iterating for File Name = img_662544171.jpg
# Iterating for File Name = img_295496652.jpg
# Iterating for File Name = img_778143575.jpg
# Iterating for File Name = img_325299426.jpg
# Iterating for File Name = img_31235891.jpg
# Iterating for File Name = img_572177224.jpg
# Iterating for File Name = img_890618205.jpg
# Iterating for File Name = img_388759127.jpg
# Iterating for File Name = img_97722994.jpg
# Iterating for File Name = img_596597607.jpg
# Iterating for File Name = img_903169389.jpg
# Iterating for File Name = img_328242995.jpg
# Iterating for File Name = img_248027559.jpg
# Iterating for File Name = img_494639149.jpg
# Iterating for File Name = img_151587462.jpg
# Iterating for File Name = img_314588345.jpg
# Iterating for File Name = img_935190062.jpg
# Iterating for File Name = img_219187814.jpg
# Iterating for File Name = img_792014803.jpg
# Iterating for File Name = img_507940877.jpg
# Iterating for File Name = img_542727542.jpg
# Iterating for File Name = img_818188992.jpg
# Iterating for File Name = img_6742720.jpg
# Iterating for File Name = img_118087051.jpg
# Iterating for File Name = img_899116515.jpg
# Iterating for File Name = img_823414610.jpg
# Iterating for File Name = img_532537349.jpg
# Iterating for File Name = img_203100632.jpg
# Iterating for File Name = img_625947603.jpg
# Iterating for File Name = img_407877135.jpg
# Iterating for File Name = img_296499098.jpg
# Iterating for File Name = img_500717830.jpg
# Iterating for File Name = img_539233740.jpg
# Iterating for File Name = img_899116515.jpg
# Iterating for File Name = img_720540842.jpg
# Iterating for File Name = img_151587462.jpg
# Iterating for File Name = img_513083145.jpg
# Iterating for File Name = img_285836582.jpg
# Iterating for File Name = img_227822455.jpg
# Iterating for File Name = img_377854318.jpg
# Iterating for File Name = img_812852606.jpg
# Iterating for File Name = img_861711709.jpg
# Iterating for File Name = img_381948076.jpg
# Iterating for File Name = img_392179229.jpg
# Iterating for File Name = img_513248114.jpg
# Iterating for File Name = img_773405553.jpg
# Iterating for File Name = img_570381637.jpg
# Iterating for File Name = img_541291505.jpg
# Iterating for File Name = img_441034296.jpg
# Iterating for File Name = img_433780658.jpg
# Iterating for File Name = img_598782963.jpg
# Iterating for File Name = img_781379848.jpg
# Iterating for File Name = img_988167485.jpg
# Iterating for File Name = img_131288292.jpg
# Iterating for File Name = img_209596332.jpg
# Iterating for File Name = img_344006007.jpg
# Iterating for File Name = img_715310136.jpg
# Iterating for File Name = img_541742847.jpg
# Iterating for File Name = img_846407440.jpg
# Iterating for File Name = img_301173412.jpg
# Iterating for File Name = img_232176481.jpg
# Iterating for File Name = img_660833938.jpg
# Iterating for File Name = img_953687083.jpg
# Iterating for File Name = img_143371697.jpg
# Iterating for File Name = img_635687714.jpg
# Iterating for File Name = img_551840052.jpg
# Iterating for File Name = img_194493908.jpg
# Iterating for File Name = img_232176481.jpg
# Iterating for File Name = img_254376397.jpg
# Iterating for File Name = img_686809156.jpg
# Iterating for File Name = img_250421395.jpg
# Iterating for File Name = img_655524873.jpg
# Iterating for File Name = img_286093498.jpg
# Iterating for File Name = img_238034465.jpg
# Iterating for File Name = img_21660913.jpg
# Iterating for File Name = img_985575452.jpg
# Iterating for File Name = img_748774975.jpg
# Iterating for File Name = img_400010536.jpg
# Iterating for File Name = img_939464754.jpg
# Iterating for File Name = img_139130444.jpg
# Iterating for File Name = img_954715588.jpg
