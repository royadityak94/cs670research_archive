# %%
import io
import re
import numpy as np
import os
import xml.etree.ElementTree as ET 
from joblib import Parallel, delayed
import multiprocessing
from utilities.score_computors import jaccard_similarity
from time import time
import pandas as pd
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from azure.cognitiveservices.vision.computervision.models import TextOperationStatusCodes
from azure.cognitiveservices.vision.computervision.models import TextRecognitionMode
from azure.cognitiveservices.vision.computervision.models import VisualFeatureTypes
from msrest.authentication import CognitiveServicesCredentials
import requests

# %%
def extract_clean_str(original_str):
    return re.sub('[^a-zA-Z0-9]+', ' ', original_str, flags=re.UNICODE).lower().strip().replace(' ', '')

def get_mapped(path):
    key_map, dict_idx = {}, 0
    for r, _, f in os.walk(dir_path):
        for file in f:
            if '.JPG' in file or '.jpg' in file:
                key_map[dict_idx] = file
                dict_idx += 1
    idxs = list(key_map.keys())          
    shuffled_idxs = np.random.randint(0, len(idxs), len(idxs))
    return key_map, shuffled_idxs

def fetch_from_xml(path, file):
    tree = ET.parse(os.path.join(path, file)).getroot()  
    return extract_clean_str(''.join([e.attrib['char'] for e in tree.iter(tag='character')]))

# %%
def compute_text_recognition(file, cutoff=.25):
    print ("Iterating for FileName = {}".format(file))
    status, score = -1, 0
    xml_file = file[:len(file)-4] + '.xml' 
    if not os.path.exists(os.path.join(dir_path, xml_file)):
        return False, status, score
    try:
        ground_truth_str = fetch_from_xml(dir_path, xml_file)
    except: 
        return False, -2, score
    if len(ground_truth_str) == 0:
        return False, status, score
    try:
        with io.open(os.path.join(dir_path, file), 'rb') as image_file:
            content = (image_file.read())
        subscription_key = os.environ['COMPUTER_VISION_SUBSCRIPTION_KEY']
        endpoint = os.environ['COMPUTER_VISION_ENDPOINT']
        ocr_url = endpoint + "vision/v2.1/ocr"
        headers = {'Ocp-Apim-Subscription-Key': subscription_key, 'Content-Type': 'application/octet-stream'}
        params = {'detectOrientation': 'true'} #'language': 'en',
        response = requests.post(ocr_url, headers=headers, params=params, data=content)
        response.raise_for_status()
        
        lines_info = [region["lines"] for region in response.json()["regions"]]
        detected_str = extract_clean_str(''.join([word_info['text'] for line in lines_info \
                                  for word_metadata in line for word_info in word_metadata["words"]]))
    except:
        return False, 100, score
    score = jaccard_similarity(detected_str, ground_truth_str)
    if score > cutoff:
        return True, 0, score
    else:
        return False, 0, score

# %%
dir_path = 'datasets/KAIST/English/'
dict_files, files_idx = get_mapped(dir_path)
shuffled_idx = np.random.randint(0, len(files_idx), len(files_idx))

# %%
df = pd.DataFrame(columns=['score', 'status', 'matched', 'time'])
for idx in shuffled_idx:
    start_time = time()
    matched, status, score = compute_text_recognition(dict_files.get(idx))
    end_time = time()
    df = df.append({'score': score, 'status': status, 'matched': matched, 'time': (end_time-start_time)}, ignore_index=True)
# Out:
# Iterating for FileName = DSC02673.JPG
# Iterating for FileName = P090902019.jpg
# Iterating for FileName = DSC03196.JPG
# Iterating for FileName = 2007-12-09-day-exterior-051.jpg
# Iterating for FileName = P1010065.JPG
# Iterating for FileName = DSC03308.JPG
# Iterating for FileName = DSC02376.JPG
# Iterating for FileName = DSC03670.JPG
# Iterating for FileName = DSC04451.JPG
# Iterating for FileName = DSC03440.JPG
# Iterating for FileName = DSC04087.JPG
# Iterating for FileName = P090911060.jpg
# Iterating for FileName = DSC04458.JPG
# Iterating for FileName = 20.JPG
# Iterating for FileName = DSC04197.JPG
# Iterating for FileName = DSC02897.JPG
# Iterating for FileName = DSC03822.JPG
# Iterating for FileName = DSC03091.JPG
# Iterating for FileName = 080119-0038.jpg
# Iterating for FileName = DSC03918.JPG
# Iterating for FileName = DSC02382.JPG
# Iterating for FileName = DSC02590.JPG
# Iterating for FileName = DSC04364.JPG
# Iterating for FileName = DSC03316.JPG
# Iterating for FileName = IMG_2618.JPG
# Iterating for FileName = DSC02956.JPG
# Iterating for FileName = DSC02491.JPG
# Iterating for FileName = DSC03501.JPG
# Iterating for FileName = DSC02869.JPG
# Iterating for FileName = DSC03650.JPG
# Iterating for FileName = DSC03091.JPG
# Iterating for FileName = 080119-0015.jpg
# Iterating for FileName = DSC03234.JPG
# Iterating for FileName = 080119-0020.jpg
# Iterating for FileName = P1010116.JPG
# Iterating for FileName = DSC03277.JPG
# Iterating for FileName = DSC03633.JPG
# Iterating for FileName = DSC03711.JPG
# Iterating for FileName = DSC02417.JPG
# Iterating for FileName = 2007-12-09-day-exterior-047.jpg
# Iterating for FileName = 115.JPG
# Iterating for FileName = P090911081.jpg
# Iterating for FileName = P1010074.JPG
# Iterating for FileName = DSC03633.JPG
# Iterating for FileName = IMG_2618.JPG
# Iterating for FileName = DSC03414.JPG
# Iterating for FileName = DSC02448.JPG
# Iterating for FileName = DSC03054.JPG
# Iterating for FileName = DSC03412.JPG
# Iterating for FileName = DSC02641.JPG
# Iterating for FileName = 046.JPG
# Iterating for FileName = DSC03279.JPG
# Iterating for FileName = 080119-0016.jpg
# Iterating for FileName = DSC04231.JPG
# Iterating for FileName = DSC03301.JPG
# Iterating for FileName = DSC04048.JPG
# Iterating for FileName = DSC04078.JPG
# Iterating for FileName = DSC03046.JPG
# Iterating for FileName = 47.JPG
# Iterating for FileName = 2007-12-08-day-092.jpg
# Iterating for FileName = DSC03904.JPG
# Iterating for FileName = DSC02958.JPG
# Iterating for FileName = DSC02322.JPG
# Iterating for FileName = P090903082.jpg
# Iterating for FileName = DSC03085.JPG
# Iterating for FileName = P090911086.jpg
# Iterating for FileName = DSC03074.JPG
# Iterating for FileName = DSC03267.JPG
# Iterating for FileName = DSC02755.JPG
# Iterating for FileName = DSC03122.JPG
# Iterating for FileName = DSC03980.JPG
# Iterating for FileName = 080119-0009.jpg
# Iterating for FileName = DSC03292.JPG
# Iterating for FileName = P090831113.jpg
# Iterating for FileName = P090903022.jpg
# Iterating for FileName = P1010021.JPG
# Iterating for FileName = P1010155.JPG
# Iterating for FileName = DSC03366.JPG
# Iterating for FileName = DSC03761.JPG
# Iterating for FileName = DSC04409.JPG
# Iterating for FileName = 078.JPG
# Iterating for FileName = DSC03871.JPG
# Iterating for FileName = DSC04461.JPG
# Iterating for FileName = P1010027.JPG
# Iterating for FileName = P1010074.JPG
# Iterating for FileName = DSC03684.JPG
# Iterating for FileName = DSC03773.JPG
# Iterating for FileName = P090905002.jpg
# Iterating for FileName = DSC03340.JPG
# Iterating for FileName = DSC03516.JPG
# Iterating for FileName = P090911083.jpg
# Iterating for FileName = DSC03217.JPG
# Iterating for FileName = DSC03769.JPG
# Iterating for FileName = DSC02581.JPG
# Iterating for FileName = DSC03613.JPG
# Iterating for FileName = DSC03055.JPG
# Iterating for FileName = DSC02963.JPG
# Iterating for FileName = DSC02893.JPG
# Iterating for FileName = DSC03936.JPG
# Iterating for FileName = DSC03086.JPG
# Iterating for FileName = DSC02687.JPG
# Iterating for FileName = DSC03135.JPG
# Iterating for FileName = DSC02323.JPG
# Iterating for FileName = DSC02725.JPG
# Iterating for FileName = DSC03673.JPG
# Iterating for FileName = DSC02382.JPG
# Iterating for FileName = P090831122.jpg
# Iterating for FileName = DSC03367.JPG
# Iterating for FileName = DSC03165.JPG
# Iterating for FileName = P1010129.JPG
# Iterating for FileName = P090904004.jpg
# Iterating for FileName = DSC02887.JPG
# Iterating for FileName = DSC03786.JPG
# Iterating for FileName = P090904005.jpg
# Iterating for FileName = 2007-12-08-day-130.jpg
# Iterating for FileName = DSC02718.JPG
# Iterating for FileName = DSC03842.JPG
# Iterating for FileName = DSC03365.JPG
# Iterating for FileName = DSC02732.JPG
# Iterating for FileName = DSC03430.JPG
# Iterating for FileName = DSC03871.JPG
# Iterating for FileName = P1010004.JPG
# Iterating for FileName = DSC03925.JPG
# Iterating for FileName = DSC02963.JPG
# Iterating for FileName = DSC02872.JPG
# Iterating for FileName = DSC02394.JPG
# Iterating for FileName = DSC03169.JPG
# Iterating for FileName = DSC03918.JPG
# Iterating for FileName = P1010132.JPG
# Iterating for FileName = P1010132.JPG
# Iterating for FileName = P090903024.jpg
# Iterating for FileName = DSC04226.JPG
# Iterating for FileName = P090905003.jpg
# Iterating for FileName = DSC02306.JPG
# Iterating for FileName = P090831114.jpg
# Iterating for FileName = DSC02718.JPG
# Iterating for FileName = v.jpg
# Iterating for FileName = 004.jpg
# Iterating for FileName = DSC03218.JPG
# Iterating for FileName = DSC03684.JPG
# Iterating for FileName = DSC04002.JPG
# Iterating for FileName = DSC02479.JPG
# Iterating for FileName = DSC03489.JPG
# Iterating for FileName = 2007-12-08-day-130.jpg
# Iterating for FileName = DSC03020.JPG
# Iterating for FileName = DSC03562.JPG
# Iterating for FileName = 080119-0020.jpg
# Iterating for FileName = 046.JPG
# Iterating for FileName = P1010123.JPG
# Iterating for FileName = DSC02575.JPG
# Iterating for FileName = DSC04149.JPG
# Iterating for FileName = 1.JPG
# Iterating for FileName = P090903099.jpg
# Iterating for FileName = 138.JPG
# Iterating for FileName = P090831022.jpg
# Iterating for FileName = DSC03324.JPG
# Iterating for FileName = DSC03637.JPG
# Iterating for FileName = 065.jpg
# Iterating for FileName = 080119-0012.jpg
# Iterating for FileName = DSC03479.JPG
# Iterating for FileName = 080119-0033.jpg
# Iterating for FileName = DSC03331.JPG
# Iterating for FileName = DSC03556.JPG
# Iterating for FileName = DSC04131.JPG
# Iterating for FileName = DSC02309.JPG
# Iterating for FileName = DSC03269.JPG
# Iterating for FileName = DSC03883.JPG
# Iterating for FileName = DSC02560.JPG
# Iterating for FileName = DSC02385.JPG
# Iterating for FileName = DSC02505.JPG
# Iterating for FileName = DSC04206.JPG
# Iterating for FileName = DSC02387.JPG
# Iterating for FileName = DSC02937.JPG
# Iterating for FileName = P1010093.JPG
# Iterating for FileName = DSC03531.JPG
# Iterating for FileName = DSC04144.JPG
# Iterating for FileName = DSC03053.JPG
# Iterating for FileName = DSC03670.JPG
# Iterating for FileName = DSC03719.JPG
# Iterating for FileName = P1010016.JPG
# Iterating for FileName = DSC03943.JPG
# Iterating for FileName = P1010020.JPG
# Iterating for FileName = P1010015.JPG
# Iterating for FileName = DSC03124.JPG
# Iterating for FileName = DSC04094.JPG
# Iterating for FileName = P1010002.JPG
# Iterating for FileName = DSC03943.JPG
# Iterating for FileName = DSC04401.JPG
# Iterating for FileName = DSC03408.JPG
# Iterating for FileName = DSC03147.JPG
# Iterating for FileName = 078.JPG
# Iterating for FileName = P090903003.jpg
# Iterating for FileName = DSC04104.JPG
# Iterating for FileName = DSC02317.JPG
# Iterating for FileName = 42.JPG
# Iterating for FileName = DSC03077.JPG
# Iterating for FileName = 080116-0084.jpg
# Iterating for FileName = 080116-0084.jpg
# Iterating for FileName = DSC03006.JPG
# Iterating for FileName = DSC04318.JPG
# Iterating for FileName = v.jpg
# Iterating for FileName = DSC02842.JPG
# Iterating for FileName = 2007-12-09-day-exterior-047.jpg
# Iterating for FileName = DSC02514.JPG
# Iterating for FileName = DSC03298.JPG
# Iterating for FileName = DSC04458.JPG
# Iterating for FileName = 080116-0066.jpg
# Iterating for FileName = DSC03147.JPG
# Iterating for FileName = DSC02789.JPG
# Iterating for FileName = 080116-0059.jpg
# Iterating for FileName = DSC03655.JPG
# Iterating for FileName = DSC02430.JPG
# Iterating for FileName = DSC02647.JPG
# Iterating for FileName = DSC02493.JPG
# Iterating for FileName = DSC03501.JPG
# Iterating for FileName = DSC02969.JPG
# Iterating for FileName = P090831121.jpg
# Iterating for FileName = P090903024.jpg
# Iterating for FileName = DSC03911.JPG
# Iterating for FileName = P090902016.jpg
# Iterating for FileName = 7.jpg
# Iterating for FileName = P1010025.JPG
# Iterating for FileName = P090902019.jpg
# Iterating for FileName = 032.jpg
# Iterating for FileName = P090911083.jpg
# Iterating for FileName = P090831011.jpg
# Iterating for FileName = DSC03150.JPG
# Iterating for FileName = DSC04063.JPG
# Iterating for FileName = DSC04314.JPG
# Iterating for FileName = DSC03003.JPG
# Iterating for FileName = DSC03532.JPG
# Iterating for FileName = DSC03722.JPG
# Iterating for FileName = DSC04401.JPG
# Iterating for FileName = P1010021.JPG
# Iterating for FileName = 139.JPG
# Iterating for FileName = P090903081.jpg
# Iterating for FileName = DSC03786.JPG
# Iterating for FileName = DSC03609.JPG
# Iterating for FileName = P090912078.jpg
# Iterating for FileName = P090911071.jpg
# Iterating for FileName = P090904004.jpg
# Iterating for FileName = DSC03759.JPG
# Iterating for FileName = 42.JPG
# Iterating for FileName = DSC04061.JPG
# Iterating for FileName = 113.jpg
# Iterating for FileName = DSC03085.JPG
# Iterating for FileName = P090911087.jpg
# Iterating for FileName = DSC04443.JPG
# Iterating for FileName = DSC03134.JPG
# Iterating for FileName = DSC04399.JPG
# Iterating for FileName = P090903015.jpg
# Iterating for FileName = DSC02802.JPG
# Iterating for FileName = P090911085.jpg
# Iterating for FileName = P090831119.jpg
# Iterating for FileName = DSC03150.JPG
# Iterating for FileName = DSC04304.JPG
# Iterating for FileName = DSC04444.JPG
# Iterating for FileName = DSC04447.JPG
# Iterating for FileName = DSC02750.JPG
# Iterating for FileName = DSC03757.JPG
# Iterating for FileName = DSC04151.JPG
# Iterating for FileName = DSC03185.JPG
# Iterating for FileName = DSC03711.JPG
# Iterating for FileName = P090911070.jpg
# Iterating for FileName = DSC03925.JPG
# Iterating for FileName = DSC04432.JPG
# Iterating for FileName = DSC04450.JPG
# Iterating for FileName = DSC03655.JPG
# Iterating for FileName = DSC02590.JPG
# Iterating for FileName = DSC03229.JPG
# Iterating for FileName = P1010044.JPG
# Iterating for FileName = DSC02989.JPG
# Iterating for FileName = DSC03483.JPG
# Iterating for FileName = DSC04437.JPG
# Iterating for FileName = 076.JPG
# Iterating for FileName = DSC04395.JPG
# Iterating for FileName = 42.JPG
# Iterating for FileName = DSC03684.JPG
# Iterating for FileName = DSC04059.JPG
# Iterating for FileName = DSC03149.JPG
# Iterating for FileName = DSC03185.JPG
# Iterating for FileName = P090831062.jpg
# Iterating for FileName = P090831075.jpg
# Iterating for FileName = 2007-12-09-day-exterior-004.jpg
# Iterating for FileName = DSC03001.JPG
# Iterating for FileName = P1010129.JPG
# Iterating for FileName = DSC02477.JPG
# Iterating for FileName = DSC02673.JPG
# Iterating for FileName = DSC03038.JPG
# Iterating for FileName = DSC03831.JPG
# Iterating for FileName = 080120-0001.jpg
# Iterating for FileName = DSC03665.JPG
# Iterating for FileName = DSC03315.JPG
# Iterating for FileName = 36.JPG
# Iterating for FileName = 1.JPG
# Iterating for FileName = DSC03883.JPG
# Iterating for FileName = DSC03010.JPG
# Iterating for FileName = P090831075.jpg
# Iterating for FileName = DSC03410.JPG
# Iterating for FileName = 068.jpg
# Iterating for FileName = DSC03628.JPG
# Iterating for FileName = DSC03409.JPG
# Iterating for FileName = DSC03160.JPG
# Iterating for FileName = DSC03618.JPG
# Iterating for FileName = DSC02600.JPG
# Iterating for FileName = P090903083.jpg
# Iterating for FileName = DSC03004.JPG
# Iterating for FileName = DSC03262.JPG
# Iterating for FileName = P090831124.jpg
# Iterating for FileName = DSC04061.JPG
# Iterating for FileName = DSC02575.JPG
# Iterating for FileName = 2007-12-09-day-exterior-032.jpg
# Iterating for FileName = P1010123.JPG
# Iterating for FileName = DSC03150.JPG
# Iterating for FileName = DSC03743.JPG
# Iterating for FileName = DSC02937.JPG
# Iterating for FileName = DSC03628.JPG
# Iterating for FileName = DSC04032.JPG
# Iterating for FileName = 080119-0015.jpg
# Iterating for FileName = DSC03273.JPG
# Iterating for FileName = 080119-0008.jpg
# Iterating for FileName = DSC04022.JPG
# Iterating for FileName = DSC03299.JPG
# Iterating for FileName = z.jpg
# Iterating for FileName = DSC03186.JPG
# Iterating for FileName = DSC02854.JPG
# Iterating for FileName = DSC03329.JPG
# Iterating for FileName = DSC03143.JPG
# Iterating for FileName = 054.JPG
# Iterating for FileName = 009.JPG
# Iterating for FileName = 114.jpg
# Iterating for FileName = DSC03207.JPG
# Iterating for FileName = DSC02524.JPG
# Iterating for FileName = 080119-0013.jpg
# Iterating for FileName = 042.JPG
# Iterating for FileName = DSC04395.JPG
# Iterating for FileName = DSC04326.JPG
# Iterating for FileName = DSC04109.JPG
# Iterating for FileName = DSC03006.JPG
# Iterating for FileName = DSC02575.JPG
# Iterating for FileName = DSC03781.JPG
# Iterating for FileName = DSC02461.JPG
# Iterating for FileName = 6.jpg
# Iterating for FileName = DSC02791.JPG
# Iterating for FileName = 2.JPG
# Iterating for FileName = DSC02590.JPG
# Iterating for FileName = DSC03705.JPG
# Iterating for FileName = DSC03707.JPG
# Iterating for FileName = P1010088.JPG
# Iterating for FileName = 080116-0056.jpg
# Iterating for FileName = DSC04035.JPG
# Iterating for FileName = DSC02936.JPG
# Iterating for FileName = 113.JPG
# Iterating for FileName = 139.JPG
# Iterating for FileName = DSC03323.JPG
# Iterating for FileName = P090903072.jpg
# Iterating for FileName = DSC02312.JPG
# Iterating for FileName = DSC02989.JPG
# Iterating for FileName = P090905003.jpg
# Iterating for FileName = DSC03012.JPG
# Iterating for FileName = 44.JPG
# Iterating for FileName = DSC04465.JPG
# Iterating for FileName = P1010116.JPG
# Iterating for FileName = DSC03657.JPG
# Iterating for FileName = DSC03136.JPG
# Iterating for FileName = DSC04203.JPG
# Iterating for FileName = DSC03522.JPG
# Iterating for FileName = DSC02993.JPG
# Iterating for FileName = DSC04033.JPG
# Iterating for FileName = P1010127.JPG
# Iterating for FileName = P1010138.JPG
# Iterating for FileName = P090831013.jpg
# Iterating for FileName = DSC03824.JPG
# Iterating for FileName = DSC03264.JPG
# Iterating for FileName = DSC03644.JPG
# Iterating for FileName = DSC02309.JPG
# Iterating for FileName = DSC02780.JPG
# Iterating for FileName = P1010123.JPG
# Iterating for FileName = 080116-0066.jpg
# Iterating for FileName = 2007-12-08-day-015.jpg
# Iterating for FileName = DSC03516.JPG
# Iterating for FileName = P090831113.jpg
# Iterating for FileName = DSC02986.JPG
# Iterating for FileName = DSC03308.JPG
# Iterating for FileName = DSC03702.JPG
# Iterating for FileName = P090912071.jpg
# Iterating for FileName = DSC02641.JPG
# Iterating for FileName = 038.JPG
# Iterating for FileName = DSC03455.JPG
# Iterating for FileName = DSC02894.JPG
# Iterating for FileName = P090831114.jpg
# Iterating for FileName = DSC02606.JPG
# Iterating for FileName = P1010004.JPG
# Iterating for FileName = DSC03520.JPG
# Iterating for FileName = DSC03670.JPG
# Iterating for FileName = DSC02970.JPG
# Iterating for FileName = DSC03411.JPG
# Iterating for FileName = DSC04091.JPG
# Iterating for FileName = DSC03112.JPG
# Iterating for FileName = IMG_2647.JPG
# Iterating for FileName = DSC04451.JPG
# Iterating for FileName = DSC03061.JPG
# Iterating for FileName = P1010060.JPG
# Iterating for FileName = DSC03673.JPG
# Iterating for FileName = DSC03517.JPG
# Iterating for FileName = DSC03737.JPG
# Iterating for FileName = DSC03006.JPG
# Iterating for FileName = 080116-0058.jpg
# Iterating for FileName = DSC04223.JPG
# Iterating for FileName = P090903041.jpg
# Iterating for FileName = DSC03575.JPG
# Iterating for FileName = DSC02374.JPG
# Iterating for FileName = DSC03467.JPG
# Iterating for FileName = DSC02919.JPG
# Iterating for FileName = DSC03548.JPG
# Iterating for FileName = P1010064.JPG
# Iterating for FileName = DSC03015.JPG
# Iterating for FileName = DSC02586.JPG
# Iterating for FileName = DSC03076.JPG
# Iterating for FileName = DSC03233.JPG
# Iterating for FileName = DSC02857.JPG
# Iterating for FileName = DSC02575.JPG
# Iterating for FileName = DSC02483.JPG
# Iterating for FileName = DSC03408.JPG
# Iterating for FileName = DSC04009.JPG
# Iterating for FileName = DSC04203.JPG
# Iterating for FileName = 2007-12-09-day-exterior-056.jpg
# Iterating for FileName = DSC04256.JPG
# Iterating for FileName = DSC02619.JPG
# Iterating for FileName = P090903022.jpg
# Iterating for FileName = 047.jpg
# Iterating for FileName = DSC04070.JPG
# Iterating for FileName = 45.JPG
# Iterating for FileName = P090831037.jpg
# Iterating for FileName = 080119-0033.jpg
# Iterating for FileName = DSC04030.JPG
# Iterating for FileName = DSC03199.JPG
# Iterating for FileName = 080116-0059.jpg
# Iterating for FileName = DSC02418.JPG
# Iterating for FileName = DSC02389.JPG
# Iterating for FileName = DSC04160.JPG
# Iterating for FileName = DSC04451.JPG
# Iterating for FileName = 142.JPG
# Iterating for FileName = 080119-0038.jpg
# Iterating for FileName = DSC03871.JPG
# Iterating for FileName = DSC03176.JPG
# Iterating for FileName = DSC03083.JPG
# Iterating for FileName = DSC02917.JPG
# Iterating for FileName = DSC02382.JPG
# Iterating for FileName = DSC04338.JPG
# Iterating for FileName = DSC03165.JPG
# Iterating for FileName = P1010020.JPG
# Iterating for FileName = DSC03652.JPG
# Iterating for FileName = DSC02711.JPG
# Iterating for FileName = DSC03440.JPG
# Iterating for FileName = DSC03265.JPG
# Iterating for FileName = DSC03711.JPG
# Iterating for FileName = 308.jpg
# Iterating for FileName = DSC02747.JPG
# Iterating for FileName = DSC04399.JPG
# Iterating for FileName = DSC02364.JPG
# Iterating for FileName = DSC03200.JPG
# Iterating for FileName = DSC03136.JPG
# Iterating for FileName = DSC03125.JPG
# Iterating for FileName = DSC03250.JPG
# Iterating for FileName = DSC02701.JPG
# Iterating for FileName = 003.JPG
# Iterating for FileName = P090903099.jpg
# Iterating for FileName = DSC04451.JPG
# Iterating for FileName = P1010062.JPG
# Iterating for FileName = DSC02954.JPG
# Iterating for FileName = DSC03732.JPG
# Iterating for FileName = DSC02772.JPG
# Iterating for FileName = DSC03830.JPG
# Iterating for FileName = DSC02461.JPG
# Iterating for FileName = P090903007.jpg
# Iterating for FileName = DSC02687.JPG
# Iterating for FileName = DSC03684.JPG
# Iterating for FileName = DSC03847.JPG
# Iterating for FileName = DSC03301.JPG
# Iterating for FileName = DSC02969.JPG
# Iterating for FileName = DSC03083.JPG
# Iterating for FileName = DSC02556.JPG
# Iterating for FileName = DSC03616.JPG
# Iterating for FileName = 2007-12-08-day-098.jpg
# Iterating for FileName = DSC02674.JPG
# Iterating for FileName = DSC04144.JPG
# Iterating for FileName = DSC02533.JPG
# Iterating for FileName = P090903076.jpg
# Iterating for FileName = DSC03980.JPG
# Iterating for FileName = DSC02398.JPG
# Iterating for FileName = DSC02777.JPG
# Iterating for FileName = DSC02500.JPG
# Iterating for FileName = DSC03125.JPG
# Iterating for FileName = P090912059.jpg
# Iterating for FileName = DSC03657.JPG
# Iterating for FileName = DSC02568.JPG
# Iterating for FileName = 2007-12-08-day-103.jpg
# Iterating for FileName = DSC02493.JPG
# Iterating for FileName = DSC03224.JPG
# Iterating for FileName = DSC03466.JPG
# Iterating for FileName = DSC02376.JPG
# Iterating for FileName = DSC02866.JPG
# Iterating for FileName = DSC02400.JPG
# Iterating for FileName = DSC04160.JPG
# Iterating for FileName = P090908006.jpg
# Iterating for FileName = DSC03689.JPG
# Iterating for FileName = DSC02696.JPG
# Iterating for FileName = 15.JPG
# Iterating for FileName = P090911016.jpg
# Iterating for FileName = DSC03149.JPG
# Iterating for FileName = P1010103.JPG
# Iterating for FileName = DSC04357.JPG
# Iterating for FileName = DSC03650.JPG
# Iterating for FileName = 118.JPG
# Iterating for FileName = 080116-0065.jpg
# Iterating for FileName = 111.jpg
# Iterating for FileName = DSC03302.JPG
# Iterating for FileName = DSC03262.JPG
# Iterating for FileName = 2007-12-09-day-exterior-063.jpg
# Iterating for FileName = P090903004.jpg
# Iterating for FileName = DSC02872.JPG
# Iterating for FileName = DSC02865.JPG
# Iterating for FileName = DSC04290.JPG
# Iterating for FileName = DSC03297.JPG
# Iterating for FileName = P1010094.JPG
# Iterating for FileName = DSC02687.JPG
# Iterating for FileName = DSC02958.JPG
# Iterating for FileName = 2007-12-08-day-106.jpg
# Iterating for FileName = DSC03062.JPG
# Iterating for FileName = P090903004.jpg
# Iterating for FileName = DSC04056.JPG
# Iterating for FileName = DSC04442.JPG
# Iterating for FileName = DSC03241.JPG
# Iterating for FileName = 080119-0017.jpg
# Iterating for FileName = P090911084.jpg
# Iterating for FileName = 080119-0007.jpg
# Iterating for FileName = DSC03249.JPG
# Iterating for FileName = DSC03017.JPG
# Iterating for FileName = DSC03684.JPG
# Iterating for FileName = P090903056.jpg
# Iterating for FileName = DSC03038.JPG
# Iterating for FileName = 080119-0015.jpg
# Iterating for FileName = DSC02434.JPG
# Iterating for FileName = P090831114.jpg
# Iterating for FileName = DSC04146.JPG
# Iterating for FileName = 064.JPG
# Iterating for FileName = P090911075.jpg
# Iterating for FileName = DSC04338.JPG
# Iterating for FileName = P090911085.jpg
# Iterating for FileName = DSC04131.JPG
# Iterating for FileName = DSC04035.JPG
# Iterating for FileName = DSC04173.JPG
# Iterating for FileName = DSC04129.JPG
# Iterating for FileName = DSC04447.JPG
# Iterating for FileName = DSC03224.JPG
# Iterating for FileName = 080116-0065.jpg
# Iterating for FileName = DSC02865.JPG
# Iterating for FileName = DSC04092.JPG
# Iterating for FileName = DSC03311.JPG
# Iterating for FileName = P090831039.jpg
# Iterating for FileName = 2007-12-08-day-099.jpg
# Iterating for FileName = DSC02419.JPG
# Iterating for FileName = DSC03132.JPG
# Iterating for FileName = DSC03119.JPG
# Iterating for FileName = DSC03078.JPG
# Iterating for FileName = DSC02732.JPG
# Iterating for FileName = DSC03839.JPG
# Iterating for FileName = 48.JPG
# Iterating for FileName = P1010069.JPG
# Iterating for FileName = DSC03025.JPG
# Iterating for FileName = DSC03986.JPG
# Iterating for FileName = DSC03741.JPG
# Iterating for FileName = DSC04151.JPG
# Iterating for FileName = DSC02434.JPG
# Iterating for FileName = DSC04360.JPG
# Iterating for FileName = DSC04087.JPG
# Iterating for FileName = DSC02610.JPG
# Iterating for FileName = P1010004.JPG
# Iterating for FileName = P090903009.jpg
# Iterating for FileName = DSC02568.JPG
# Iterating for FileName = DSC03522.JPG
# Iterating for FileName = 026.JPG
# Iterating for FileName = DSC02514.JPG
# Iterating for FileName = DSC03986.JPG
# Iterating for FileName = DSC02926.JPG
# Iterating for FileName = P1010021.JPG
# Iterating for FileName = DSC02511.JPG
# Iterating for FileName = DSC03837.JPG
# Iterating for FileName = P1010067.JPG
# Iterating for FileName = 134.JPG
# Iterating for FileName = DSC03718.JPG
# Iterating for FileName = P090905003.jpg
# Iterating for FileName = DSC03734.JPG
# Iterating for FileName = P090831062.jpg
# Iterating for FileName = DSC02602.JPG
# Iterating for FileName = DSC04149.JPG
# Iterating for FileName = DSC03654.JPG
# Iterating for FileName = DSC02867.JPG
# Iterating for FileName = DSC03410.JPG
# Iterating for FileName = DSC02854.JPG
# Iterating for FileName = DSC03674.JPG
# Iterating for FileName = DSC03301.JPG
# Iterating for FileName = DSC03224.JPG
# Iterating for FileName = 027.JPG
# Iterating for FileName = 108.JPG
# Iterating for FileName = 031.JPG
# Iterating for FileName = DSC02902.JPG
# Iterating for FileName = P1010060.JPG
# Iterating for FileName = DSC03314.JPG
# Iterating for FileName = z.jpg
# Iterating for FileName = DSC03007.JPG
# Iterating for FileName = P1010087.JPG
# Iterating for FileName = DSC02859.JPG
# Iterating for FileName = DSC03372.JPG
# Iterating for FileName = DSC02489.JPG
# Iterating for FileName = P1010069.JPG
# Iterating for FileName = DSC03896.JPG
# Iterating for FileName = P1010056.JPG
# Iterating for FileName = DSC04048.JPG
# Iterating for FileName = DSC03575.JPG
# Iterating for FileName = DSC02912.JPG
# Iterating for FileName = DSC03656.JPG
# Iterating for FileName = P1010019.JPG
# Iterating for FileName = P090831121.jpg
# Iterating for FileName = P090831007.jpg
# Iterating for FileName = P090903001.jpg
# Iterating for FileName = P090903056.jpg
# Iterating for FileName = 065.jpg
# Iterating for FileName = 1.jpg
# Iterating for FileName = DSC03820.JPG
# Iterating for FileName = DSC03439.JPG
# Iterating for FileName = DSC02776.JPG
# Iterating for FileName = DSC03823.JPG
# Iterating for FileName = f.jpg
# Iterating for FileName = DSC02448.JPG
# Iterating for FileName = P090831125.jpg
# Iterating for FileName = DSC03403.JPG
# Iterating for FileName = 029.jpg
# Iterating for FileName = P090912068.jpg
# Iterating for FileName = P090903050.jpg
# Iterating for FileName = DSC02660.JPG
# Iterating for FileName = DSC03160.JPG
# Iterating for FileName = DSC03285.JPG
# Iterating for FileName = DSC03208.JPG
# Iterating for FileName = DSC03047.JPG
# Iterating for FileName = DSC03046.JPG
# Iterating for FileName = DSC02859.JPG
# Iterating for FileName = DSC02436.JPG
# Iterating for FileName = DSC03820.JPG
# Iterating for FileName = DSC02746.JPG
# Iterating for FileName = DSC02379.JPG
# Iterating for FileName = DSC03556.JPG
# Iterating for FileName = DSC03398.JPG
# Iterating for FileName = P090831042.jpg
# Iterating for FileName = DSC04256.JPG
# Iterating for FileName = DSC03129.JPG
# Iterating for FileName = DSC02394.JPG
# Iterating for FileName = DSC03723.JPG
# Iterating for FileName = DSC04029.JPG
# Iterating for FileName = DSC03285.JPG
# Iterating for FileName = P1010021.JPG
# Iterating for FileName = DSC03255.JPG
# Iterating for FileName = P1010052.JPG
# Iterating for FileName = DSC03711.JPG
# Iterating for FileName = DSC02427.JPG
# Iterating for FileName = P090911016.jpg
# Iterating for FileName = DSC03664.JPG
# Iterating for FileName = DSC04233.JPG
# Iterating for FileName = DSC04120.JPG
# Iterating for FileName = DSC04401.JPG
# Iterating for FileName = DSC02585.JPG
# Iterating for FileName = P1010137.JPG
# Iterating for FileName = 080116-0058.jpg
# Iterating for FileName = DSC02471.JPG
# Iterating for FileName = 118.JPG
# Iterating for FileName = DSC02398.JPG
# Iterating for FileName = P090911050.jpg
# Iterating for FileName = DSC02724.JPG
# Iterating for FileName = DSC04109.JPG
# Iterating for FileName = 026.JPG
# Iterating for FileName = DSC02854.JPG
# Iterating for FileName = P090831114.jpg
# Iterating for FileName = 118.JPG
# Iterating for FileName = DSC03300.JPG
# Iterating for FileName = DSC03943.JPG
# Iterating for FileName = DSC03001.JPG
# Iterating for FileName = DSC02647.JPG
# Iterating for FileName = DSC02751.JPG
# Iterating for FileName = DSC02664.JPG
# Iterating for FileName = DSC04447.JPG
# Iterating for FileName = DSC04183.JPG
# Iterating for FileName = 2007-12-09-day-exterior-023.jpg
# Iterating for FileName = P090831075.jpg
# Iterating for FileName = P090831010.jpg
# Iterating for FileName = 119.JPG
# Iterating for FileName = DSC02430.JPG
# Iterating for FileName = P090902016.jpg
# Iterating for FileName = DSC02861.JPG
# Iterating for FileName = 31.JPG
# Iterating for FileName = DSC03012.JPG
# Iterating for FileName = P090903004.jpg
# Iterating for FileName = DSC04434.JPG
# Iterating for FileName = DSC02881.JPG
# Iterating for FileName = DSC03257.JPG
# Iterating for FileName = DSC03328.JPG
# Iterating for FileName = 2007-12-08-day-117.jpg
# Iterating for FileName = DSC03187.JPG
# Iterating for FileName = DSC02551.JPG
# Iterating for FileName = DSC03544.JPG
# Iterating for FileName = DSC03472.JPG
# Iterating for FileName = 047.jpg
# Iterating for FileName = 089.jpg
# Iterating for FileName = P090831114.jpg
# Iterating for FileName = DSC03130.JPG
# Iterating for FileName = DSC03031.JPG
# Iterating for FileName = DSC03224.JPG
# Iterating for FileName = DSC03131.JPG
# Iterating for FileName = DSC03328.JPG
# Iterating for FileName = DSC02857.JPG
# Iterating for FileName = P090903004.jpg
# Iterating for FileName = DSC03324.JPG
# Iterating for FileName = DSC03819.JPG
# Iterating for FileName = 101.JPG
# Iterating for FileName = P1010152.JPG
# Iterating for FileName = P090903030.jpg
# Iterating for FileName = DSC02574.JPG
# Iterating for FileName = P1010095.JPG
# Iterating for FileName = P090831015.jpg
# Iterating for FileName = DSC02382.JPG
# Iterating for FileName = 2007-12-08-day-113.jpg
# Iterating for FileName = DSC03187.JPG
# Iterating for FileName = DSC03189.JPG
# Iterating for FileName = DSC03435.JPG
# Iterating for FileName = DSC03185.JPG
# Iterating for FileName = DSC03054.JPG
# Iterating for FileName = DSC03478.JPG
# Iterating for FileName = DSC03085.JPG
# Iterating for FileName = DSC03269.JPG
# Iterating for FileName = DSC04338.JPG
# Iterating for FileName = DSC03150.JPG
# Iterating for FileName = DSC02427.JPG
# Iterating for FileName = m.jpg
# Iterating for FileName = DSC03210.JPG
# Iterating for FileName = P1010013.JPG
# Iterating for FileName = DSC04019.JPG
# Iterating for FileName = DSC03586.JPG
# Iterating for FileName = DSC02519.JPG
# Iterating for FileName = DSC04447.JPG
# Iterating for FileName = P090831045.jpg
# Iterating for FileName = DSC03276.JPG
# Iterating for FileName = DSC02513.JPG
# Iterating for FileName = DSC04122.JPG
# Iterating for FileName = DSC02902.JPG
# Iterating for FileName = DSC03264.JPG
# Iterating for FileName = DSC04066.JPG
# Iterating for FileName = z.jpg
# Iterating for FileName = P1010007.JPG
# Iterating for FileName = DSC04338.JPG
# Iterating for FileName = DSC03500.JPG
# Iterating for FileName = DSC03312.JPG
# Iterating for FileName = DSC03306.JPG
# Iterating for FileName = DSC03759.JPG
# Iterating for FileName = DSC02804.JPG
# Iterating for FileName = DSC02609.JPG
# Iterating for FileName = DSC03312.JPG
# Iterating for FileName = DSC03053.JPG
# Iterating for FileName = DSC03430.JPG
# Iterating for FileName = DSC03707.JPG
# Iterating for FileName = DSC03165.JPG
# Iterating for FileName = P090912047.jpg
# Iterating for FileName = 2007-12-08-day-092.jpg
# Iterating for FileName = DSC02489.JPG
# Iterating for FileName = DSC03135.JPG
# Iterating for FileName = DSC02788.JPG
# Iterating for FileName = DSC03177.JPG
# Iterating for FileName = DSC02919.JPG
# Iterating for FileName = DSC03656.JPG
# Iterating for FileName = DSC04079.JPG
# Iterating for FileName = DSC04410.JPG
# Iterating for FileName = 8.jpg
# Iterating for FileName = 080116-0057.jpg
# Iterating for FileName = DSC03023.JPG
# Iterating for FileName = 2007-12-08-day-137.jpg
# Iterating for FileName = DSC03294.JPG
# Iterating for FileName = 025.jpg
# Iterating for FileName = P090831011.jpg
# Iterating for FileName = DSC03305.JPG
# Iterating for FileName = DSC03147.JPG
# Iterating for FileName = DSC02872.JPG
# Iterating for FileName = DSC02755.JPG
# Iterating for FileName = DSC03255.JPG
# Iterating for FileName = 2007-12-09-day-exterior-078.jpg
# Iterating for FileName = DSC04433.JPG
# Iterating for FileName = DSC03867.JPG
# Iterating for FileName = DSC02573.JPG
# Iterating for FileName = DSC02323.JPG
# Iterating for FileName = DSC03207.JPG
# Iterating for FileName = DSC02711.JPG
# Iterating for FileName = DSC03439.JPG
# Iterating for FileName = DSC02785.JPG
# Iterating for FileName = DSC02660.JPG
# Iterating for FileName = 43.JPG
# Iterating for FileName = DSC02460.JPG
# Iterating for FileName = DSC02894.JPG
# Iterating for FileName = DSC03544.JPG
# Iterating for FileName = DSC02411.JPG
# Iterating for FileName = DSC03292.JPG
# Iterating for FileName = DSC03067.JPG
# Iterating for FileName = P090905002.jpg
# Iterating for FileName = DSC03549.JPG
# Iterating for FileName = DSC03534.JPG
# Iterating for FileName = P090908006.jpg
# Iterating for FileName = P1010026.JPG
# Iterating for FileName = DSC02559.JPG
# Iterating for FileName = DSC03887.JPG
# Iterating for FileName = DSC02804.JPG
# Iterating for FileName = 080119-0020.jpg
# Iterating for FileName = DSC03745.JPG
# Iterating for FileName = DSC02940.JPG
# Iterating for FileName = P1010137.JPG
# Iterating for FileName = 086.JPG
# Iterating for FileName = DSC04091.JPG
# Iterating for FileName = 014.JPG
# Iterating for FileName = P1010025.JPG
# Iterating for FileName = DSC02356.JPG
# Iterating for FileName = DSC03678.JPG
# Iterating for FileName = DSC03631.JPG
# Iterating for FileName = P1010057.JPG
# Iterating for FileName = DSC02733.JPG
# Iterating for FileName = 080116-0084.jpg
# Iterating for FileName = DSC02423.JPG
# Iterating for FileName = DSC03161.JPG
# Iterating for FileName = DSC04047.JPG
# Iterating for FileName = DSC02408.JPG
# Iterating for FileName = DSC03620.JPG
# Iterating for FileName = DSC04032.JPG
# Iterating for FileName = DSC03145.JPG
# Iterating for FileName = DSC03571.JPG
# Iterating for FileName = DSC02502.JPG
# Iterating for FileName = DSC03765.JPG
# Iterating for FileName = P1010007.JPG
# Iterating for FileName = DSC03310.JPG
# Iterating for FileName = DSC03532.JPG
# Iterating for FileName = DSC02394.JPG
# Iterating for FileName = DSC03552.JPG
# Iterating for FileName = DSC03121.JPG
# Iterating for FileName = DSC04031.JPG
# Iterating for FileName = DSC03129.JPG
# Iterating for FileName = 009.JPG
# Iterating for FileName = DSC02874.JPG
# Iterating for FileName = DSC02842.JPG
# Iterating for FileName = DSC03015.JPG
# Iterating for FileName = DSC03151.JPG
# Iterating for FileName = DSC02559.JPG
# Iterating for FileName = DSC04055.JPG
# Iterating for FileName = 080119-0007.jpg
# Iterating for FileName = DSC02864.JPG
# Iterating for FileName = DSC03986.JPG
# Iterating for FileName = P1010056.JPG
# Iterating for FileName = P1010063.JPG
# Iterating for FileName = DSC03867.JPG
# Iterating for FileName = DSC04200.JPG
# Iterating for FileName = DSC04465.JPG
# Iterating for FileName = P1010155.JPG
# Iterating for FileName = DSC03719.JPG
# Iterating for FileName = DSC03118.JPG
# Iterating for FileName = 055.JPG
# Iterating for FileName = DSC03909.JPG
# Iterating for FileName = 097.jpg
# Iterating for FileName = 7.jpg
# Iterating for FileName = DSC03737.JPG
# Iterating for FileName = DSC03478.JPG
# Iterating for FileName = DSC02673.JPG
# Iterating for FileName = DSC02676.JPG
# Iterating for FileName = DSC03947.JPG
# Iterating for FileName = DSC02954.JPG
# Iterating for FileName = 20.JPG
# Iterating for FileName = DSC03015.JPG
# Iterating for FileName = DSC03651.JPG
# Iterating for FileName = DSC03483.JPG
# Iterating for FileName = P090831012.jpg
# Iterating for FileName = P090831122.jpg
# Iterating for FileName = DSC03245.JPG
# Iterating for FileName = DSC03483.JPG
# Iterating for FileName = DSC03212.JPG
# Iterating for FileName = P090904004.jpg
# Iterating for FileName = DSC03124.JPG
# Iterating for FileName = DSC03682.JPG
# Iterating for FileName = DSC02857.JPG
# Iterating for FileName = DSC03548.JPG
# Iterating for FileName = DSC02940.JPG
# Iterating for FileName = DSC03176.JPG
# Iterating for FileName = DSC03277.JPG
# Iterating for FileName = DSC03901.JPG
# Iterating for FileName = DSC02794.JPG
# Iterating for FileName = DSC03051.JPG
# Iterating for FileName = DSC03125.JPG
# Iterating for FileName = DSC03604.JPG
# Iterating for FileName = DSC02323.JPG
# Iterating for FileName = DSC02893.JPG
# Iterating for FileName = P1010016.JPG
# Iterating for FileName = P090903030.jpg
# Iterating for FileName = DSC02739.JPG
# Iterating for FileName = DSC03332.JPG
# Iterating for FileName = DSC03134.JPG
# Iterating for FileName = DSC02609.JPG
# Iterating for FileName = DSC04256.JPG
# Iterating for FileName = DSC02980.JPG
# Iterating for FileName = P090911085.jpg
# Iterating for FileName = 032.jpg
# Iterating for FileName = DSC03306.JPG
# Iterating for FileName = P090903081.jpg
# Iterating for FileName = DSC02954.JPG
# Iterating for FileName = P1010027.JPG
# Iterating for FileName = DSC03561.JPG
# Iterating for FileName = DSC03267.JPG
# Iterating for FileName = P1010006.JPG
# Iterating for FileName = DSC02927.JPG
# Iterating for FileName = 117.JPG
# Iterating for FileName = DSC02895.JPG
# Iterating for FileName = DSC02647.JPG
# Iterating for FileName = DSC03918.JPG
# Iterating for FileName = DSC03918.JPG
# Iterating for FileName = P1010088.JPG
# Iterating for FileName = 080116-0058.jpg
# Iterating for FileName = DSC03331.JPG
# Iterating for FileName = DSC02357.JPG
# Iterating for FileName = DSC03307.JPG
# Iterating for FileName = P090903003.jpg
# Iterating for FileName = DSC04399.JPG
# Iterating for FileName = DSC02243.JPG
# Iterating for FileName = DSC04304.JPG
# Iterating for FileName = P090905007.jpg
# Iterating for FileName = DSC03478.JPG
# Iterating for FileName = DSC02524.JPG
# Iterating for FileName = DSC04464.JPG
# Iterating for FileName = 113.jpg
# Iterating for FileName = 080116-0065.jpg
# Iterating for FileName = P090831005.jpg
# Iterating for FileName = 080120-0001.jpg
# Iterating for FileName = P1010116.JPG
# Iterating for FileName = s.jpg
# Iterating for FileName = 082.JPG
# Iterating for FileName = DSC03440.JPG
# Iterating for FileName = DSC02400.JPG
# Iterating for FileName = s.jpg
# Iterating for FileName = DSC04349.JPG
# Iterating for FileName = DSC02482.JPG
# Iterating for FileName = 080118-0011.jpg
# Iterating for FileName = 032.jpg
# Iterating for FileName = DSC03329.JPG
# Iterating for FileName = P1010069.JPG
# Iterating for FileName = DSC03429.JPG
# Iterating for FileName = DSC02859.JPG
# Iterating for FileName = DSC02466.JPG
# Iterating for FileName = DSC03439.JPG
# Iterating for FileName = DSC02430.JPG
# Iterating for FileName = DSC02567.JPG
# Iterating for FileName = DSC03489.JPG
# Iterating for FileName = DSC02418.JPG
# Iterating for FileName = P1010025.JPG
# Iterating for FileName = P090902016.jpg
# Iterating for FileName = DSC02575.JPG
# Iterating for FileName = DSC03579.JPG
# Iterating for FileName = DSC03581.JPG
# Iterating for FileName = DSC04032.JPG
# Iterating for FileName = P1010019.JPG
# Iterating for FileName = DSC04094.JPG
# Iterating for FileName = DSC03883.JPG
# Iterating for FileName = 080119-0012.jpg
# Iterating for FileName = DSC02912.JPG
# Iterating for FileName = DSC02993.JPG
# Iterating for FileName = 078.JPG
# Iterating for FileName = DSC04434.JPG
# Iterating for FileName = DSC03396.JPG
# Iterating for FileName = DSC02719.JPG
# Iterating for FileName = DSC04443.JPG
# Iterating for FileName = DSC03517.JPG
# Iterating for FileName = 038.JPG
# Iterating for FileName = DSC03631.JPG
# Iterating for FileName = P090912047.jpg
# Iterating for FileName = DSC02493.JPG
# Iterating for FileName = P1010007.JPG
# Iterating for FileName = DSC02350.JPG
# Iterating for FileName = DSC02317.JPG
# Iterating for FileName = P1010090.JPG
# Iterating for FileName = DSC03273.JPG
# Iterating for FileName = P090903008.jpg
# Iterating for FileName = DSC04449.JPG
# Iterating for FileName = DSC03429.JPG
# Iterating for FileName = 2007-12-09-day-exterior-047.jpg
# Iterating for FileName = 10.JPG
# Iterating for FileName = P090908006.jpg
# Iterating for FileName = 42.JPG
# Iterating for FileName = P1010026.JPG
# Iterating for FileName = DSC02619.JPG
# Iterating for FileName = 44.JPG
# Iterating for FileName = 114.jpg
# Iterating for FileName = DSC03141.JPG
# Iterating for FileName = DSC04401.JPG
# Iterating for FileName = P1010093.JPG
# Iterating for FileName = DSC04318.JPG
# Iterating for FileName = DSC02664.JPG
# Iterating for FileName = P1010120.JPG
# Iterating for FileName = DSC02519.JPG
# Iterating for FileName = DSC02493.JPG
# Iterating for FileName = DSC03711.JPG
# Iterating for FileName = DSC02676.JPG
# Iterating for FileName = 4.jpg
# Iterating for FileName = DSC03196.JPG
# Iterating for FileName = DSC02861.JPG
# Iterating for FileName = DSC02590.JPG
# Iterating for FileName = DSC03081.JPG
# Iterating for FileName = 029.jpg
# Iterating for FileName = P1010027.JPG
# Iterating for FileName = DSC02450.JPG
# Iterating for FileName = DSC02436.JPG
# Iterating for FileName = P090831121.jpg
# Iterating for FileName = 080116-0060.jpg
# Iterating for FileName = DSC04072.JPG
# Iterating for FileName = DSC02623.JPG
# Iterating for FileName = 049.JPG
# Iterating for FileName = DSC04014.JPG
# Iterating for FileName = P1010093.JPG
# Iterating for FileName = DSC04131.JPG
# Iterating for FileName = P090911086.jpg
# Iterating for FileName = DSC02776.JPG
# Iterating for FileName = DSC03628.JPG
# Iterating for FileName = DSC02756.JPG
# Iterating for FileName = P090905002.jpg
# Iterating for FileName = DSC03291.JPG
# Iterating for FileName = DSC04072.JPG
# Iterating for FileName = DSC04464.JPG
# Iterating for FileName = DSC02545.JPG
# Iterating for FileName = DSC03200.JPG
# Iterating for FileName = P1010120.JPG
# Iterating for FileName = DSC02368.JPG
# Iterating for FileName = DSC03478.JPG
# Iterating for FileName = P090831023.jpg
# Iterating for FileName = DSC02803.JPG
# Iterating for FileName = DSC03396.JPG
# Iterating for FileName = DSC03604.JPG
# Iterating for FileName = DSC04091.JPG
# Iterating for FileName = DSC03365.JPG
# Iterating for FileName = DSC03050.JPG
# Iterating for FileName = P1010075.JPG
# Iterating for FileName = 137.JPG
# Iterating for FileName = DSC03781.JPG
# Iterating for FileName = DSC04447.JPG
# Iterating for FileName = DSC03925.JPG
# Iterating for FileName = DSC02555.JPG
# Iterating for FileName = P090905003.jpg
# Iterating for FileName = DSC02969.JPG
# Iterating for FileName = DSC04338.JPG
# Iterating for FileName = DSC02579.JPG
# Iterating for FileName = DSC04451.JPG
# Iterating for FileName = DSC02358.JPG
# Iterating for FileName = 076.JPG
# Iterating for FileName = 080119-0008.jpg
# Iterating for FileName = DSC02349.JPG
# Iterating for FileName = DSC03667.JPG
# Iterating for FileName = DSC03200.JPG
# Iterating for FileName = DSC03165.JPG
# Iterating for FileName = DSC02912.JPG
# Iterating for FileName = DSC03311.JPG
# Iterating for FileName = DSC03691.JPG
# Iterating for FileName = DSC02791.JPG
# Iterating for FileName = DSC04431.JPG
# Iterating for FileName = DSC04318.JPG
# Iterating for FileName = DSC02613.JPG
# Iterating for FileName = DSC02325.JPG
# Iterating for FileName = DSC04115.JPG
# Iterating for FileName = DSC03118.JPG
# Iterating for FileName = DSC03823.JPG
# Iterating for FileName = DSC04434.JPG
# Iterating for FileName = DSC03054.JPG
# Iterating for FileName = DSC03210.JPG
# Iterating for FileName = DSC02501.JPG
# Iterating for FileName = DSC02724.JPG
# Iterating for FileName = P090912059.jpg
# Iterating for FileName = 054.JPG
# Iterating for FileName = 108.JPG
# Iterating for FileName = 080116-0057.jpg
# Iterating for FileName = DSC02859.JPG
# Iterating for FileName = DSC02639.JPG
# Iterating for FileName = DSC04098.JPG
# Iterating for FileName = DSC03662.JPG
# Iterating for FileName = DSC03031.JPG
# Iterating for FileName = DSC03038.JPG
# Iterating for FileName = DSC02610.JPG
# Iterating for FileName = 104.jpg
# Iterating for FileName = DSC03998.JPG
# Iterating for FileName = P1010094.JPG
# Iterating for FileName = P1010090.JPG
# Iterating for FileName = DSC03842.JPG
# Iterating for FileName = P090912047.jpg
# Iterating for FileName = P1010138.JPG
# Iterating for FileName = DSC02928.JPG
# Iterating for FileName = DSC03732.JPG
# Iterating for FileName = DSC04330.JPG
# Iterating for FileName = DSC03637.JPG
# Iterating for FileName = 110.jpg
# Iterating for FileName = DSC03199.JPG
# Iterating for FileName = DSC04048.JPG
# Iterating for FileName = DSC02687.JPG
# Iterating for FileName = DSC03283.JPG
# Iterating for FileName = DSC04349.JPG
# Iterating for FileName = DSC02801.JPG
# Iterating for FileName = DSC03786.JPG
# Iterating for FileName = P090904005.jpg
# Iterating for FileName = DSC03245.JPG
# Iterating for FileName = DSC04087.JPG
# Iterating for FileName = DSC03151.JPG
# Iterating for FileName = 008.JPG
# Iterating for FileName = DSC02306.JPG
# Iterating for FileName = DSC03691.JPG
# Iterating for FileName = 086.JPG
# Iterating for FileName = DSC03294.JPG
# Iterating for FileName = 055.JPG
# Iterating for FileName = DSC03161.JPG
# Iterating for FileName = P1010114.JPG
# Iterating for FileName = DSC02964.JPG
# Iterating for FileName = DSC03314.JPG
# Iterating for FileName = P090911081.jpg
# Iterating for FileName = DSC03170.JPG
# Iterating for FileName = P090903055.jpg
# Iterating for FileName = DSC03143.JPG
# Iterating for FileName = DSC03412.JPG
# Iterating for FileName = P090902016.jpg
# Iterating for FileName = P090831023.jpg
# Iterating for FileName = P1010156.JPG
# Iterating for FileName = P1010065.JPG
# Iterating for FileName = DSC03260.JPG
# Iterating for FileName = DSC03033.JPG
# Iterating for FileName = DSC04290.JPG
# Iterating for FileName = IMG_2618.JPG
# Iterating for FileName = DSC03821.JPG
# Iterating for FileName = 025.JPG
# Iterating for FileName = DSC04151.JPG
# Iterating for FileName = DSC03831.JPG
# Iterating for FileName = t.jpg
# Iterating for FileName = DSC03501.JPG
# Iterating for FileName = DSC02674.JPG
# Iterating for FileName = DSC02910.JPG
# Iterating for FileName = DSC03773.JPG
# Iterating for FileName = DSC03033.JPG
# Iterating for FileName = DSC04409.JPG
# Iterating for FileName = P090831019.jpg
# Iterating for FileName = DSC03651.JPG
# Iterating for FileName = DSC03331.JPG
# Iterating for FileName = DSC03517.JPG
# Iterating for FileName = DSC02423.JPG
# Iterating for FileName = DSC02788.JPG
# Iterating for FileName = DSC04150.JPG
# Iterating for FileName = DSC03074.JPG
# Iterating for FileName = DSC03569.JPG
# Iterating for FileName = 2007-12-08-day-103.jpg
# Iterating for FileName = 049.JPG
# Iterating for FileName = P1010137.JPG
# Iterating for FileName = P090903050.jpg
# Iterating for FileName = DSC02791.JPG
# Iterating for FileName = DSC04015.JPG
# Iterating for FileName = 080119-0017.jpg
# Iterating for FileName = P1010086.JPG
# Iterating for FileName = 7.jpg
# Iterating for FileName = DSC04115.JPG
# Iterating for FileName = 138.JPG
# Iterating for FileName = P1010063.JPG
# Iterating for FileName = DSC03679.JPG
# Iterating for FileName = P090903092.jpg
# Iterating for FileName = DSC02490.JPG
# Iterating for FileName = DSC03131.JPG
# Iterating for FileName = 047.JPG
# Iterating for FileName = P1010084.JPG
# Iterating for FileName = DSC02886.JPG
# Iterating for FileName = P090831005.jpg
# Iterating for FileName = P090903022.jpg
# Iterating for FileName = DSC03660.JPG
# Iterating for FileName = DSC03125.JPG

# %%
display(df)
# Out:
#          score status matched      time
# 0            0      0   False  0.193809
# 1     0.631579      0    True  0.124048
# 2          0.8      0    True  0.175187
# 3     0.354839      0    True  0.237938
# 4     0.461538      0    True  0.145799
# ...        ...    ...     ...       ...
# 1175  0.785714      0    True  0.264928
# 1176  0.692308      0    True  0.129097
# 1177         0     -1   False  0.000843
# 1178         0      0   False  0.166199
# 1179         1      0    True  0.094233
#
# [1180 rows x 4 columns]
