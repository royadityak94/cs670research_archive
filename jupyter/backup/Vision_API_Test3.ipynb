# %%
import argparse
from google.oauth2 import service_account
from google.cloud import vision
import matplotlib.pyplot as plt
import cv2
import io
import re
import numpy as np
import os
import xml.etree.ElementTree as ET 
from utilities.score_computors import are_sentences_alike

# %%
dir_path = 'datasets/KAIST/English/'
MAX_TRAINING = 1180 #5

# %%
def extract_clean_str(original_str):
    return re.sub('[^a-zA-Z0-9]+', ' ', original_str, flags=re.UNICODE).lower().strip().replace(' ', '')

def get_mapped(path):
    key_map, dict_idx = {}, 0
    for r, _, f in os.walk(dir_path):
        for file in f:
            if '.JPG' in file or '.jpg' in file:
                key_map[dict_idx] = file
                dict_idx += 1
    idxs = list(key_map.keys())          
    shuffled_idxs = np.random.randint(0, len(idxs), len(idxs))
    return key_map, shuffled_idxs

def fetch_from_xml(path, file):
    tree = ET.parse(os.path.join(path, file)).getroot()  
    return extract_clean_str(''.join([e.attrib['char'] for e in tree.iter(tag='character')]))

# %%
dict_files, files_idx = get_mapped(dir_path)
shuffled_idx = np.random.randint(0, len(files_idx), len(files_idx))
vision_client = vision.ImageAnnotatorClient()
correct_pred, total_pred = 0, 0

for idx in shuffled_idx:
    file = dict_files.get(idx)
    print ("Iterating for file = {}".format(file))
    xml_file = file[:len(file)-4] + '.xml' 
    
    if not os.path.exists(os.path.join(dir_path, xml_file)):
        continue
    ground_truth_str = fetch_from_xml(dir_path, xml_file)
    
    if len(ground_truth_str) == 0:
        continue
    with io.open(os.path.join(dir_path, file), 'rb') as image_file:
        content = (image_file.read())
    image = vision.types.Image(content=content)
    text_detection_response = vision_client.text_detection(image=image)
    detected_str = extract_clean_str(text_detection_response.full_text_annotation.text)
    
    if are_sentences_alike(detected_str, ground_truth_str, .6) and len(detected_str) != 0:
        correct_pred += 1
    
    total_pred += 1
    if total_pred >= MAX_TRAINING:
        break
# Out:
# Iterating for file = 44.JPG
# Iterating for file = 090.jpg
# Iterating for file = DSC02382.JPG
# Iterating for file = DSC03631.JPG
# Iterating for file = 054.JPG
# Iterating for file = P1010113.JPG
# Iterating for file = DSC03135.JPG
# Iterating for file = P090912050.jpg
# Iterating for file = DSC03613.JPG
# Iterating for file = 086.jpg
# Iterating for file = 2007-12-09-day-exterior-032.jpg
# Iterating for file = DSC03176.JPG
# Iterating for file = DSC03294.JPG
# Iterating for file = DSC02429.JPG
# Iterating for file = DSC04451.JPG
# Iterating for file = DSC02379.JPG
# Iterating for file = DSC04057.JPG
# Iterating for file = DSC03519.JPG
# Iterating for file = DSC02919.JPG
# Iterating for file = P090831012.jpg
# Iterating for file = DSC04246.JPG
# Iterating for file = DSC02937.JPG
# Iterating for file = 001.jpg
# Iterating for file = DSC02624.JPG
# Iterating for file = DSC03081.JPG
# Iterating for file = DSC03167.JPG
# Iterating for file = DSC04104.JPG
# Iterating for file = DSC04431.JPG
# Iterating for file = DSC03432.JPG
# Iterating for file = DSC03367.JPG
# Iterating for file = DSC04086.JPG
# Iterating for file = DSC04200.JPG
# Iterating for file = P1010156.JPG
# Iterating for file = 2007-12-08-day-111.jpg
# Iterating for file = DSC04163.JPG
# Iterating for file = DSC04249.JPG
# Iterating for file = 097.jpg
# Iterating for file = DSC03890.JPG
# Iterating for file = IMG_2481.JPG
# Iterating for file = 142.JPG
# Iterating for file = DSC03830.JPG
# Iterating for file = DSC03909.JPG
# Iterating for file = DSC03652.JPG
# Iterating for file = DSC04155.JPG
# Iterating for file = DSC03582.JPG
# Iterating for file = DSC02938.JPG
# Iterating for file = P1010045.JPG
# Iterating for file = DSC03479.JPG
# Iterating for file = DSC02483.JPG
# Iterating for file = DSC03267.JPG
# Iterating for file = DSC03707.JPG
# Iterating for file = DSC04108.JPG
# Iterating for file = DSC04318.JPG
# Iterating for file = DSC03396.JPG
# Iterating for file = 055.JPG
# Iterating for file = DSC02377.JPG
# Iterating for file = DSC03284.JPG
# Iterating for file = P1010007.JPG
# Iterating for file = DSC02940.JPG
# Iterating for file = 027.jpg
# Iterating for file = DSC03331.JPG
# Iterating for file = DSC03657.JPG
# Iterating for file = 080119-0009.jpg
# Iterating for file = 105.jpg
# Iterating for file = DSC03401.JPG
# Iterating for file = DSC03332.JPG
# Iterating for file = DSC03723.JPG
# Iterating for file = P090911087.jpg
# Iterating for file = DSC03439.JPG
# Iterating for file = DSC03081.JPG
# Iterating for file = DSC04091.JPG
# Iterating for file = DSC03847.JPG
# Iterating for file = DSC02755.JPG
# Iterating for file = P090911080.jpg
# Iterating for file = DSC03986.JPG
# Iterating for file = DSC03820.JPG
# Iterating for file = DSC02718.JPG
# Iterating for file = DSC03168.JPG
# Iterating for file = DSC03048.JPG
# Iterating for file = P090912040.jpg
# Iterating for file = DSC02802.JPG
# Iterating for file = DSC03084.JPG
# Iterating for file = DSC04312.JPG
# Iterating for file = DSC03406.JPG
# Iterating for file = DSC03652.JPG
# Iterating for file = DSC03290.JPG
# Iterating for file = DSC03025.JPG
# Iterating for file = DSC03531.JPG
# Iterating for file = DSC04056.JPG
# Iterating for file = DSC04173.JPG
# Iterating for file = DSC03430.JPG
# Iterating for file = DSC03093.JPG
# Iterating for file = 032.jpg
# Iterating for file = 26.JPG
# Iterating for file = DSC04094.JPG
# Iterating for file = DSC03227.JPG
# Iterating for file = DSC04031.JPG
# Iterating for file = DSC03294.JPG
# Iterating for file = DSC03402.JPG
# Iterating for file = DSC04290.JPG
# Iterating for file = DSC03718.JPG
# Iterating for file = DSC03401.JPG
# Iterating for file = DSC02920.JPG
# Iterating for file = DSC03959.JPG
# Iterating for file = DSC04249.JPG
# Iterating for file = 047.JPG
# Iterating for file = DSC02771.JPG
# Iterating for file = DSC03332.JPG
# Iterating for file = DSC02242.JPG
# Iterating for file = DSC03212.JPG
# Iterating for file = DSC02940.JPG
# Iterating for file = P090831005.jpg
# Iterating for file = DSC02724.JPG
# Iterating for file = DSC03786.JPG
# Iterating for file = IMG_2647.JPG
# Iterating for file = DSC02859.JPG
# Iterating for file = DSC03489.JPG
# Iterating for file = DSC03467.JPG
# Iterating for file = 080.JPG
# Iterating for file = 080119-0014.jpg
# Iterating for file = DSC03060.JPG
# Iterating for file = DSC02519.JPG
# Iterating for file = 065.jpg
# Iterating for file = 080116-0089.jpg
# Iterating for file = P1010073.JPG
# Iterating for file = DSC03054.JPG
# Iterating for file = 26.JPG
# Iterating for file = DSC03609.JPG
# Iterating for file = DSC03935.JPG
# Iterating for file = 065.jpg
# Iterating for file = 078.JPG
# Iterating for file = DSC03581.JPG
# Iterating for file = 6.jpg
# Iterating for file = DSC03711.JPG
# Iterating for file = DSC03315.JPG
# Iterating for file = P1010116.JPG
# Iterating for file = DSC04131.JPG
# Iterating for file = 2007-12-09-day-exterior-086.jpg
# Iterating for file = DSC02897.JPG
# Iterating for file = DSC02756.JPG
# Iterating for file = P090903081.jpg
# Iterating for file = DSC04461.JPG
# Iterating for file = DSC03631.JPG
# Iterating for file = DSC02557.JPG
# Iterating for file = DSC04144.JPG
# Iterating for file = DSC03015.JPG
# Iterating for file = P1010085.JPG
# Iterating for file = DSC04306.JPG
# Iterating for file = 2007-12-09-day-exterior-051.jpg
# Iterating for file = DSC02480.JPG
# Iterating for file = P1010024.JPG
# Iterating for file = DSC02352.JPG
# Iterating for file = DSC02780.JPG
# Iterating for file = P090831077.jpg
# Iterating for file = DSC02323.JPG
# Iterating for file = DSC04104.JPG
# Iterating for file = DSC03150.JPG
# Iterating for file = IMG_2618.JPG
# Iterating for file = DSC04323.JPG
# Iterating for file = DSC02964.JPG
# Iterating for file = DSC04404.JPG
# Iterating for file = 129.JPG
# Iterating for file = P090903041.jpg
# Iterating for file = DSC03759.JPG
# Iterating for file = DSC04013.JPG
# Iterating for file = DSC03196.JPG
# Iterating for file = DSC03830.JPG
# Iterating for file = 080119-0003.jpg
# Iterating for file = DSC02545.JPG
# Iterating for file = DSC03839.JPG
# Iterating for file = 10.JPG
# Iterating for file = DSC04094.JPG
# Iterating for file = DSC03242.JPG
# Iterating for file = DSC03631.JPG
# Iterating for file = 17.JPG
# Iterating for file = DSC02344.JPG
# Iterating for file = DSC04314.JPG
# Iterating for file = DSC03412.JPG
# Iterating for file = DSC03401.JPG
# Iterating for file = P090911071.jpg
# Iterating for file = DSC02364.JPG
# Iterating for file = DSC02746.JPG
# Iterating for file = DSC02958.JPG
# Iterating for file = DSC03918.JPG
# Iterating for file = 2007-12-08-day-099.jpg
# Iterating for file = 105.jpg
# Iterating for file = t.jpg
# Iterating for file = DSC03309.JPG
# Iterating for file = P090903030.jpg
# Iterating for file = 2007-12-08-day-044.jpg
# Iterating for file = DSC02384.JPG
# Iterating for file = 2007-12-08-day-099.jpg
# Iterating for file = DSC04360.JPG
# Iterating for file = DSC04397.JPG
# Iterating for file = DSC03217.JPG
# Iterating for file = 081.JPG
# Iterating for file = DSC04463.JPG
# Iterating for file = DSC03745.JPG
# Iterating for file = DSC03119.JPG
# Iterating for file = DSC04052.JPG
# Iterating for file = DSC02556.JPG
# Iterating for file = P090903015.jpg
# Iterating for file = DSC04364.JPG
# Iterating for file = DSC02585.JPG
# Iterating for file = DSC03273.JPG
# Iterating for file = DSC03331.JPG
# Iterating for file = P1010103.JPG
# Iterating for file = DSC03439.JPG
# Iterating for file = DSC03004.JPG
# Iterating for file = P090831016.jpg
# Iterating for file = P090903008.jpg
# Iterating for file = 2007-12-08-day-118.jpg
# Iterating for file = 2007-12-08-day-106.jpg
# Iterating for file = DSC03655.JPG
# Iterating for file = DSC03662.JPG
# Iterating for file = DSC03998.JPG
# Iterating for file = DSC04244.JPG
# Iterating for file = 107.jpg
# Iterating for file = DSC04401.JPG
# Iterating for file = 58.JPG
# Iterating for file = DSC02919.JPG
# Iterating for file = DSC04072.JPG
# Iterating for file = 26.JPG
# Iterating for file = DSC03401.JPG
# Iterating for file = DSC02964.JPG
# Iterating for file = DSC04357.JPG
# Iterating for file = 133.JPG
# Iterating for file = IMG_2647.JPG
# Iterating for file = DSC02384.JPG
# Iterating for file = DSC02568.JPG
# Iterating for file = DSC04223.JPG
# Iterating for file = P1010120.JPG
# Iterating for file = DSC02344.JPG
# Iterating for file = DSC03187.JPG
# Iterating for file = DSC04019.JPG
# Iterating for file = DSC03724.JPG
# Iterating for file = DSC02349.JPG
# Iterating for file = P090903072.jpg
# Iterating for file = P090903030.jpg
# Iterating for file = DSC02575.JPG
# Iterating for file = 308.jpg
# Iterating for file = DSC02775.JPG
# Iterating for file = DSC02884.JPG
# Iterating for file = P090831019.jpg
# Iterating for file = DSC03839.JPG
# Iterating for file = DSC02425.JPG
# Iterating for file = DSC03829.JPG
# Iterating for file = DSC03274.JPG
# Iterating for file = P090911064.jpg
# Iterating for file = P1010088.JPG
# Iterating for file = DSC03052.JPG
# Iterating for file = P1010009.JPG
# Iterating for file = DSC03621.JPG
# Iterating for file = DSC03656.JPG
# Iterating for file = DSC03250.JPG
# Iterating for file = DSC03300.JPG
# Iterating for file = DSC04465.JPG
# Iterating for file = DSC04139.JPG
# Iterating for file = DSC02940.JPG
# Iterating for file = DSC04409.JPG
# Iterating for file = P1010062.JPG
# Iterating for file = P090905002.jpg
# Iterating for file = DSC03430.JPG
# Iterating for file = 038.JPG
# Iterating for file = 080119-0016.jpg
# Iterating for file = 43.JPG
# Iterating for file = DSC04151.JPG
# Iterating for file = 080119-0012.jpg
# Iterating for file = DSC02611.JPG
# Iterating for file = DSC04197.JPG
# Iterating for file = DSC04072.JPG
# Iterating for file = P1010020.JPG
# Iterating for file = DSC03133.JPG
# Iterating for file = DSC03055.JPG
# Iterating for file = DSC02802.JPG
# Iterating for file = DSC02674.JPG
# Iterating for file = DSC03691.JPG
# Iterating for file = DSC03478.JPG
# Iterating for file = P1010010.JPG
# Iterating for file = DSC02319.JPG
# Iterating for file = DSC04076.JPG
# Iterating for file = DSC02750.JPG
# Iterating for file = P090831011.jpg
# Iterating for file = DSC03654.JPG
# Iterating for file = DSC03823.JPG
# Iterating for file = DSC02919.JPG
# Iterating for file = DSC03517.JPG
# Iterating for file = 48.JPG
# Iterating for file = DSC04433.JPG
# Iterating for file = DSC03085.JPG
# Iterating for file = DSC02590.JPG
# Iterating for file = DSC04087.JPG
# Iterating for file = P090911060.jpg
# Iterating for file = DSC02319.JPG
# Iterating for file = 58.JPG
# Iterating for file = DSC04322.JPG
# Iterating for file = P090912062.jpg
# Iterating for file = P090831021.jpg
# Iterating for file = DSC02902.JPG
# Iterating for file = 26.JPG
# Iterating for file = 57.JPG
# Iterating for file = P090903002.jpg
# Iterating for file = DSC04487.JPG
# Iterating for file = 26.JPG
# Iterating for file = 2007-12-09-day-exterior-037.jpg
# Iterating for file = 025.jpg
# Iterating for file = 7.jpg
# Iterating for file = P090912036.jpg
# Iterating for file = DSC03082.JPG
# Iterating for file = DSC02947.JPG
# Iterating for file = DSC03655.JPG
# Iterating for file = P090911086.jpg
# Iterating for file = 47.JPG
# Iterating for file = 2007-12-08-day-092.jpg
# Iterating for file = DSC03439.JPG
# Iterating for file = 2007-12-09-day-exterior-047.jpg
# Iterating for file = 081.JPG
# Iterating for file = DSC03544.JPG
# Iterating for file = P1010057.JPG
# Iterating for file = 2007-12-09-day-exterior-023.jpg
# Iterating for file = 080116-0055.jpg
# Iterating for file = DSC02928.JPG
# Iterating for file = DSC02886.JPG
# Iterating for file = DSC03664.JPG
# Iterating for file = P090911067.jpg
# Iterating for file = DSC03691.JPG
# Iterating for file = P090911016.jpg
# Iterating for file = DSC03136.JPG
# Iterating for file = DSC03260.JPG
# Iterating for file = DSC03372.JPG
# Iterating for file = P1010069.JPG
# Iterating for file = P1010048.JPG
# Iterating for file = DSC03986.JPG
# Iterating for file = DSC02859.JPG
# Iterating for file = 080116-0055.jpg
# Iterating for file = DSC02477.JPG
# Iterating for file = 2007-12-09-day-exterior-047.jpg
# Iterating for file = DSC03345.JPG
# Iterating for file = DSC03650.JPG
# Iterating for file = DSC04361.JPG
# Iterating for file = DSC04397.JPG
# Iterating for file = DSC02719.JPG
# Iterating for file = DSC02800.JPG
# Iterating for file = P090831013.jpg
# Iterating for file = P090912037.jpg
# Iterating for file = DSC04057.JPG
# Iterating for file = 108.JPG
# Iterating for file = DSC02606.JPG
# Iterating for file = P090831013.jpg
# Iterating for file = DSC02755.JPG
# Iterating for file = DSC03552.JPG
# Iterating for file = DSC02309.JPG
# Iterating for file = DSC02782.JPG
# Iterating for file = DSC03786.JPG
# Iterating for file = DSC04047.JPG
# Iterating for file = DSC03050.JPG
# Iterating for file = DSC03329.JPG
# Iterating for file = DSC03823.JPG
# Iterating for file = DSC03764.JPG
# Iterating for file = DSC02933.JPG
# Iterating for file = DSC03959.JPG
# Iterating for file = P090911060.jpg
# Iterating for file = P090911083.jpg
# Iterating for file = 027.jpg
# Iterating for file = DSC04395.JPG
# Iterating for file = DSC03085.JPG
# Iterating for file = DSC02877.JPG
# Iterating for file = DSC02872.JPG
# Iterating for file = DSC03765.JPG
# Iterating for file = DSC03571.JPG
# Iterating for file = DSC03133.JPG
# Iterating for file = P090903063.jpg
# Iterating for file = 2007-12-09-day-exterior-032.jpg
# Iterating for file = DSC02320.JPG
# Iterating for file = 080116-0059.jpg
# Iterating for file = P1010080.JPG
# Iterating for file = DSC02963.JPG
# Iterating for file = DSC02417.JPG
# Iterating for file = DSC03053.JPG
# Iterating for file = DSC04248.JPG
# Iterating for file = DSC04357.JPG
# Iterating for file = DSC03085.JPG
# Iterating for file = P090903072.jpg
# Iterating for file = DSC04078.JPG
# Iterating for file = DSC02556.JPG
# Iterating for file = DSC04451.JPG
# Iterating for file = DSC03561.JPG
# Iterating for file = DSC03534.JPG
# Iterating for file = 113.jpg
# Iterating for file = 041.JPG
# Iterating for file = DSC02442.JPG
# Iterating for file = DSC02585.JPG
# Iterating for file = DSC03147.JPG
# Iterating for file = P1010016.JPG
# Iterating for file = DSC02475.JPG
# Iterating for file = P090911064.jpg
# Iterating for file = DSC03549.JPG
# Iterating for file = DSC03656.JPG
# Iterating for file = 032.jpg
# Iterating for file = DSC03010.JPG
# Iterating for file = 080119-0006.jpg
# Iterating for file = DSC02989.JPG
# Iterating for file = P1010129.JPG
# Iterating for file = DSC02519.JPG
# Iterating for file = 054.JPG
# Iterating for file = DSC02969.JPG
# Iterating for file = DSC04109.JPG
# Iterating for file = DSC04162.JPG
# Iterating for file = DSC03586.JPG
# Iterating for file = DSC02545.JPG
# Iterating for file = P090831043.jpg
# Iterating for file = DSC03010.JPG
# Iterating for file = DSC02673.JPG
# Iterating for file = DSC04064.JPG
# Iterating for file = 014.JPG
# Iterating for file = P090831007.jpg
# Iterating for file = DSC02796.JPG
# Iterating for file = DSC03271.JPG
# Iterating for file = DSC03015.JPG
# Iterating for file = P090904004.jpg
# Iterating for file = DSC03839.JPG
# Iterating for file = DSC02924.JPG
# Iterating for file = DSC03501.JPG
# Iterating for file = DSC03279.JPG
# Iterating for file = DSC03644.JPG
# Iterating for file = DSC03579.JPG
# Iterating for file = DSC03904.JPG
# Iterating for file = DSC02624.JPG
# Iterating for file = P1010012.JPG
# Iterating for file = DSC02532.JPG
# Iterating for file = DSC04434.JPG
# Iterating for file = P090831115.jpg
# Iterating for file = 021.JPG
# Iterating for file = P1010054.JPG
# Iterating for file = DSC02675.JPG
# Iterating for file = DSC02416.JPG
# Iterating for file = DSC02690.JPG
# Iterating for file = DSC04047.JPG
# Iterating for file = 2007-12-08-day-106.jpg
# Iterating for file = 2007-12-09-day-exterior-023.jpg
# Iterating for file = DSC03150.JPG
# Iterating for file = DSC02799.JPG
# Iterating for file = DSC02678.JPG
# Iterating for file = DSC04139.JPG
# Iterating for file = DSC04092.JPG
# Iterating for file = P1010090.JPG
# Iterating for file = DSC03309.JPG
# Iterating for file = DSC02907.JPG
# Iterating for file = P1010002.JPG
# Iterating for file = 2007-12-09-day-exterior-032.jpg
# Iterating for file = DSC04063.JPG
# Iterating for file = DSC03436.JPG
# Iterating for file = DSC02646.JPG
# Iterating for file = DSC03166.JPG
# Iterating for file = 105.jpg
# Iterating for file = DSC02674.JPG
# Iterating for file = DSC02874.JPG
# Iterating for file = DSC03467.JPG
# Iterating for file = 18.JPG
# Iterating for file = DSC02606.JPG
# Iterating for file = DSC04125.JPG
# Iterating for file = P090831122.jpg
# Iterating for file = 080116-0060.jpg
# Iterating for file = P090831121.jpg
# Iterating for file = DSC02772.JPG
# Iterating for file = P1010044.JPG
# Iterating for file = 129.JPG
# Iterating for file = DSC02357.JPG
# Iterating for file = DSC02482.JPG
# Iterating for file = 080116-0058.jpg
# Iterating for file = DSC02359.JPG
# Iterating for file = DSC04092.JPG
# Iterating for file = DSC03199.JPG
# Iterating for file = DSC02969.JPG
# Iterating for file = DSC02867.JPG
# Iterating for file = DSC03142.JPG
# Iterating for file = P090905007.jpg
# Iterating for file = DSC04364.JPG
# Iterating for file = DSC04135.JPG
# Iterating for file = DSC03743.JPG
# Iterating for file = DSC04029.JPG
# Iterating for file = P090903092.jpg
# Iterating for file = P090903024.jpg
# Iterating for file = P1010048.JPG
# Iterating for file = P090911016.jpg
# Iterating for file = DSC02398.JPG
# Iterating for file = DSC02450.JPG
# Iterating for file = P1010094.JPG
# Iterating for file = DSC03229.JPG
# Iterating for file = 8.jpg
# Iterating for file = DSC03539.JPG
# Iterating for file = P1010133.JPG
# Iterating for file = DSC02676.JPG
# Iterating for file = DSC02903.JPG
# Iterating for file = DSC02519.JPG
# Iterating for file = DSC02867.JPG
# Iterating for file = 2007-12-08-day-106.jpg
# Iterating for file = P090831017.jpg
# Iterating for file = DSC02394.JPG
# Iterating for file = 032.jpg
# Iterating for file = P090912066.jpg
# Iterating for file = DSC03883.JPG
# Iterating for file = DSC03609.JPG
# Iterating for file = DSC02842.JPG
# Iterating for file = DSC02317.JPG
# Iterating for file = P1010060.JPG
# Iterating for file = DSC03015.JPG
# Iterating for file = DSC02527.JPG
# Iterating for file = DSC03135.JPG
# Iterating for file = DSC02379.JPG
# Iterating for file = DSC03571.JPG
# Iterating for file = DSC02887.JPG
# Iterating for file = DSC02590.JPG
# Iterating for file = DSC03091.JPG
# Iterating for file = DSC03010.JPG
# Iterating for file = DSC04249.JPG
# Iterating for file = DSC03168.JPG
# Iterating for file = DSC04030.JPG
# Iterating for file = DSC03738.JPG
# Iterating for file = 48.JPG
# Iterating for file = P090911064.jpg
# Iterating for file = P090831010.jpg
# Iterating for file = 2007-12-09-day-exterior-086.jpg
# Iterating for file = DSC04052.JPG
# Iterating for file = DSC02791.JPG
# Iterating for file = 104.jpg
# Iterating for file = DSC02919.JPG
# Iterating for file = DSC03820.JPG
# Iterating for file = DSC03839.JPG
# Iterating for file = P090831021.jpg
# Iterating for file = DSC02777.JPG
# Iterating for file = DSC03674.JPG
# Iterating for file = DSC02629.JPG
# Iterating for file = 080118-0007.jpg
# Iterating for file = DSC02240.JPG
# Iterating for file = 083.JPG
# Iterating for file = DSC04153.JPG
# Iterating for file = 45.JPG
# Iterating for file = 2007-12-08-day-137.jpg
# Iterating for file = 18.JPG
# Iterating for file = DSC02923.JPG
# Iterating for file = DSC03259.JPG
# Iterating for file = 56.JPG
# Iterating for file = DSC03077.JPG
# Iterating for file = DSC02907.JPG
# Iterating for file = IMG_2618.JPG
# Iterating for file = DSC03539.JPG
# Iterating for file = DSC02575.JPG
# Iterating for file = 2.JPG
# Iterating for file = DSC03316.JPG
# Iterating for file = 027.JPG
# Iterating for file = DSC02483.JPG
# Iterating for file = DSC02471.JPG
# Iterating for file = DSC03414.JPG
# Iterating for file = DSC02800.JPG
# Iterating for file = DSC04203.JPG
# Iterating for file = DSC03732.JPG
# Iterating for file = DSC03023.JPG
# Iterating for file = DSC03297.JPG
# Iterating for file = 26.JPG
# Iterating for file = DSC03077.JPG
# Iterating for file = ktx.jpg
# Iterating for file = DSC04442.JPG
# Iterating for file = DSC03432.JPG
# Iterating for file = P090903055.jpg
# Iterating for file = DSC03010.JPG
# Iterating for file = P1010024.JPG
# Iterating for file = DSC04364.JPG
# Iterating for file = 42.JPG
# Iterating for file = DSC03411.JPG
# Iterating for file = DSC04078.JPG
# Iterating for file = P090911060.jpg
# Iterating for file = DSC03654.JPG
# Iterating for file = P1010098.JPG
# Iterating for file = DSC03266.JPG
# Iterating for file = 047.jpg
# Iterating for file = DSC02368.JPG
# Iterating for file = DSC03365.JPG
# Iterating for file = DSC02687.JPG
# Iterating for file = P090912074.jpg
# Iterating for file = DSC04080.JPG
# Iterating for file = DSC03743.JPG
# Iterating for file = 080119-0033.jpg
# Iterating for file = 080119-0011.jpg
# Iterating for file = P1010044.JPG
# Iterating for file = DSC02862.JPG
# Iterating for file = DSC02406.JPG
# Iterating for file = DSC03745.JPG
# Iterating for file = m.jpg
# Iterating for file = DSC04226.JPG
# Iterating for file = DSC02776.JPG
# Iterating for file = P1010164.JPG
# Iterating for file = 080119-0013.jpg
# Iterating for file = DSC04150.JPG
# Iterating for file = DSC03638.JPG
# Iterating for file = P090905007.jpg
# Iterating for file = DSC03165.JPG
# Iterating for file = IMG_2481.JPG
# Iterating for file = DSC02354.JPG
# Iterating for file = DSC03245.JPG
# Iterating for file = DSC03693.JPG
# Iterating for file = DSC02937.JPG
# Iterating for file = DSC03135.JPG
# Iterating for file = DSC03323.JPG
# Iterating for file = DSC03168.JPG
# Iterating for file = DSC02964.JPG
# Iterating for file = DSC03935.JPG
# Iterating for file = DSC03556.JPG
# Iterating for file = 2007-12-08-day-091.jpg
# Iterating for file = DSC03170.JPG
# Iterating for file = DSC03786.JPG
# Iterating for file = DSC03084.JPG
# Iterating for file = IMG_2618.JPG
# Iterating for file = 002.jpg
# Iterating for file = 026.JPG
# Iterating for file = DSC03652.JPG
# Iterating for file = P1010055.JPG
# Iterating for file = DSC04321.JPG
# Iterating for file = DSC03305.JPG
# Iterating for file = P1010080.JPG
# Iterating for file = DSC03650.JPG
# Iterating for file = 100.JPG
# Iterating for file = DSC04122.JPG
# Iterating for file = DSC02557.JPG
# Iterating for file = DSC03122.JPG
# Iterating for file = DSC04465.JPG
# Iterating for file = DSC02726.JPG
# Iterating for file = DSC04009.JPG
# Iterating for file = DSC04019.JPG
# Iterating for file = P090903001.jpg
# Iterating for file = DSC02604.JPG
# Iterating for file = P090903009.jpg
# Iterating for file = 1.jpg
# Iterating for file = DSC03000.JPG
# Iterating for file = DSC02411.JPG
# Iterating for file = P090831118.jpg
# Iterating for file = DSC03946.JPG
# Iterating for file = DSC02672.JPG
# Iterating for file = 44.JPG
# Iterating for file = 115.JPG
# Iterating for file = DSC03199.JPG
# Iterating for file = DSC02557.JPG
# Iterating for file = 58.JPG
# Iterating for file = DSC03723.JPG
# Iterating for file = DSC04139.JPG
# Iterating for file = DSC03234.JPG
# Iterating for file = DSC04135.JPG
# Iterating for file = 44.JPG
# Iterating for file = DSC02389.JPG
# Iterating for file = DSC02998.JPG
# Iterating for file = P090903055.jpg
# Iterating for file = DSC03003.JPG
# Iterating for file = P090912062.jpg
# Iterating for file = DSC02319.JPG
# Iterating for file = DSC02799.JPG
# Iterating for file = DSC03129.JPG
# Iterating for file = DSC03229.JPG
# Iterating for file = P090831114.jpg
# Iterating for file = DSC02572.JPG
# Iterating for file = DSC03757.JPG
# Iterating for file = DSC03229.JPG
# Iterating for file = 1.JPG
# Iterating for file = DSC03409.JPG
# Iterating for file = DSC02421.JPG
# Iterating for file = P090903015.jpg
# Iterating for file = 047.JPG
# Iterating for file = DSC02910.JPG
# Iterating for file = P1010056.JPG
# Iterating for file = DSC03912.JPG
# Iterating for file = P1010132.JPG
# Iterating for file = 137.JPG
# Iterating for file = 3.JPG
# Iterating for file = 080120-0001.jpg
# Iterating for file = DSC03658.JPG
# Iterating for file = DSC02322.JPG
# Iterating for file = DSC04065.JPG
# Iterating for file = DSC02881.JPG
# Iterating for file = P090912036.jpg
# Iterating for file = DSC03581.JPG
# Iterating for file = DSC03651.JPG
# Iterating for file = DSC04305.JPG
# Iterating for file = DSC02461.JPG
# Iterating for file = DSC04149.JPG
# Iterating for file = DSC02925.JPG
# Iterating for file = DSC03670.JPG
# Iterating for file = DSC02884.JPG
# Iterating for file = DSC03061.JPG
# Iterating for file = DSC03133.JPG
# Iterating for file = DSC03431.JPG
# Iterating for file = P090831011.jpg
# Iterating for file = P090831008.jpg
# Iterating for file = DSC03682.JPG
# Iterating for file = DSC03271.JPG
# Iterating for file = DSC02859.JPG
# Iterating for file = P090912040.jpg
# Iterating for file = DSC04254.JPG
# Iterating for file = P090831022.jpg
# Iterating for file = DSC04063.JPG
# Iterating for file = DSC02893.JPG
# Iterating for file = DSC02344.JPG
# Iterating for file = DSC04076.JPG
# Iterating for file = 133.JPG
# Iterating for file = DSC03136.JPG
# Iterating for file = P1010085.JPG
# Iterating for file = DSC02877.JPG
# Iterating for file = DSC03999.JPG
# Iterating for file = DSC03718.JPG
# Iterating for file = DSC04155.JPG
# Iterating for file = DSC03414.JPG
# Iterating for file = P1010099.JPG
# Iterating for file = P090912059.jpg
# Iterating for file = P1010082.JPG
# Iterating for file = DSC04463.JPG
# Iterating for file = DSC04035.JPG
# Iterating for file = P1010086.JPG
# Iterating for file = DSC03210.JPG
# Iterating for file = DSC04323.JPG
# Iterating for file = 080119-0014.jpg
# Iterating for file = DSC04256.JPG
# Iterating for file = DSC02788.JPG
# Iterating for file = 083.JPG
# Iterating for file = DSC02590.JPG
# Iterating for file = DSC03579.JPG
# Iterating for file = 063.JPG
# Iterating for file = DSC03340.JPG
# Iterating for file = 134.JPG
# Iterating for file = P090831125.jpg
# Iterating for file = P090911067.jpg
# Iterating for file = DSC02355.JPG
# Iterating for file = DSC02460.JPG
# Iterating for file = DSC02411.JPG
# Iterating for file = 6.jpg
# Iterating for file = DSC02513.JPG
# Iterating for file = 032.jpg
# Iterating for file = DSC02398.JPG
# Iterating for file = DSC03549.JPG
# Iterating for file = 080119-0013.jpg
# Iterating for file = 031.JPG
# Iterating for file = DSC03185.JPG
# Iterating for file = P1010099.JPG
# Iterating for file = DSC02477.JPG
# Iterating for file = P1010025.JPG
# Iterating for file = DSC03273.JPG
# Iterating for file = DSC03743.JPG
# Iterating for file = DSC02483.JPG
# Iterating for file = DSC03467.JPG
# Iterating for file = DSC03785.JPG
# Iterating for file = DSC02725.JPG
# Iterating for file = 2007-12-08-day-103.jpg
# Iterating for file = DSC03887.JPG
# Iterating for file = DSC03063.JPG
# Iterating for file = DSC03489.JPG
# Iterating for file = DSC04318.JPG
# Iterating for file = P090831122.jpg
# Iterating for file = P1010052.JPG
# Iterating for file = DSC04128.JPG
# Iterating for file = P1010012.JPG
# Iterating for file = 014.JPG
# Iterating for file = P090903071.jpg
# Iterating for file = DSC03129.JPG
# Iterating for file = P090831015.jpg
# Iterating for file = DSC03640.JPG
# Iterating for file = DSC03554.JPG
# Iterating for file = 118.JPG
# Iterating for file = DSC03514.JPG
# Iterating for file = DSC02719.JPG
# Iterating for file = DSC02447.JPG
# Iterating for file = DSC02646.JPG
# Iterating for file = 56.JPG
# Iterating for file = DSC03896.JPG
# Iterating for file = DSC02447.JPG
# Iterating for file = 080119-0020.jpg
# Iterating for file = DSC03316.JPG
# Iterating for file = DSC04395.JPG
# Iterating for file = 090.jpg
# Iterating for file = DSC03124.JPG
# Iterating for file = DSC03664.JPG
# Iterating for file = DSC02918.JPG
# Iterating for file = DSC02887.JPG
# Iterating for file = DSC02924.JPG
# Iterating for file = P1010060.JPG
# Iterating for file = DSC04368.JPG
# Iterating for file = DSC03911.JPG
# Iterating for file = P1010060.JPG
# Iterating for file = P1010035.JPG
# Iterating for file = P090902019.jpg
# Iterating for file = P1010057.JPG
# Iterating for file = 047.JPG
# Iterating for file = DSC03302.JPG
# Iterating for file = 2007-12-08-day-091.jpg
# Iterating for file = DSC02933.JPG
# Iterating for file = 063.JPG
# Iterating for file = DSC03299.JPG
# Iterating for file = DSC02377.JPG
# Iterating for file = DSC04368.JPG
# Iterating for file = DSC02479.JPG
# Iterating for file = P090902018.jpg
# Iterating for file = DSC03687.JPG
# Iterating for file = DSC02776.JPG
# Iterating for file = DSC02413.JPG
# Iterating for file = P1010087.JPG
# Iterating for file = P1010164.JPG
# Iterating for file = DSC04071.JPG
# Iterating for file = DSC02770.JPG
# Iterating for file = DSC02611.JPG
# Iterating for file = DSC03203.JPG
# Iterating for file = 080116-0055.jpg
# Iterating for file = DSC02907.JPG
# Iterating for file = 025.jpg
# Iterating for file = DSC03283.JPG
# Iterating for file = DSC04115.JPG
# Iterating for file = 078.JPG
# Iterating for file = P1010098.JPG
# Iterating for file = DSC02419.JPG
# Iterating for file = DSC02749.JPG
# Iterating for file = DSC04322.JPG
# Iterating for file = DSC03446.JPG
# Iterating for file = DSC03544.JPG
# Iterating for file = DSC03432.JPG
# Iterating for file = DSC04404.JPG
# Iterating for file = DSC02384.JPG
# Iterating for file = DSC03345.JPG
# Iterating for file = DSC03026.JPG
# Iterating for file = DSC04421.JPG
# Iterating for file = DSC04337.JPG
# Iterating for file = DSC02610.JPG
# Iterating for file = P090911084.jpg
# Iterating for file = 080119-0004.jpg
# Iterating for file = DSC04305.JPG
# Iterating for file = 002.jpg
# Iterating for file = DSC04429.JPG
# Iterating for file = P090912071.jpg
# Iterating for file = 2007-12-08-day-106.jpg
# Iterating for file = DSC02376.JPG
# Iterating for file = DSC03212.JPG
# Iterating for file = P1010020.JPG
# Iterating for file = DSC02411.JPG
# Iterating for file = DSC03730.JPG
# Iterating for file = DSC02755.JPG
# Iterating for file = DSC03650.JPG
# Iterating for file = 2007-12-09-day-exterior-047.jpg
# Iterating for file = DSC03061.JPG
# Iterating for file = DSC03582.JPG
# Iterating for file = 51.JPG
# Iterating for file = DSC04059.JPG
# Iterating for file = DSC02421.JPG
# Iterating for file = DSC03150.JPG
# Iterating for file = 110.jpg
# Iterating for file = DSC03413.JPG
# Iterating for file = P090831012.jpg
# Iterating for file = DSC03203.JPG
# Iterating for file = P1010024.JPG
# Iterating for file = P090912071.jpg
# Iterating for file = DSC04061.JPG
# Iterating for file = DSC02355.JPG
# Iterating for file = DSC03666.JPG
# Iterating for file = P1010064.JPG
# Iterating for file = 065.jpg
# Iterating for file = DSC03331.JPG
# Iterating for file = DSC02602.JPG
# Iterating for file = DSC03787.JPG
# Iterating for file = DSC03015.JPG
# Iterating for file = DSC03314.JPG
# Iterating for file = 080119-0009.jpg
# Iterating for file = DSC04094.JPG
# Iterating for file = P1010085.JPG
# Iterating for file = DSC04003.JPG
# Iterating for file = P090831136.jpg
# Iterating for file = DSC03909.JPG
# Iterating for file = 18.JPG
# Iterating for file = 089.jpg
# Iterating for file = DSC03170.JPG
# Iterating for file = DSC04069.JPG
# Iterating for file = DSC02639.JPG
# Iterating for file = DSC02674.JPG
# Iterating for file = 57.JPG
# Iterating for file = DSC03396.JPG
# Iterating for file = DSC03758.JPG
# Iterating for file = P090831037.jpg
# Iterating for file = P1010114.JPG
# Iterating for file = DSC02514.JPG
# Iterating for file = P090911050.jpg
# Iterating for file = P1010096.JPG
# Iterating for file = DSC02978.JPG
# Iterating for file = DSC04304.JPG
# Iterating for file = DSC03077.JPG
# Iterating for file = DSC03433.JPG
# Iterating for file = DSC04450.JPG
# Iterating for file = DSC02894.JPG
# Iterating for file = P1010030.JPG
# Iterating for file = DSC02407.JPG
# Iterating for file = P090831115.jpg
# Iterating for file = 2007-12-08-day-111.jpg
# Iterating for file = P090905003.jpg
# Iterating for file = DSC04318.JPG
# Iterating for file = DSC02368.JPG
# Iterating for file = P090903024.jpg
# Iterating for file = DSC03225.JPG
# Iterating for file = 104.jpg
# Iterating for file = DSC02801.JPG
# Iterating for file = DSC02357.JPG
# Iterating for file = 080119-0016.jpg
# Iterating for file = 064.JPG
# Iterating for file = P1010017.JPG
# Iterating for file = P1010098.JPG
# Iterating for file = DSC03254.JPG
# Iterating for file = P1010086.JPG
# Iterating for file = DSC03201.JPG
# Iterating for file = P1010156.JPG
# Iterating for file = P1010065.JPG
# Iterating for file = 080118-0011.jpg
# Iterating for file = DSC03265.JPG
# Iterating for file = DSC02919.JPG
# Iterating for file = DSC03730.JPG
# Iterating for file = 4.jpg
# Traceback (most recent call last):
#
#   File "/home/ec2-user/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-19-bb83c1977d2f>", line 13, in <module>
#     ground_truth_str = fetch_from_xml(dir_path, xml_file)
#
#   File "<ipython-input-14-e9427f63dd51>", line 16, in fetch_from_xml
#     tree = ET.parse(os.path.join(path, file)).getroot()
#
#   File "/home/ec2-user/anaconda3/lib/python3.6/xml/etree/ElementTree.py", line 1196, in parse
#     tree.parse(source, parser)
#
#   File "/home/ec2-user/anaconda3/lib/python3.6/xml/etree/ElementTree.py", line 597, in parse
#     self._root = parser._parse_whole(source)
#
#   File "<string>", line unknown
# ParseError: XML or text declaration not at start of entity: line 1, column 4

# %%
os.path.exists("datasets/KAIST/English/36.xml")
# Out:
# False

# %%
print ("Accuracy = {}".format(correct_pred/total_pred))
# Out:
# Accuracy = 0.7703016241299304

# %%
vision_client = vision.ImageAnnotatorClient()
correct_pred, total_pred = 0, 0
idx = 20
file = dict_files.get(idx)
xml_file = file[:len(file)-4] + '.xml' 

ground_truth_str = fetch_from_xml(dir_path, xml_file)
if len(ground_truth_str) == 0:
    print ("A")
    #continue


with io.open(os.path.join(dir_path, file), 'rb') as image_file:
        content = (image_file.read())
image = vision.types.Image(content=content)
text_detection_response = vision_client.text_detection(image=image)
detected_str = extract_clean_str(text_detection_response.full_text_annotation.text)
 

if are_sentences_alike(detected_str, ground_truth_str, .3):
    correct_pred += 1

# %%
f = open(os.path.join(dir_path, 'DSC02629.xml'), "r")
print(f.read())

# %%
len(files_idx)

# %%
ground_truth

# %%
import xml.etree.ElementTree as ET 
tree = ET.parse(os.path.join(dir_path, 'DSC02629.xml')) 
root = tree.getroot() 
ground_truth = ''
for elem in tree.iter(tag='character'):
    ground_truth += (elem.attrib['char'])

# %%
vision_client = vision.ImageAnnotatorClient()
curr_training = 0
for idx in shuffled_idx:
    file = dict_files.get(idx)
    
    with io.open(dir_path, 'rb') as image_file:
        content = (image_file.read())
    image = vision.types.Image(content=content)
    text_detection_response = vision_client.text_detection(image=image)
    detected_str = text_detection_response.full_text_annotation.text
    
    
    curr_training += 1
    if curr_training > MAX_TRAINING:
        break

# %%
root = ET.parse(os.path.join(dir_path, 'DSC02629.xml')).getroot()  
ground_truth = extract_clean_str(''.join([e.attrib['char'] for e in tree.iter(tag='character')]))
ground_truth

# %%
dir_path, xml_file

# %%
are_sentences_alike(detected_str, ground_truth_str, .3)

# %%
len(ground_truth_str)

# %%
detected_str, ground_truth_str
